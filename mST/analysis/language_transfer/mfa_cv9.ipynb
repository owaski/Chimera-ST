# %%
import os
import re
import random
from argparse import Namespace
from string import punctuation
from collections import defaultdict

import IPython

import torch as th
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
import torchaudio
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sentencepiece as spm

import textgrids
import faiss

from sentence_transformers import SentenceTransformer
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

from fairseq.data import Dictionary
from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)
from fairseq.data.audio.speech_to_text_dataset import get_features_or_waveform
from examples.speech_to_text.data_utils import load_df_from_tsv, save_df_to_tsv
from fairseq.checkpoint_utils import load_checkpoint_to_cpu
from fairseq.data.encoders.sentencepiece_bpe import SentencepieceBPE, SentencepieceConfig

from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)

# %% [markdown]
# # Build Code-Switch for CV 9.0 Language

# %%
root = '/mnt/data/siqiouyang/datasets/cv-corpus-9.0-2022-04-27/'

# %% [markdown]
# # Tokenization

# %%
tokenizer = spm.SentencePieceProcessor()
tokenizer.Load('/mnt/data/siqiouyang/runs/mST/pretrained/mbart50.ft.n1/sentence.bpe.model')
# Out:
# True

# %%
lang = 'de'
lang_root = os.path.join(root, lang)

# %%
lang_df = load_df_from_tsv(os.path.join(lang_root, 'validated.tsv'))

# %%
# Optionally resample the audio to 16kHz
# os.makedirs(os.path.join(dict_lang_root, '16kHz'))
# for path in tqdm(dict_lang_df['path']):
#     audio_path = os.path.join(dict_lang_root, 'clips/{}'.format(path))
#     waveform, sample_rate = torchaudio.load(audio_path)
#     resampled_waveform = torchaudio.functional.resample(waveform, sample_rate, 16000)
#     torchaudio.save(os.path.join(dict_lang_root, '16kHz/{}.wav'.format(path[:-4])), resampled_waveform, sample_rate=16000)

# %%
sentences = lang_df['sentence'].tolist()
sentences
# Out:
# ['Zieht euch bitte draußen die Schuhe aus.',
#  'Es gibt auch mehrere Campingplätze.',
#  'Es kommt zum Showdown in Gstaad.',
#  'Ihre Fotostrecken erschienen in Modemagazinen wie der Vogue, Harper’s Bazaar und Marie Claire.',
#  'Aber weißt du, wer den Stein wirklich ins Rollen gebracht hat?',
#  'Felipe hat eine auch für Monarchen ungewöhnlich lange Titelliste.',
#  'Was solls, ich bin bereit.',
#  'Sein Atelier diente nebenher zur Tarnung unerlaubter politischer Aktivitäten.',
#  'Das Internet besteht aus vielen Computern, die miteinander verbunden sind.',
#  'Jörg van Essen ist stets über die Landesliste Nordrhein-Westfalen in den Deutschen Bundestag eingezogen.',
#  'Der Uranus ist der siebente Planet in unserem Sonnensystem.',
#  'Sie gewannen das Match mit sechs Löchern Vorsprung.',
#  'Die Wagen erhielten ein einheitliches Erscheinungsbild in weiß mit rotem Fensterband.',
#  'Seinen Vornamen erhielt er in Gedenken an seinen früh verstorbenen Onkel.',
#  'Mit den Senators nahm er an drei All-Star-Spielen teil.',
#  'Vorher und danach war der Löwe im Wappen.',
#  'Insgesamt ist der Sound etwas zu basslastig.',
#  'Wie ist die derzeitige Verkehrssituation?',
#  'Vielleicht können Sie uns diese Frage am Ende der Aussprache beantworten.',
#  'Dieses Maß wird in Zoll angegeben.',
#  'Aus den Prozessakten der Hexenverfolgung sind keine authentischen Rezepte bekannt.',
#  'Ein großer Teil der Conciergerie wird heute für die Pariser Gerichte genutzt.',
#  'Weshalb möchtest du nach Bergheim?',
#  'Auflage des Wettbewerbes.',
#  'Eislutscher sind viel leckerer als Eistüten.',
#  'Seit ihrem achten Lebensjahr bekam sie Tanzunterricht.',
#  'Wenn nicht, dann legt man sie irgendwo hin, wo Platz ist.',
#  'Der Innenraum trägt eine flache Holzdecke, an der Nord- und Westwand sind Emporen angebracht.',
#  'Vier Jahre später erlitt sein Vater einen Jagdunfall, der ihn arbeitsunfähig machte.',
#  'Durch Bestrahlen kann eine Kontamination der Nahrung verhindert werden.',
#  'Ich hätte Sie nicht bestehen lassen.',
#  'Insbesondere keine Topflappen.',
#  'Wir werden in diese Debatte nicht erneut eintreten.',
#  'Im Winter wird Rugby Union gespielt, im Sommer Cricket.',
#  'Es gibt vier Staubblätter.',
#  'Die bundesdeutsche Anti-Atom-Bewegung erlebte in Brokdorf ihren unaufhaltsamen Aufstieg und ihre größten Niederlagen.',
#  'Ein unbekannter Tatverdächtiger wird in seinem Wagen verfolgt.',
#  'fünf',
#  'Die Pfarrkirche des Ortes war dem Heiligen Martin gewidmet.',
#  'Das Publikum fordert lautstark eine Zugabe.',
#  'Daneben veröffentlichte er mehrere Bücher über den Bau und die Konstruktion von Dampflokomotiven.',
#  'Es ist die höchste Anzahl von Eukaryoten, die bisher bei den Faultieren beobachtet wurde.',
#  '„Dann kann er jetzt vergnügt sein und schnell laufen“, sagte Tante Dahlia lebhaft.',
#  'Müller, geboren.',
#  'Sie liegt im Osten des Landes, an der Grenze zu Tansania.',
#  'Zu seinen weiteren Aufgaben gehört die Abnahme von neu eingekauften oder geleasten Flugzeugen.',
#  'Der Standesbeamte war ein komischer Vogel.',
#  'Das kann nicht gehen.',
#  'Ähnlich gefärbte Ziegen kommen auch im Piemont und im Hochsavoyen der französischen Alpen vor.',
#  'Sie trugen alle sowjetische Hoheitszeichen, als sie per Bahn im Reich eintrafen.',
#  'Meine Lieblingsfarbe ist schwarz, sagte Lola.',
#  'Nach dem Verlust dieser Funktion beschäftigten sich die Einwohner hauptsächlich mit Landwirtschaft.',
#  'Sie wurde nach der Stadt Boise in Idaho benannt.',
#  'Er arbeitete anschließend am Brookhaven National Laboratory.',
#  'Macht euch nur darüber lustig.',
#  'Abschließend möchte ich Ihnen gerne etwas sehr Wichtiges mitteilen.',
#  'Dieses Rittergut wird heute für private Wohnzwecke genutzt.',
#  'Als staatlicher Feiertag gilt er für staatliche Angestellte und Beamte.',
#  'Sowohl Thomas Howard als auch Margaret Douglas wurden im Tower of London gefangen gesetzt.',
#  'Sein Sohn war der Politiker Hartwig von Rheden.',
#  'Wie ist die derzeitige Verkehrssituation?',
#  'Hiernach war er Hofmeister des jungen Herrn von Wilmersdorf.',
#  'Die Uhr geht falsch.',
#  'Legislaturperiode des türkischen Parlamentes war er Abgeordneter.',
#  'Doch wie sich gerade zeigt, ist das Thema aktueller denn je.',
#  'acht',
#  'Mit sechs Jahren hatte Judy Weiss ihre ersten Klavierstunden.',
#  'Während der Streife hatten Buffy und Angel einen Streit.',
#  'Katarina Srebotnik und Nenad Zimonjić waren die Titelverteidiger.',
#  'Polnische Armee sich westlich der Weichsel Brückenköpfe erkämpften.',
#  'Sie sind heute noch in Kraft.',
#  'Der Tunnel ist der längste dieser Eisenbahnstrecke und bildet mit den zweithöchsten Punkt.',
#  'Später übernahm die Stadt Heilbronn dies als offiziellen Namen.',
#  'Der Datenschutz ist gewährleistet.',
#  'Die Frühjahrstagung des Rates hat das unter Beweis gestellt.',
#  'Aus dieser Ehe stammt die Schauspielerin und Sängerin Laura Schneiderhan.',
#  'Laut Clamp dienen diese beiden Manga dazu, das gesamte Clamp-Universum zu verbinden.',
#  'Sie ist eine agile, gute Schwimmerin.',
#  'Unter der Plane wächst nichts.',
#  'Messe in der Kapelle an allen Festtagen gestattet.',
#  'drei',
#  'Nach zwei Auftritten als Gastdarsteller in der Sitcom Wer ist hier der Boss?',
#  'Leider ist der Rat hier nicht mehr vertreten.',
#  'Das Land musste neu aufgebaut werden und brauchte gebildete junge Menschen.',
#  'Ach du Schreck!',
#  'Hilf mir mal.',
#  'Der Strahl wird in kleinste Partikel zerstäubt.',
#  'Vor der Kirche befindet sich ein Taufstein, in den Menschendarstellungen und Symbole eingearbeitet sind.',
#  'Die Frau von Justice, Wilhelmina, wird in den Filmen oft erwähnt, aber nie gezeigt.',
#  'Ein altes Backhaus ist auch heute noch in Betrieb und Mittelpunkt des Ortsteiles.',
#  'Die Sache hat allerdings einen Haken.',
#  'Louise d’Aumont entstammte einer der reichsten Familien Frankreichs.',
#  'Wie lange ist der letzte Ölwechsel her?',
#  'Keine Ahnung.',
#  'Auch die am Platz liegende Kindertagesstätte trägt den Namen der beiden Kinder.',
#  'Zwei Softball-Spieler versuchen, einen Ball zu fangen.',
#  'Abflussrohre sollte man verschließen, damit der Geruch der Kanalisation nicht in die Wohnung steigt.',
#  'Ja gut, da kann man nichts machen!',
#  'Eine Nebenstelle des Rathauses ist in "Cavaliere" eingerichtet.',
#  'Bei Siebmacher ist der Wappenschild waagrecht geteilt in Silber und Schwarz.',
#  'Das Attentat war stümperhaft geplant.',
#  'vier',
#  'Er ist Mitglied des Landesvorstands im "Team Stronach für Steiermark".',
#  'Sie wurde nach Plänen des Architekten Paul Hoppe errichtet.',
#  "Diese Körper werden als ein Bauteil montiert 'Phase-Plug' genannt.",
#  'Rang im Norden.',
#  'Dabei durfte die historische Fassade nicht beschädigt werden.',
#  'Haben wir noch genügend Rohstoffe?',
#  'Der Empfänger erhält also ein möglicherweise verändertes Wort.',
#  'Das Fachwissen sollte in Westeuropa nicht mehr interessant sein.',
#  'Bezug auf diesen Text nimmt beispielsweise der stadtplanerische Entwurf von Karlsruhe.',
#  'Daher verpasste er den Saisonauftakt und kehrte erst Ende März zurück ins Training.',
#  'Ich möchte ferner hinzufügen, dass unsere Hersteller in diesem Bereich Weltspitze sind.',
#  'Da muss ein rasches Vorgehen geplant werden!',
#  'Er entthronte seinen Halbbruder und setzte ihn gefangen; anschließend ermordete er Peter eigenhändig.',
#  'Gründer und Geschäftsführer ist Paul Grau.',
#  'Zum zweiten möchte ich einige Worte an die Kommission richten.',
#  'Herr Rahn hat gekräuseltes Haar.',
#  'neun',
#  'In den Umkleiden gibt es Spinde.',
#  'Auf Vereinsebene gewann er drei deutsche Meistertitel.',
#  'Klasse aus einem Spiel zwischen diesen beiden Klubs bestand.',
#  'Hauptaugenmerk lag zunächst auf der Schaffung von effizienteren Produktionsbedingungen.',
#  'Der schmale Anbau im Westen hatte ein Giebeldach.',
#  'Hast du dein Ticket nach Görlitz schon gebucht?',
#  'Da wird Rebecca sich aber freuen!',
#  'Es entstand dadurch das Gefühl, dass die Gerechtigkeit niemals siegen könne.',
#  'In Kontakt mit anderen Menschen zu bleiben, senkt das Risiko, an Demenz zu erkranken.',
#  'So entschloss er sich nach einer Auseinandersetzung mit einem Vorgesetzten, aus dem Militärdienst auszuscheiden.',
#  'Er wurde Mitglied des Heilbronner Künstlerbundes und malte gemeinsam mit Wilhelm Schäffer.',
#  'Zugleich werden von der Steuerung automatisch, und der Fahrweise angepasst, Gas und Kupplung bedient.',
#  'Die junge Polizistin machte den Eindruck, als müsste sie sich vor ihren älteren Kollegen erst noch beweisen.',
#  'Das wird auch geschehen.',
#  'Du benutzt ständig irgendwelche Redewendungen, die ich nicht kenne.',
#  'Noch im Bademantel schlurfte er zum Kühlschrank und griff sich einen Jogurt.',
#  'Das kann man auch einfach mit einem scharfen Messer machen.',
#  'Die Partei war damit zwar gerettet, doch wurde die Parteiführung anschließend verhaftet.',
#  'Er erkrankte zudem an Kinderlähmung.',
#  'Dieser Anblick zog zahlreiche Neugierige an.',
#  'In diesen drei Action-Filmen werden Themen des modernen organisierten Verbrechens behandelt.',
#  'Fördern bedeutet natürlich auch immer eine gewisse finanzielle Unterstützung.',
#  'Was hat sich darüber hinaus verändert?',
#  'Der Entwurf verfehlte dennoch die notwendige Zweidrittelmehrheit.',
#  'Die internationale Politik vermochte erst in der Weimarer Republik kleine Zugeständnisse aushandeln.',
#  'So viel Tiefgründigkeit traue ich denen nicht zu.',
#  'Noch im Jahrzehnt seines Todesjahres entstanden zwei hagiographische Lebensbeschreibungen Bardos.',
#  'nan',
#  'Aufgrund der zerklüfteten Küstenlinien Rügens waren die Umwege sonst erheblich.',
#  'Über beide Kanäle steigt dadurch ein Teil der Schmelze bis in das Gefäß auf.',
#  'Die Linie wurde später von der Union Pacific Railroad übernommen.',
#  'Dazu gehören ein Wetterdienst sowie Informationen zum Seegang und zum Schiffsverkehr in engen Passagen.',
#  'Der Burgstall wird im Westen durch den Steilhang geschützt.',
#  'Die Lösungen können nur dann eine Wirkung erzielen, wenn sie miteinander verknüpft werden.',
#  'Mir ist der Appetit vergangen.',
#  'Ein Wal ist gestrandet.',
#  'Die Strichfarbe ist weiß.',
#  'Soweit zu dieser Sache!',
#  'Es ist bedauerlich, wie viele Kinder beim Laternenumzug nur noch LED-Laternen tragen dürfen.',
#  'Dort existiert ein Vulkan, der Kahlberg, der kurz vor dem Ausbruch steht.',
#  'Die Reaktion von weißem Phosphor mit Sauerstoff ist stark exotherm.',
#  'Drittens, die wichtige Frage der Einwanderung.',
#  'Dieses Abkommen tritt mit seiner Unterschrift in Kraft.',
#  'Leonie und Paul streiten sich darum, wer als erstes auf das Schaukelpferd darf.',
#  'Wäre das eine geeignete Kodierung oder eher nicht?',
#  'Ich bin sehr gespannt.',
#  'Dies waren schwierige Jahren mit zahlreichen Herausforderungen.',
#  'Ich denke, die maltesische Bevölkerung sollte selbst entscheiden, ob Malta beitreten will oder nicht.',
#  'So gesehen, kann er nur unausgereift sein.',
#  'Im Personenverkehr diente die Strecke vornehmlich lokalen Interessen.',
#  'Anna, weißt du wo Charlotte ist?',
#  'ja',
#  'sechs',
#  'In Österreich ist ebenfalls die U-Schreibung üblich.',
#  'Haben wir noch Nudeln?',
#  'Der ebenfalls abgebildete Ochse soll auf die Gründungslegende der Kapelle Bezug nehmen.',
#  'Aber wie?',
#  'Die Stadt Aachen verteilt bereits vorsorglich Jodtabletten.',
#  'Alle Mitgliedstaaten profitieren direkt oder indirekt.',
#  'Der Pfarrhof war von da an von Weltgeistlichen bewohnt.',
#  'acht',
#  'Konstantinopel war die Hauptstadt des Byzantinischen Reichs.',
#  'Sie muss Folge leisten.',
#  'Der Ladenbesitzer ist überrascht und verärgert und bringt diese Gefühle zum Ausdruck, indem er „Hey!“ sagt.',
#  'Ab jetzt noch achtundvierzig Stunden.',
#  'Daran sollten wir uns auch heute immer wieder erinnern.',
#  'Das beinhaltet Dinge wie Essen, Schreiben, Zähne-Putzen, Rasieren, Kämmen und Sich-Waschen.',
#  'Diese Aneignung vollzieht sich vielfach auf der Grundlage eingeführter esoterischer Vorstellungen.',
#  'Die größten Städte Englands sind London, Birmingham und Manchester.',
#  'Ursprünglich war der Ort nur eine Alm und nur im Sommer bewohnt.',
#  'nan',
#  'Die Küche der Stadt Livorno bietet vor allem Fischgerichte.',
#  'neun',
#  'Anschließend wechselte er in die Werkstatt Cranachs nach Mechelen.',
#  'Gorki gab dem angehenden Schriftsteller den Rat, sich mehr Lebenserfahrung zu verschaffen.',
#  'Wie blöd muss man sein?',
#  'neun',
#  'Hast du noch eine Ersatzpatrone?',
#  'Die unabhängige Jury kann sich dabei auch gegen die Vergabe eines Prädikats entscheiden.',
#  'Vielleicht nimmt ja ein netter Nachbar mein Paket entgegen.',
#  'Dafür benötigen sie eine längere Zeit bis zur Sättigung.',
#  'Das Lied hat sie so sehr berührt, dass sie weinen musste.',
#  'Seine ersten vier Lebensjahre verbrachte er in seinem Geburtsort.',
#  'Außerdem gibt es ein Röhrenwerk und Betriebe der Bauwirtschaft.',
#  'Die Romane erschienen im Kelter Verlag.',
#  'Er ist verheiratet und hat fünf Kinder.',
#  'Kettenbriefe leite ich aus Prinzip nicht weiter.',
#  'Plaaz besitzt einen Bahnhof an den Bahnstrecken Rostock–Neustrelitz und Plaaz–Güstrow.',
#  'Des Deutschen Volkes Edelstein.',
#  'Das war im September letzten Jahres.',
#  'Diệm konnte zunächst fliehen, wurde jedoch von Suchtrupps aufgegriffen und ermordet.',
#  'Die Lehren des esoterischen Christentums und die Philosophie werden durch Fernkurse verbreitet.',
#  'Damit war der Krieg in Europa beendet.',
#  'Güngör ist verheiratet, hat ein Kind und wohnt in Bremen-Osterholz.',
#  'Johann Carl entstammte der österreichischen Adelsfamilie Khevenhüller.',
#  'Überdeutlich wird dies bei jeder Form von Gewalt in der Pflege.',
#  'ja',
#  'Gewerkschaften und Sozialdemokraten riefen erfolgreich zu großen Demonstrationen auf.',
#  'In geübter Hand sind die Risiken gering.',
#  'In Deutschland ist seine Verbreitung auf die Nordhälfte beschränkt.',
#  'Was nicht passt, wird passend gemacht.',
#  'Wegen Verstoßes gegen die Lizenzauflagen wurden dem Verein vier Punkte abgezogen.',
#  'Als Produzent',
#  'Deswegen ballert es mehr.',
#  'drei',
#  'Dies ist grundsätzlich zu begrüßen.',
#  'Die einzigartige Unterwasserwelt macht die Insel zu einem beliebten Ziel für Taucher.',
#  'In der Bevölkerung wurde es gut angenommen.',
#  'Die aristokratische Regierung musste dem Druck nachgeben und zurücktreten.',
#  'Ihr älterer Sohn, Jan Kiepura jun.',
#  'Conakry ist die Hauptstadt von Guinea.',
#  'Es sind kaum Gebrauchsspuren zu erkennen.',
#  'Wie wollt Ihr die Leute überzeugen, wenn Ihr selbst so unüberzeugt klingt?',
#  'Papperlapapp!, widersprach Elke.',
#  'Er war Ersatzmann für weitere Sojus-Missionen.',
#  'Da Mykoplasmen keine Zellwand haben, können sie nur auf speziellen Nährböden angezüchtet werden.',
#  'Linda führt ein Doppelleben.',
#  'Wie pumpt ein Baum das Wasser aus dem Boden in die Blätter?',
#  'Alles anzeigen.',
#  'Er starb wenige Wochen später.',
#  'Besonders berüchtigt für seine pyroklastischen Ströme ist der Unzen in Japan.',
#  'Die letzten Monate seiner Amtszeit waren von der Weltwirtschaftskrise überschattet.',
#  'Das neue Anti-Terror-Gesetz ist doch nur eine weitere Beschneidung unserer Grundrechte.',
#  'Zudem forschte er über die Stadtgeschichte von Warburg.',
#  'Der Fluss markiert die Grenze.',
#  'Der oft minderwertige Schnaps wurde in das angrenzende hessische Gebiet eingeschmuggelt.',
#  'Allein die Unterstützung der Völker stärkt es in seinem Ringen.',
#  'An dieser Stelle lichtet sich der Wald etwas.',
#  'Das Kaliwerk Zielitz ist das größte Kalibergwerk Deutschlands und eines der größten weltweit.',
#  'Minute für Jörgen Pettersson eingewechselt.',
#  'Zwei Täfelchen aus getriebenem Silber zeigen ihn als Krieger mit Schild und Speer.',
#  'Wieso, das ist doch prima!',
#  'Zuletzt betätigte er sich auch als politischer und Romanautor.',
#  'Deswegen haben wir Schutzvorkehrungen für jeden Fall getroffen.',
#  'Gegenwärtig werden Richtlinien ausgearbeitet.',
#  'Als Gastgeber ist Frankreich bereits qualifiziert.',
#  'Die Anlage ist in Privatbesitz und ständig bewohnt.',
#  'Schildern Sie das Vorgehen noch mal in eigenen Worten.',
#  'Zum Transport von Holz und anderen Gütern konnten die Leitern abgenommen werden.',
#  'Anders als sein Name vermuten lässt, lebt der Käfer hauptsächlich an Eichen.',
#  'Dennoch gibt es viele Gründe, die diesen Optimismus rechtfertigen.',
#  'Sie galt als politischer Gegner der Great Alliance.',
#  'Kurz nachdem die Räuber die Bank verlassen hatten, wurde die Polizei verständigt.',
#  'Hier steht das Konzept Cassirers der Theorie Adornos entgegen.',
#  'sechs',
#  'Hier liegt ein schwerwiegender Vorgang zugrunde, ein schwerwiegender politischer Fehler.',
#  'Angebaut werden insbesondere Zierpflanzen, Kartoffeln und Erdbeeren.',
#  'Alwin, Nadja und Andrea spielen Verstecken.',
#  'ja',
#  'Kennst du die Geschichte hinter diesem Song?',
#  'Geht das nicht auch ohne die schwarzen Balken?',
#  'Der gutaussehende und begabte Soldat ist bei seinen Kameraden wie auch den Vorgesetzten beliebt.',
#  'Die Augen liegen nicht seitlich, sondern nahezu auf der Oberseite der Larven.',
#  'Auch die Villages-Lagen sind sehr gut gemachte Weine.',
#  'Das geht nicht an.',
#  'Schon in Angola spielte Rafael Fußball.',
#  'Die Thermoplaste werden erhitzt, in ihre Form gebracht und wieder abgekühlt.',
#  'Hinzu kommt, dass die Fahrt jetzt vollkommen überdacht ist.',
#  'Gegensatz ist die Rückversicherung.',
#  'Versionsnummern sagen heutzutage nichts mehr aus.',
#  'Stagnierende Umsätze sind das Resultat.',
#  'Zugleich wurde der alte Name "Latina" wieder angenommen.',
#  'Die Schüler können jederzeit ohne Probleme ins Schweizer Schulsystem wechseln.',
#  'Er gilt als begabter Songwriter und Musiker.',
#  'sechs',
#  'Die Fruchtknoten sind kahl.',
#  'fünf',
#  'Stattdessen geht es in die Entwicklung von Medikamenten oder Therapien.',
#  'Der Bezirk gehört zu den am dichtesten verbauten Bezirken Wiens.',
#  'Er gehörte als Exklave zum Amt Bokeloh.',
#  'Akupunktur funktioniert nicht, wenn man nicht dran glaubt.',
#  'Auch aus eigener Erfahrung weiß ich, dass Vieles oft schief läuft.',
#  'Das spart Geschirr.',
#  'Was für ein Angeber, dachte Horst im Stillen.',
#  'Es hat ein oder mehrere voneinander und untereinander elektrisch isolierte Adernpaare.',
#  'Doch die kolumbianische Regierung blieb untätig.',
#  'drei',
#  'Er ist im Urnenhain Tolkewitz beigesetzt.',
#  'Dies ist nicht der Zweck der heutigen Debatte.',
#  'Sie würde es von anderen abhängig machen, ob sie kommt oder nicht.',
#  'Omi saß im Schaukelstuhl und strickte einen Pullover.',
#  'Ein Jahr später erhielt der Torwart einen Profivertrag, war aber nur Ersatzmann.',
#  'Mit letzterem Album war der Vertrag mit Epic erfüllt.',
#  'Der Bereitschaft der Behörden, diese Fälle aufzuklären, ist nur selten groß.',
#  'In der kurzen aber turbulenten Firmengeschichte ging es auf und ab.',
#  'Manche Menschen empfinden den Spiegelei-Effekt darüber hinaus als unästhetisch.',
#  'Seitdem firmiert das Unternehmen als Strategy& als eigenständiger Teil des PwC-Firmennetzwerkes.',
#  'Letzter deutscher Geistlicher war Pfarrer Arno Kopisch.',
#  'Sie werden zum Teil als Originale in der Literatur beschrieben.',
#  'Die Trainer sind Klaus und Gabi Bahr.',
#  'Er hat ihn im Schwitzkasten.',
#  'Es existiert auch der "Transport der Schiffe in einem wassergefüllten Trog"',
#  'Am Ende der Saison stand der direkte Wiederabstieg.',
#  'Der Sitz der Bundesarbeitsgemeinschaft ist Berlin.',
#  'Hersteller des Bootes war die Schweers-Werft in Bardenfleth.',
#  'Platz der Billboard Charts.',
#  'Alle vier Seiten waren beschriftet.',
#  'An der Bergstation gibt es ein Restaurant mit Bar und Aussichtsterrasse.',
#  'Mit der will er das ganze Land erobern.',
#  'Durch die Eintragung im Handelsregister entstehen Rechtsfolgen im Verkehr mit den eingetragenen Gesellschaften.',
#  'An jeder Seite liegt ein monumentales Tor mit seitlichen Ecktürmen.',
#  'Hei',
#  'Im Bevölkerungsschutz wurden und werden Mannschaftstransportwagen vielfältig eingesetzt.',
#  'Geh mir nicht auf den Keks.',
#  'sieben',
#  'Ich habe etwas Käse mitgebracht.',
#  'Ein Sieg würde sie an die Spitze der Tabelle katapultieren.',
#  'Sie entstanden wie das Tal selbst durch Erosion des weichen Felsens.',
#  'Aber der Petitionsausschuss kann noch mehr leisten.',
#  'Dessen Nachfolger John Robson ernannte Davie zum Attorney General.',
#  'nein',
#  'Deshalb würde ich einfach diese Schutzkappe überstülpen und gut ist.',
#  'Karl Eckermann war Mitglied im Hannoverschen Künstlerverein.',
#  '"Sie werden doch nicht etwa", setzte ich zum Protest an, doch es war bereits zu spät.',
#  'Wiener Gemeindebezirk Leopoldstadt.',
#  'Diesen musste er sich als Kritiker bei der "Berliner allgemeinen musikalischen Zeitung" verdienen.',
#  'Sein erster Studienort ist nicht bekannt, dürfte jedoch Leipzig gewesen sein.',
#  'Früher war die Kapazität deutlich größer.',
#  'Dieser Laser ist so stark, dass man damit Metall schneiden kann.',
#  'Hier war Burger bald wegen seiner Grausamkeit und seiner Willkür gefürchtet.',
#  'Erstrebt wird ein System ausgewogener checks and balances.',
#  'Das älteste bekannte Exemplar in der Wildnis ist mit fünf Jahren gestorben.',
#  'Diese Operation konnte aufgrund der geringen Distanz mit leichten Landungsbooten durchgeführt werden.',
#  'Fundamentreste sind aber noch vorhanden.',
#  'Thursday muss geduldig warten, bis die Aufhebung seiner Ausrottung „bestehen bleibt“.',
#  'Der Verwaltungsträger ist dabei eine juristische Person des öffentlichen Rechts oder des Privatrechts.',
#  'neun',
#  'Der ""floh!',
#  'The Coup ist bekannt für seine offen antikapitalistische Einstellung.',
#  'Der Einsatz weiterer Multicast-Protokolle ist daher unumgänglich.',
#  'Daher, schrieb er, sei es mit einer speziellen Technik möglich, sie sprechen zu lehren.',
#  'eins',
#  'Er zählt zu den bekanntesten mexikanischen Sängern.',
#  'Sehr viele Bürger im Osten sind konfessionslos.',
#  'Oberhalb der Einmündung des Steinbachs trägt er auch den Namen Mühlbach.',
#  'Er kehrte daraufhin wieder zu Lok Delitzsch in die drittklassige Bezirksliga zurück.',
#  'Die Autobahnabfahrt nach Kempten',
#  'Wer das sieht, der weiß, dass diesem Schiff großes Unglück geschehen wird.',
#  'Wie gefährlich sind E-Zigaretten?',
#  'Georg Talbot führte den Ehrentitel ""Geheimer Kommerzienrat.',
#  'Ich finde aber, dass wir das Problem im großen und ganzen gut gelöst haben.',
#  'Jugendliche aus anderen Orten waren dabei gern gesehene Gäste.',
#  'Dadurch gibt es auch einige größere Hotels und Kurhotels.',
#  'Suche Züge nach Düsseldorf.',
#  'Ist dies eine Anpassung an die Globalisierung?',
#  'Mit Tempomat wird mir immer so langweilig, dass ich nicht mehr richtig aufpasse.',
#  'ja',
#  'Königswarter Ehrenpreis“ verliehen.',
#  'Dylan sollte das Stück kürzen, was er ablehnte.',
#  'Dies waren die ersten Lokomotiven aus Mödling.',
#  'Der Ortsname leitet sich von einem gleichlautenden Flurnamen ab.',
#  'Seitdem betreibt Speckmann die Band von dort aus weiter.',
#  'Dort informierte ein preußischer Armeeangehöriger Schleinitz vom Kriegsausbruch.',
#  'zwei',
#  'Man sollte die Fragen also geschickt so formulieren, dass sie erwartungsgemäß bejaht werden.',
#  'Uwe holt die Fliegenklatsche.',
#  'Die Fahrt nach Köln konnte er sich nicht leisten',
#  'Bynum wechselte die High-School insgesamt drei Mal.',
#  'Direkt an der Autobahn zu tanken, ist teuer.',
#  'Beide Male mussten sie sich der Konkurrenz aus dem eigenen Land geschlagen geben.',
#  'Per Räuberleiter könnten wir es über die Mauer schaffen.',
#  'Jeder hat es gedacht, aber keiner traute sich, es zu verbalisieren.',
#  'Die Kassiererin kann den Barcode nicht finden.',
#  'Vorsichtig steigen sie durch die Dachluke.',
#  'Die Messtechnik ist in Verbindung mit Steuerungs- und Regelungstechnik eine Voraussetzung der Automatisierungstechnik.',
#  'Heute wird sie in den meisten Armeen nur noch bei Paraden getragen.',
#  'Außerdem scheut Coelho sich nicht, gleich zu Beginn einen Selbstbezug herzustellen.',
#  'Ebenso ist auch die Ortsverwaltung hier untergebracht.',
#  'Der Neuling sollte sich lieber warm anziehen.',
#  'Deshalb ist die flexible Anpassung der amtlichen Kontrollen an die Größe des Betriebes notwendig.',
#  'Fünf Jahre später wanderte er nach Schweden aus.',
#  'Aus seinem Rucksack nahm er einen Adapter von HDMI auf DVI.',
#  'Wir telefonieren später',
#  'ja',
#  'Es implementiert dazu nur einen Ausschnitt der Programmiersprache Java.',
#  'Azevedo wurde als Sohn eines Schreiners in einem nordportugiesischen Dorf geboren.',
#  'drei',
#  'Weitergehende Dokumente mit genaueren Daten sind jedoch nicht existent.',
#  'Über die Jahre wurden seine Verantwortungen immer umfangreicher.',
#  'Er hat sich außerdem um den sozialen Wohnungsbau in Heilbronn verdient gemacht.',
#  'Meine Arbeit endet hier.',
#  'In England ist sie lokal verbreitet.',
#  'nein',
#  'Platz und wurde zum Chefcoach befördert.',
#  'Zu Beginn der folgenden Saison gewann man den Superpokal.',
#  'Deshalb habe ich einen eigenen Gesetzentwurf geschrieben"".',
#  'Besonders auch historisch wertvoll sind seine Zyklen aus Prag und Paris.',
#  'Er kassierte das Tor, das dieses Spiel beendete.',
#  'Der Gerichtsmediziner Thomas Noguchi stufte den Fall als Unfalltod durch Ertrinken und Unterkühlung ein.',
#  'ja',
#  'In Reims ist eine Straße nach Halbwachs benannt.',
#  'Gegebenenfalls leiten sie Ratsuchende an Gynäkologen, Hebammen und andere Fachdienste weiter.',
#  'Aus finanziellen Gründen begann er später Unterhaltungsromane zu schreiben.',
#  'Dazu entstand eine Kriegsgräberstätte in der Ortsmitte.',
#  'Dennoch gelten die Begriffe heute auch mit Bezug auf einzelne Kunstwerke als weitgehend austauschbar.',
#  'eins',
#  'Auf der Brücke warteten der König und der Kronprinz.',
#  'Mein Aquarium muss mal wieder gereinigt werden.',
#  'Sein Gemälde ist in der National Gallery in London zu sehen.',
#  'Baker ist verheiratet und hat drei Kinder.',
#  'Die Touring-Version wurde allerdings nicht in Serie produziert.',
#  'Beide Systeme können also nur mit eingeschränkter Geschwindigkeit arbeiten.',
#  'Auch wenn mir die Kunden auf die Nerven gehen, muss ich Höflichkeit bewahren.',
#  'Man kann stattdessen auch Rapsöl oder Sonnenblumenöl nehmen.',
#  'Gleichzeitig erfolgte die Umbenennung des Schachtes Justus in "Wittekind".',
#  'vier',
#  'Ich habe Ihnen nochmals einen Brief geschrieben, aber keine Antwort erhalten.',
#  'Nach Kriegsende wurde der Ortskern neu aufgebaut.',
#  'ja',
#  'Es ist dann vielmehr ein Sammelsurium unkonkreter Aussagen ohne klare Leitlinien.',
#  'Das Abgeordnetenhaus kann die Regierung als Ganzes durch ein Misstrauensvotum zum Rücktritt zwingen.',
#  'Auch als Synchronsprecher war er aktiv.',
#  'Hier soll sich sein Schicksal erfüllen.',
#  'Ein weiter bekannter Enkel war der Rechtsanwalt Gustav Eduard Nolte.',
#  'Der nördliche Abschnitt wird mittels der S-Bahn vom Bahnhof Friedrichshagen erschlossen.',
#  'Es fehlt das gewisse Etwas.',
#  'Es war also nur Abbau von Diskriminierungen, nicht Besserstellung bezweckt.',
#  'Kann Spuren von Sellerie enthalten.',
#  'Produzent sämtlicher Folgen war Helmut Ringelmann.',
#  'nan',
#  'Sie halten die Zeit reif für ein Umdenken.',
#  'eins',
#  'Die Elbe fließt durch Dresden, Magdeburg und Hamburg und mündet in die Nordsee',
#  'Am Ende kommt es doch anders.',
#  'Dabei werden Bewusstsein und Schmerzempfindung ausgeschaltet.',
#  'Dort will Rau ein auf internationale Tourneen spezialisiertes „globales Volkstheater“ etablieren.',
#  'Er besuchte in Kiel die Oberrealschule, die heutige Max-Planck-Schule.',
#  'Nun möchte ich über die Datenerfassung sprechen.',
#  'Diese Dinge müssen in der Europäischen Union schneller koordiniert werden.',
#  'Am Freitag will die Geschäftsführung Bilanz ziehen.',
#  'Geh von der Couch, du fauler Hund!',
#  'An der Rennbahn gibt es eine eigene Haltestelle.',
#  'Die Insel liegt am nördlichen Ende der Bristol Bay am Eingang der Togiak Bay.',
#  'Diese Gemälde sind „von feiner Stimmung und großer poetischer Wirkung“.',
#  'Die erste Herrenmannschaft des Clubs spielt in der Baseball-Bundesliga.',
#  'Deshalb wird diese kompakte und stromsparende Methode nur bei Raumfahrtmissionen verwendet.',
#  'Die interaktive Installation ist in Karlsruhe im Zentrum für Kunst und Medientechnologie zu erfahren.',
#  'Die preußisch-sächsische Armee marschierte am Rande des Thüringer Waldes auf.',
#  'Hier waren Haken angebracht, an denen der Henker seine Arbeit vollzog.',
#  'Seine schriftstellerische Tätigkeit setzte er bis zu seinem Tode fort.',
#  'Er war Mitglied der Volkstanzgruppe Ostrołęka.',
#  'Also, lass uns mal lieber höher klettern.',
#  'Erfolgreichste Gruppe waren die Supremes.',
#  'Diese verbindet die Gemeinde im Norden mit Reutlingen und im Süden mit Riedlingen.',
#  'Ihr Weg führt durch ein bewaldetes Tal vorbei an der Ortschaft Gößl.',
#  'Es gibt fast keine Übersetzungen ins Deutsche.',
#  'Es müssen auch alle in die selbe Richtung ziehen.',
#  'Dennoch ist es notwendig, wie ich es sehe, diese Änderung vorzunehmen.',
#  'Mit diesem Club begannen seine sportlichen Erfolge.',
#  'Kurz darauf erschießt sich Tetley.',
#  'Während des dänisch-schwedischen Krieges war er als kaiserlicher Abgesandter in Kopenhagen.',
#  'neun',
#  'acht',
#  'Die Roadmap scheint uns zu lähmen.',
#  'Dann hätte Postumius auch gegen religiöse Vorschriften verstoßen.',
#  'Unter diesem Namen ist ein weiterer Sohn des Radjedef bekannt.',
#  'Im Sprachgebrauch und in der Literatur wurde es weiterhin zumeist einfach als Yoshiwara bezeichnet.',
#  'Woher haben Sie meine Nummer?',
#  'Als der Funkspruch einging, brach im Kontrollzentrum Hektik aus.',
#  'Die Geschichte der Ahrtalbahn beginnt als Zweigstrecke der linken Rheinstrecke.',
#  'Sie ist also ansteckend.',
#  'Nach einer Desensibilisierung kommt sie mit ihrem Heuschnupfen ganz gut zurecht.',
#  'Wo zum Henker sind wir?',
#  'Neu-Delhi ist die Hauptstadt von Indien.',
#  'Eigentlich war es eher ein Monolog.',
#  'Temperatur im Wohnzimmer um zwei Grad Celsius hochregeln.',
#  'Finden Sie das witzig?',
#  'Mit der Gründung der ""Hör Zu!',
#  'Die Gletscher hatten das weiche Gestein abgetragen und das harte Gestein blieb stehen.',
#  'Es herrscht ein Steppenklima, weshalb nebst Reben auch verschiedene Kakteenarten gedeihen.',
#  'Natürlich gibt es Probleme oder Unstimmigkeiten.',
#  'sechs',
#  'vier',
#  'Diese öffnen mit einem Monat die Augen und werden nach zwei Monaten entwöhnt.',
#  'Ein Großteil der Einwohner pendelt nach Lund und Malmö.',
#  'Das Bild der Gemeinde ist von Weiden, Wald, Obstbäumen und Weinbergen geprägt.',
#  'Dem Landgericht Arnsberg übergeordnet ist das Oberlandesgericht Hamm.',
#  'Conakry ist die Hauptstadt von Guinea.',
#  'Wieso warst du nicht auf meiner Beerdigung?',
#  'Er wurde zum Boss der russischen Mafia in New York.',
#  'Auch geflochtene Gürtel sind bekannt.',
#  'Gott sei Dank habe ich gerade noch die Kurve gekriegt.',
#  'Sie wird in Form von vier Zahlen geschrieben, die mit Punkten voneinander getrennt sind.',
#  'Sie war die Cousine von Carl Maria von Weber.',
#  'Er beschrieb Menschen aus dem bäuerlichen Milieu in moralischen und religiösen Grenzsituationen.',
#  'Zu so später Stunde sind die meisten Schüler nicht mehr besonders aufnahmefähig.',
#  'Die Winkelhalbierende unterteilt das Winkelfeld in zwei deckungsgleiche Teile.',
#  'Ja, Glenn ist wirklich eine Frostbeule.',
#  'Britta hat null Bock auf die bevorstehende Familienfeier.',
#  'Es existiert kein Harmonisierungsbedarf.',
#  'Obwohl aus der Ehe vier Kinder hervorgingen, verlief seine Ehe unglücklich.',
#  'An meiner rechten Pedale ist ein Reflektor abgebrochen.',
#  'Andreas anrufen.',
#  'Wie lange braucht man mit dem Fahrrad von Regensburg bis Ludwigsburg?',
#  'Ich war hier seit Jahren nicht mehr.',
#  'Das Unternehmen betreibt Bus- und Straßenbahnlinien.',
#  'Lassen Sie mich zunächst ein paar Worte zur Analyse selbst sagen.',
#  'Klettern hat auch viel mit Angstüberwindung zu tun.',
#  'Die vier Takte heißen ansaugen, verdichten, arbeiten und ausstoßen.',
#  'Unter Friedrich Karl erlebte Plön eine kulturelle Blüte.',
#  'Danach studierte er.',
#  'Bei solchen Operationen besteht aber immer die Gefahr von Blutverlusten.',
#  'Alte Dieselmotoren musste man mit einem Gasbrenner oder Ähnlichem vorglühen, wenn sie nicht ansprangen.',
#  'Ein besonderer Stellenwert kam bei ihm der Zeichnung zu.',
#  'Ohne entsprechende Einstellungen oder Vorgaben wirkt das Erscheinungsbild antiquiert.',
#  'Herr Rahn hat gekräuseltes Haar.',
#  'Richtig zubereitet schmeckt sogar Kohlrabi lecker.',
#  'Einstellungen anzeigen.',
#  'Das Überqueren dieser Brücke war kostenlos.',
#  'Später wechselte er als Referent ins Niedersächsische Kultusministerium.',
#  'Er schien betrunken zu sein.',
#  'acht',
#  'Hei',
#  'Firefox',
#  'zwei',
#  'Wir sind aber heute nicht hier, um eine sprachliche Angelegenheit zu lösen.',
#  'Dies ist es, worauf es ankommt!',
#  'Ihre größten Hits waren „Quo Vadis“, „Veni Vidi Vici“ und „Nostra Culpa“.',
#  'Gewalt und Terrorismus sind einfach nur Mittel zum Zweck.',
#  'Ausstellung über „Die Wikinger.',
#  'Die Einöde liegt inmitten eines Golfplatzes.',
#  'Erst die spätere gewählte Landesregierung verlegte den Regierungssitz wieder nach Bregenz.',
#  'Der Verein spielt momentan in der drittklassigen Campeonato Nacional de Seniores.',
#  'Das Lexikon des internationalen Films schrieb, der Film sei auf den Hauptdarsteller zugeschnitten.',
#  'Es gilt als eines der letzten „unberührten“ maritimen Ökosysteme.',
#  'Wolltest du schon immer mal deinen Computer nach der eigenen Pfeife tanzen lassen?',
#  'Der Ausschlag ist immer rechts neben dem Mund an der Wange.',
#  'In Silber eine ausgerissene grüne Staude mit fünf Blättern.',
#  'Im Gebr.',
#  'Darf ich mich auf deinen Schoß setzen?',
#  'Im Winter wird an Tankstellen Winterdiesel verkauft.',
#  'Wir wohnen zwar in Bochum, haben aber ein Ferienhaus im Sauerland, wo wir viele Wochenenden verbringen.',
#  'Horst und Ingo lasen abwechselnd die Fürbitten.',
#  'Später übernahmen die Herren von Burtscheid-Büllesheim die Pfandschaft.',
#  'Sie sind heute neben der Protestantischen Kirche ausgestellt.',
#  'Lassen Sie mich durch, ich bin Arzt!',
#  'Schöne Grüße von Bernhard!',
#  'Dabei können auch mehrere Profile eines gleichen Protokolls genutzt werden.',
#  'Diese erhielt dadurch ihren jetzigen Namen.',
#  'Aber letzten Endes müssen wir realistisch sein.',
#  'Das ist ebenfalls eine seriöse Organisation.',
#  'Der Film wurde nach Zerschlagung des Prager Frühlings verboten.',
#  'Die Serie wurde bei der Interopa Film in Berlin vertont.',
#  'Er konnte aber den Ort halten und die Angreifer schlagen.',
#  'Diese Bestimmungen müssen bei der Halbzeitbewertung der Fonds umgesetzt werden.',
#  'Elf Meilen vor der Küste ist ein Tanker auf Grund gelaufen.',
#  'Mandy spielt in ihrer Freizeit Saxophon.',
#  'Die kostenlose Brücke wurde von reichen Bürgern errichtet.',
#  'Wie lange ist der letzte Ölwechsel her?',
#  'Einen Ruf nach Dorpat hatte Claus abgelehnt.',
#  'Als Anna dem Jungen aber immer noch nicht glauben will, verlangt er einen Test.',
#  'zwei',
#  'vier',
#  'Im Ort gibt es einen Haltepunkt der Nahetalbahn.',
#  'Rostow gehörte zu den ältesten und wichtigen Burgen der Kiewer Rus.',
#  'Darauf kommt es an.',
#  'Das ist ein klassischer Fall von Gier frisst Hirn.',
#  'Die sieben Gebiete sind mehr als vorher speziell für die Software-Entwicklung definiert.',
#  'Meist besteht Fieber.',
#  'Sie machen ein Zeichen?',
#  'Einmal im Jahr sollte der Kleidschrank ausgemistet werden.',
#  'Irgendwie kommt er nicht in seine Schuhe rein.',
#  'Noch auf der Suche nach einem passenden Geschenk?',
#  'Der Name des Asteroiden ist abgeleitet von der finnischen Stadt Vaasa.',
#  'Die Behandlung erfolgt im Wesentlichen symptomatisch.',
#  'Wer braucht bei diesem Klima schon eine Sitzheizung?',
#  'Wie lange läuft die Waschmaschine noch?',
#  'Bei Löwenzahn wurde gezeigt, wie man aus einem Schuhkarton eine Lochkamera baut.',
#  'Es muss sich grundlegend etwas ändern.',
#  'Demnach würde es sich bei "Monachus" um ein paraphyletisches Taxon handeln.',
#  'Wir wissen auch, welche Probleme es in den Überwachungssystemen gegeben hat.',
#  'In der Gemeinde befindet sich ein Campus der Southern Leyte State University.',
#  'Nach dem Ende von ""Wer ist hier der Boss?',
#  'Hunderte Pumpen bilden mehrere Ringe um die Gruben.',
#  'Stilistisch zählt sie zum musikalischen Verismus.',
#  'Mehr Wirtschaftswachstum geht meist auch mit mehr Ressourcenverbrauch einher.',
#  'Wenn man mit dem Fernrohr gen Westen blickt, kann man es erkennen.',
#  'Sie hat archäologische Ausgrabungen in Italien und Ägypten geleitet oder daran teilgenommen.',
#  'Sie ist das zentrale Printmedium für die staatliche Informationspolitik.',
#  'Die Parkmöglichkeiten für Pkw sind in den nahe gelegenen Wohnstraßen sehr begrenzt.',
#  'Sein Lebenswerk wird von Armin Peter Faust äußerst anschaulich dargestellt.',
#  'fünf',
#  'eins',
#  'In dieser Zeit traf er zwölf Mal, darunter waren sechs Elfmeter.',
#  'Wolfurt gilt als typisches Straßendorf und erstreckt sich beidseitig der Hauptstraße in Richtung Dornbirn.',
#  'Das kann man durch solche Methoden.',
#  'Es geht hier nicht darum, wiederum nur die Straße in allen Bereichen zu verdammen.',
#  'Dementsprechend gibt es nur spärliche Informationen darüber.',
#  'Die Unternehmensgeschichte setzte sich unmittelbar nach dem Zweiten Weltkrieg fort.',
#  'Außerdem wurden zusätzliche Stützpfeiler eingezogen.',
#  'Später wurde die "Bremerton" nach San Diego verlegt.',
#  'Zudem will sie Pina nach Südamerika entführen.',
#  'Seither wechseln sich diese und die Labour Party in größeren Abständen ab.',
#  'Insgesamt gab es drei, wobei die beiden vorderen nicht hintereinander, sondern nebeneinander gesetzt waren.',
#  'Diese waren für Fische und Krebse bisher nahezu unüberwindbare künstliche Hindernisse.',
#  'Es gibt verschiedene Sportvereine.',
#  'Die Band beginnt nun auch eigene Stücke zu schreiben.',
#  'Liebe Ria!',
#  'Von dem Maler Hermann Bauch stammt ein Mosaik und ein Bleiglasfenster im Eingangsbereich.',
#  'Lassen Sie mich erklären, was es ist, und vor allem, was es nicht ist.',
#  'Ich glaube, wir sollten auch über die Erfolge der letzten Jahre sprechen.',
#  'Außerdem wurde ihm der ganze Körper mit warmen Wasser abgerieben.',
#  'Im Corriere della Sera finden sich ganze fünf Artikel zu diesem Großereignis.',
#  'Im Diagramm rechts sind drei Geräte eingezeichnet.',
#  'Das altgermanische Wort mhd.',
#  'Die Reisezeit beträgt zwei Minuten.',
#  'Bereits im März des Folgejahres wurde er zum Komusubi befördert.',
#  'Durch böse Geister hervorgerufene Krankheiten können mit dieser Zeremonie entkräftet werden.',
#  'Der Lake Zürich befindet sich im Lake County, das zur Metropolregion Chicago gehört.',
#  'Ich muss die DVD bis Donnerstag in die Videothek zurückbringen.',
#  'Aus Lärmschutzgründen hat man neben der Hauptverkehrsader einen Wall aufgeschüttet.',
#  'Die nachfolgende Sendung ist für Zuschauer unter sechzehn Jahren nicht geeignet.',
#  'Pubertät ist die Zeit, in der die Eltern schwierig werden.',
#  'Worte sind deshalb nicht genug!',
#  'Kleine Hilfsmittel werden gebaut, Abläufe besprochen, und eines Nachts schließlich beginnt der Einbruch.',
#  'Warum steht das Telefon nicht in seiner Ladestation?',
#  'Die Segel sind gesetzt.',
#  'Seltene Ausnahmen kommen aber vor.',
#  'Wendell Ford besuchte die öffentlichen Schulen im Daviess County.',
#  'Diese Endung bedeutet nichts weiter als „Dorf“.',
#  'Der Name ist ein Patronym und bedeutet "Sohn des Friðrik".',
#  'Sie ist gelblich, rötlich oder bräunlich gefärbt.',
#  'Umso größer ist ihre Beliebtheit in der Türkei.',
#  'Als Werkstoff ist Gold relativ wertlos.',
#  'Als er auf die Uhr sah, stellte Jan fest, dass er eine halbe Stunde mit dem Lesen der Kommentare verplempert hatte.',
#  'neun',
#  'sechs',
#  'Als die Polizei auftaucht, injiziert sich Nelson jedoch das Serum selber.',
#  'Schwerin schrieb wissenschaftliche Aufsätze unter anderem über die Gattungen ""Acer"" und "Sambucus".',
#  'Der Pazifik ist der größte Ozean der Welt.',
#  'So morsch, wie der Stamm ist, würde ich ihn lieber nicht als Lastenträger einsetzen.',
#  'Peter Graf von Lacy ist der bekannteste Vertreter dieser sogenannten „Wildgänse“.',
#  'Der erste Sohn Willi verstarb schon recht früh.',
#  'Die Wiederwahl gelang ihm zweimal.',
#  'Daraufhin floh die ganze Kolonie.',
#  'Ich leih mir ein Fahrrad beim Hotel, meinte sie.',
#  'Zum Grillen braucht man Ketchup oder Barbecue-Soße.',
#  'Darüber hinaus sind Machine Head seit jeher auch vom Hip Hop beeinflusst.',
#  'Sie stellte darüber hinaus ihre eigene Stellung in der Kunstszene ebenso radikal in Frage.',
#  'Während des Striptease läuft auf der rechten Bildhälfte der Abspann.',
#  'Er erlitt eine leichte Verwundung und wurde zuletzt zum Fahnenjunker befördert.',
#  'Firefox',
#  'ja',
#  'Eine Nanny sorgte für die ersten Schritte zur Kommunikation mit anderen Kindern.',
#  'Im Herbst sind sie ziemlich derb, grob und scharf gesägt.',
#  'Benannt wurde der Bodden nach dem auf Rügen liegenden Hauptort am Bodden Schaprode.',
#  'Der Verein wurde zu diesem Zeitpunkt aufgelöst.',
#  'Sie geht wie die erstmalige Verwendung der Sonnenuhr wahrscheinlich auf die Babylonier zurück.',
#  'Diese sind zum Teil vulkanischen Ursprungs.',
#  'Es heißt, sein Sohn Li Shimin habe ihm alle Arbeit abgenommen.',
#  'Ich habe mit Begeisterung für diesen Text gestimmt.',
#  'Originale von Levis Büchern erzielen heute im Handel dreistellige Beträge.',
#  'Von dort verläuft der Weg weiter in den Wald.',
#  'Ob man beides getrennt oder zusammen isst, ist egal.',
#  'Wer ist noch mal Klassensprecher?',
#  'Aber nun bloß nicht in eine Schockstarre verfallen!',
#  'Ja, ich komme ja schon!',
#  'Nebenbei arbeitete er als Aushilfskraft auf einer Farm.',
#  'Ein territorial größeres Europa wird nicht mit einem etatmäßig kleineren Europa erreicht.',
#  'Ihr Sohn kam durch künstliche Befruchtung zur Welt.',
#  'Die nachtaktiven Falter fliegen von Mitte Juli bis Mitte Oktober.',
#  'acht',
#  'fünf',
#  'Nutzer können ihre Lesezeichen online abspeichern, verwalten und mit anderen Nutzern teilen.',
#  'Die Don Bosco Kath.',
#  'Saul Bass zählt zu den innovativsten Designern und Filmemachern seiner Zeit.',
#  'In Grün über silbernem Wellenbalken eine silberne Eiche.',
#  'Weitere wichtige Industriezweige sind die Mikromechanik, Galvanoplastik, Metallbau und die Holzverarbeitung.',
#  'Über den Autor ist nichts bekannt, vermutlich stammte er aus dem deutschen Sprachgebiet.',
#  'Man steuert es mit einem Doppelpaddel.',
#  'Wir haben ein Problem auf OSI-Schicht acht.',
#  'Wir spielen immer noch, aber das Leben auf Tour ist derzeit nicht machbar.',
#  'Heute zeigt sich der größte Teil der Anlage als englischer Garten.',
#  'Seine Residenz nahm er in München, wo er auch starb.',
#  'Innerer und äußerer Narthex können als getrennte Teile eines Narthex auch gemeinsam vorkommen.',
#  'Dabei belegte er die Plätze vier und drei.',
#  'Kim Darby ist die Tochter zweier professioneller Tänzer.',
#  'Ich glaube, das führt nicht in die richtige Richtung.',
#  'Das ist eine extrem schlechte Richtlinie.',
#  'Herr Lurch entblößte sein hageres Gesicht.',
#  'Nur Carmen findet das unfair.',
#  'Ingeborg Krabbe hatte drei Geschwister.',
#  'Es kommt wirklich darauf an, dass solche Daten auf dieser Ebene erfasst werden.',
#  'Strumming hingegen ergibt ein harmonisches Pulsieren.',
#  'Bin ich zum Kauf einer Hypothek berechtigt?',
#  'Teheran ist die Hauptstadt vom Iran.',
#  'Kohlenhydrate sind besser als ihr Ruf.',
#  'Ohne die professionelle Unterstützung der Maserati-Rennabteilung waren diese Wagen der Konkurrenz nun doch unterlegen.',
#  'Sie diente zunächst als Unterkunft für belgische Besatzungstruppen.',
#  'Da müssen wir sprengen, meinte der Zahnarzt.',
#  'Außerdem spielte er beim Nachfolgeteam Newmarket Royals sowie beim Ligakonkurrenten London Knights.',
#  'Wie auch das Instant-Runoff-Voting erfüllt die Coombs-Wahl das Condorcet-Kriterium nicht.',
#  'Smith wuchs in Chicago auf.',
#  'Wir sind hier allein.',
#  'Dumm ist, wer etwas weiß, aber trotz des besseren Wissens falsch handelt.',
#  'Hauptthema der Show ist die Revanche für üble Streiche unter Freunden.',
#  'Gleichzeitig wurden Sportwetten teilweise verboten.',
#  'sieben',
#  'ja',
#  'Zudem versah er im Kloster lange Jahre die Ämter des Novizenmeisters und Prior.',
#  'Heidenhain entstammte einer Ärztefamilie.',
#  'acht',
#  'zwei',
#  'Ebenfalls in Auggen angesiedelt sind die Kelterei der Fa.',
#  'Diese steht auch für Absolventen einheimischer Schulen mit Deutschkenntnissen offen.',
#  'Also ich höre nichts.',
#  'Wie kann man sich schützen?',
#  'Nach fünf Monaten lag eine empfindlichere Platte als die bis dahin erhältlichen vor.',
#  'Ziel ist es, die Übereinstimmung eines Softwaresystems mit seiner Spezifikation zu überprüfen.',
#  'Mit einem warmen Getränk im Bauch lässt sich die Kälte besser aushalten.',
#  'Die Antivirensoftware ist amok gelaufen und hat alle Computer im Haus lahmgelegt.',
#  'Ihre Kloake ist in dieser Zeit kugelförmig.',
#  'Die Strecke beginnt im Süden Veronas und führt durch die Poebene Richtung Südosten.',
#  'Erst von dort konnte er seinen Weg frei fortsetzen.',
#  'Sie erhebt sich, heute immer noch gut erkennbar, aus dem Schwemmland heraus.',
#  'Die Kanarischen Inseln gehören zu Spanien.',
#  'Wissenschaftler haben diese Mutation bisher nur bei Frauen beobachtet.',
#  'Seine Geschäftsbeziehungen reichten bis Nordamerika und Asien.',
#  'Zahlreiche vordere Platzierungen bei Deutschen, Europa- und Weltmeisterschaften sowie Olympischen Spielen folgten.',
#  'In einer Tageszeitung blätternd sitzt Siegfried auf einer Parkbank.',
#  'Mit einem warmen Getränk im Bauch lässt sich die Kälte besser aushalten.',
#  'Folge dem Querverweis.',
#  'Ostern ist immer eine Woche nach dem ersten Vollmond im Frühling.',
#  'Im Mittelalter hatten wechselnde Herrschaften das Dorf inne.',
#  'Den Namen Ghibli tragen auch weitere Fahrzeuge von Maserati.',
#  'Du kannst mit dem Bus nach Frankfurt an der Oder fahren.',
#  'Mir doch egal.',
#  'Allerdings ergaben weitere Prüfungen, dass es mittelfristig keinen Bedarf für eine solche Autobahn gäbe.',
#  'Umgekehrt kann ein Freibrief eine Ausschreibung als Vogelfrei gemeint sein.',
#  'Bizarr-groteske Abschnitte zeigen Einflüsse durch Schostakowitsch.',
#  'Er war einer der Pioniere auf dem Gebiet der Nutzung der Sonnenenergie.',
#  'Auch wenn mir die Kunden auf die Nerven gehen, muss ich Höflichkeit bewahren.',
#  'Die Spülmaschine ist fertig.',
#  'In der archaischen Periode wurden erste Formen des Ackerbaus entwickelt.',
#  'Die Komödie sei besser als der erste Film.',
#  'Aktuell gilt folgender Modus.',
#  'Damit endet eine erfolgreiche internationale Bildungsarbeit vor allem im musisch-kulturellen Bereich.',
#  'Der Sohn eines Bergmanns begann seine Fußballkarriere bei den Sportfreunden Wanne-Eickel.',
#  'In diesem Jahr gab es sieben Nummer-eins-Singles und sechsunddreißig Nummer-eins-Alben.',
#  'Nordwestlich von Hackhausen befindet sich die Ortschaft Hackenbroich.',
#  'Im Ort Gnarrenburg gingen viele soziale Einrichtungen von Hermann Lamprecht und der Marienhütte aus.',
#  'Ich werde folglich den Rat über die im Parlament vorgetragenen Bedenken informieren.',
#  'Es wäre traurig gewesen, ein so wichtiges Thema nicht im Konsens verabschieden zu können.',
#  'Nach dessen Tod im gleichen Jahr kam es kurzfristig an andere Besitzer.',
#  'Kurz danach gab es einen Werbespot mit dem Cancan von Jacques Offenbach.',
#  'Das ist besser.',
#  'Wie sieht es mit Gleitzeit aus?',
#  'Nahe dem Dorf befindet sich auch der Grand Canyon National Park Airport.',
#  'Sie sollen verkünden, dass die Liebe den Tod besiegt hat.',
#  'Wart ihr schon einmal in dem Club?',
#  'Wo Rauch ist, ist auch Feuer.',
#  'Direkt von der Straße wurden sie von Alfred Biolek für seine Fernsehshow "Showbühne" engagiert.',
#  'Ein Jahr später wechselte er zu Health Net und er wurde erfolgreicher.',
#  'Er trat der Freimaurerloge "Lautaro" bei.',
#  'Mit „Fürst“ war eher die soziale als die rechtliche Rolle des so Bezeichneten gemeint.',
#  'Kennen Sie einen berühmten Chorsänger?',
#  'Die Gründung eines eigenen Instituts gelang nicht.',
#  'Auf den Scheiterhaufen mit diesem Ketzer!',
#  'Besser als gar nichts.',
#  'Im englischsprachigen Umfeld werden die Postleitzahlen korrekter als "Code" bezeichnet.',
#  'Sie greifen daher nicht in die bestehende Organisationsstruktur ein.',
#  'Unterschlupf fanden sie manchmal nur wenige Tage, in vielen Fällen aber auch monatelang.',
#  'Die Weidenutzung der Wälder wirkte sich noch schädlicher aus.',
#  'Hierin ist stets eine Gruppe Bewunderer vor der Büste von Delacroix versammelt.',
#  'Selbst Luxemburg hat mehr!',
#  'Im Kessel brodelte und blubberte eine giftgrüne Suppe.',
#  'Wieso tust du dir das an?',
#  'Noch versuchte Bürgermeister Anklam, den Aktivitäten der Nationalsozialisten in der Stadt Einhalt zu gebieten.',
#  'Er wird vor allem von Einheimischen am Wochenende frequentiert.',
#  'Hierfür ist ihm die Bindung der Staatsgewalt an die Grundrechte entscheidend gewesen.',
#  'Die unterschiedlichen Formen sind mit der "rubāb" verwandt, deren Verbreitungsschwerpunkt in Afghanistan liegt.',
#  'Der so genannte "Heinz-Lindner-Preis" wurde im Rahmen des Hessentages in Bad Arolsen überreicht.',
#  'Insgesamt kann man das Kalevala als sein "magnum opus" bezeichnen.',
#  'Darf ich mich auf deinen Schoß setzen?',
#  'Mit dem möchte ich nicht unbedingt auf Tuchfühlung gehen.',
#  'Da ist es dreckig.',
#  'Holzverbrennung muss nämlich als Kohlendioxidquelle auch verrechnet werden.',
#  'Hendrik Hering lebt auch heute noch in Hachenburg.',
#  'Zur Zeit der attischen Demokratie war die Ekklesia der oberste Souverän Athens.',
#  'Als Singles wurden die Lieder „Stricken“, „Just Stop“ und „Land of Confusion“ ausgekoppelt.',
#  'Ich muss hier zwei weitere Tatsachen erwähnen.',
#  'Also hat sich die heute Einundvierzig-Jährige umschulen lassen.',
#  'Sie hat die Aussage bloß auf ihren Kern zurückgeführt.',
#  'Hei',
#  'eins',
#  'Gut neun Prozent der Bevölkerung waren Analphabeten.',
#  'Für mich war dann klar, dass sie bereit sein würden, weiterzugehen.',
#  'Wann ist Sonnenaufgang in Fürth?',
#  'Ernie und Bert sind beste Freunde, aber sehr unterschiedlich.',
#  'Für seinen Einsatz in Nordafrika erhielt er mehrere italienische und deutsche Auszeichnungen.',
#  'Heute ist sie Torwart-Trainerin beim Frauen-Regionalligisten Sportfreunde Siegen.',
#  'Wussten Sie, dass ausgerechnet am Valentinstag die meisten Beziehungen zerbrechen?',
#  'Der Nachwuchs kommt blind auf die Welt.',
#  'Die deutsche Partnerstadt von Saint-Priest ist Mühlheim am Main bei Frankfurt am Main.',
#  'Bundesliga aufzusteigen.',
#  'Unser Kater hatte keinen Hunger, sondern wollte nur mit der Maus spielen.',
#  'Ich bin etwas skeptisch.',
#  'Diese Überwachung sollte ausdrücklich gegen Sozialdumping gerichtet sein.',
#  'Wie Kommissar Bolkestein in der gestrigen Sitzung erläuterte, bereitet uns diese Übermittlung Sorge.',
#  'Als Sühne versucht er seine Neigung mit finanziellen Wohltaten zu kompensieren.',
#  'Langenbach gehörte zum Rentamt München und zum Landgericht Kranzberg.',
#  'nein',
#  'nan',
#  'Eine Klimaanlage war für Marco reiner Luxus.',
#  'Hast du eine Ahnung, wie billig Zahnpasta ist?',
#  'Der Atlantische Ozean wird auch Atlantik genannt.',
#  'Der Schaden am Stoff kann zügig repariert werden.',
#  'Diese Cluster sind Kofaktoren für mehrere unentbehrliche Enzyme.',
#  'Die Auszeichnung wird teilweise als Ehre oder Preis verstanden.',
#  'Wir betrachten hier als Beispiel eine Kreisbahn.',
#  'Im Ort gibt es zwei Kirchen und ein Herrenhaus.',
#  'Die Sammlung wird ständig erweitert und restaurierte Geräte mit erläuternden Hintergrundinformationen im Wechsel ausgestellt.',
#  'Die Braut trug am Hochzeitstag die Tracht, die ihr am Vorabend angelegt worden war.',
#  'Sie ist mittlerweile verheiratet und man sieht ihren Sohn im Zimmer spielen.',
#  'Er soll gleichzeitig den ersten Jakobsweg, den "Camino Primitivo" eröffnet haben.',
#  'Dort kam er nur fünfmal zum Einsatz.',
#  'Tschechoslowakische Liga aufstieg.',
#  'Während dieser Zeit erhielt er auch von Jaki Byard und Herb Pomeroy privaten Unterricht.',
#  'Der Begriff leitet sich vom griech.',
#  'Eine Speicherung von E-Mails ist nicht vorgesehen.',
#  'Die genaue Unfallursache konnte dem Vernehmen nach nie ermittelt werden.',
#  'An diesem Grundsatz halten wir fest, und das wissen auch die Mitgliedstaaten.',
#  'Beides ist gleichermaßen unbefriedigend.',
#  'Die Siedlung selbst ist völlig autofrei.',
#  'Dieser brachte ihm auch das Lesen bei.',
#  'Daneben hat er vor allem Kammermusikwerke geschrieben, unter denen zehn Streichquartette hervorheben sind.',
#  'In Celle verwaltete er das Finanzressort.',
#  'Er ist lobenswert und sollte angenommen werden.',
#  'Sie wurden nacheinander im Verlauf mehrerer Jahre getötet oder lebendig begraben.',
#  'Eine interaktive Landkarte ist online verfügbar.',
#  'Sie jagen mit Pfeil und Bogen auf Wildschweine, Reptilien und Vögel.',
#  'Ohne die geostationären Satelliten kommt das System nicht aus.',
#  'Mercedes ist eigentlich ein weiblicher Vorname.',
#  'Auf diesen Moment hat unser Haus lange Zeit gewartet und hingearbeitet.',
#  'Wenn das Klopapier ausverkauft ist, kaufe ich stattdessen eine Bildzeitung.',
#  'Kurt Dietrich, Otto Heinrich und Hans Georg aus dem Winckel sind seine jüngeren Brüder.',
#  'Sein Bruder Dick führte das Ölgeschäft weiter.',
#  'zwei',
#  'neun',
#  'Die Gemeinde verfügt über einen Kindergarten, eine Grundschule und eine weiterführende Schule.',
#  'Wechselnd tauchen Nebendarsteller auf und verschwinden wieder.',
#  'nein',
#  'ja',
#  'So kam es in der Vergangenheit dort immer wieder zu Protesten und staatlichen Repressalien.',
#  'Monsheim liegt an der Pfrimm im südlichen Wonnegau in Rheinhessen.',
#  'Daher möchte ich, dass diese wohlbekannten Akzente auch finanziell gut versehen sind.',
#  'Sie folgt damit der Klassifikation des Aarne-Thompson-Index.',
#  'Mir ist der Appetit vergangen.',
#  'Gaborone ist die Hauptstadt von Botswana.',
#  'Über eine schlechte Vergütung kann ich mich jedenfalls nicht beklagen.',
#  'Es kommt auf die Inhaltsstoffe an.',
#  'Die bekannteste Farm war im Besitz von David Strawbridge, der ihr den Namen Castle Shanahan gab.',
#  'Die Bezeichnung „Nalgene“ ist ein eingetragenes Warenzeichen.',
#  'Dadurch ist der Unterlauf nicht schiffbar.',
#  'Robert vergibt ihr, doch Mrs.',
#  'Eine schnelle psychosoziale Unterstützung reagiert als eine Psychosoziale Notfallversorgung auf akute Ereignisse.',
#  'Bei den Präsidentschaftswahlen hatte Palmer aber keine Chance.',
#  'Viele wurden später erneut aufgelegt.',
#  'Diese wurden in älteren Normen als "Typen" bezeichnet.',
#  'Drei Monate nach dem Rücktritt ließ er sich erneut von Jassir Arafat berufen.',
#  'Auch im Free Jazz findet die Inside-Outside-Improvisation immer wieder Anwendung.',
#  'Diese wurde im Zweiten Weltkrieg vollständig vertrieben oder ausgelöscht.',
#  'Die Schneide ist typischerweise aus gehärtetem Stahl.',
#  'acht',
#  'eins',
#  'Weiterhin führte er die erste Volkszählung in Navarra durch.',
#  'Ein Wanderweg führt durch die Schlucht zum Gipfel des Großen Falkensteins.',
#  'Seine Rede kann man nur als zynisch bezeichnen.',
#  'Kreissägen und Bohrmaschinen sollten nie mit Handschuhen bedient werden.',
#  'Wie war es für Teenies in den Sechzigern?',
#  'Zu schneller Reichtum kann den Charakter zerstören.',
#  'Alle fünf starben während ihrer Rückkehr.',
#  'Unordnung auf großen Skalen.',
#  'Hierbei nimmt die Farbintensität mit sinkendem Eisengehalt ab.',
#  'Sein erster Musiklehrer mit Liedern aus der Sprache und Literatur Paschtu war Jafar.',
#  'Sind Sie erstens nicht auch der Meinung, dass Herr Heaton-Harris Betrügern grünes Licht gibt?',
#  'Sie wird damit eine der ersten und vielleicht bekanntesten Performance-Künstlerinnen der Schweiz.',
#  'Ich denke nicht, dass die Wand so bemalt werden sollte.',
#  'Emil wohnt in der Usedomer Straße.',
#  'Er erhält eine Kopie der Rechnung zur Kenntnisnahme.',
#  'Alle Arbeiten zur Wartung konnte die Besatzung ohne fremde Hilfe durchführen.',
#  'Überdies verfasste er eine Reihe von lateinischen Lebensbeschreibungen der Augsburger Bürgermeister.',
#  'Später stieg er zum Leiter der Behörde auf.',
#  'Dann sind wir bereit, mit Ihnen alles durchzufechten.',
#  'Das ist ein Forum, in dem alle die Minderheiten betreffenden Fragen erörtert werden können.',
#  'Paris ist die Hauptstadt von Frankreich.',
#  'Der Atlantische Ozean bedeckt insgesamt etwa ein Fünftel der Erdoberfläche.',
#  'Diesen Zickenkrieg ertrage ich nicht länger, platzte es dem Vater heraus.',
#  'Ich will gar nicht wissen, was in seinem Kopfkino gerade abgeht.',
#  'Haben wir Puderzucker auf Vorrat?',
#  'Johanna liegt mit einer Magen-Darm-Erkrankung flach.',
#  'Hast du dir das Kennzeichen ausgesucht oder wurde es zugeteilt?',
#  'Zu viele Goldsucher seien von dort oben nicht zurückgekommen.',
#  'Alter Falter, das hat mir gerade noch gefehlt.',
#  'Und so geht es im Gänsemarsch bis zum Ärmelkanal.',
#  'Meine zweite Anmerkung betrifft die Länder.',
#  'Ihre Pilotprojekte wären ein guter Anfang.',
#  'Firefox',
#  'fünf',
#  'Dort vertreibt er die synthetisch erzeugten Lebensmittel aus seiner Fabrik.',
#  'Sie war Teil der Baltischen Flotte.',
#  'Er war in einigen Bereichen der Regierung tätig.',
#  'Im Südwesten grenzt Epping Forest an Greater London.',
#  'Sein Thron wird von zwei Elefanten getragen.',
#  'Selbst Fachautoren verwenden die Wörter „Umgangsformen“ und „Etikette“ häufig bedeutungsgleich.',
#  'Zweitens gibt es keine Möglichkeit, bei einer übergeordneten Instanz Berufung einzulegen.',
#  'Vor Ort befindet sich zudem der Kreuzweg Burrweiler.',
#  'Als Student an der Universität Wien wurde er Mitglied des österreichischen Cartellverbandes.',
#  'Ian Carr würdigte ihn als selten talentierten Komponisten und Arrangeur sowie als charismatischen Bigband-Leiter.',
#  'Dann kann ich jetzt ja die Wäsche aufhängen.',
#  'Am deutlichsten merkt man den Dopplereffekt, wenn ein Einsatzwagen mit Sirene an einem vorbeifährt.',
#  'Den darauffolgenden Strafstoß parierte er sogar.',
#  'In einer Variante des Antriebs drehen sich zwei Propeller innerhalb eines Kragens gegeneinander.',
#  'Dann erscheint der Geist seines Vaters, den er ebenfalls verachtet.',
#  'Der Flughafen kann nur privat angeflogen werden.',
#  'Als Kind wollte ich immer erwachsen sein.',
#  'Das sind düstere Aussichten.',
#  'Ein Wassertropfen fällt von dem Wasserspeier auf ihn.',
#  'In seinen Stücken übernahm er häufig auch die Hauptrolle auf der Theaterbühne.',
#  'In Goldbach liegt der Hund begraben.',
#  'Der Konzern fürchtet um seine Reputation.',
#  'Besonders prägte ihn aber Django Reinhardt.',
#  'Die Geschichte von Salzburg war immer auf das Engste mit der Salzgewinnung verbunden.',
#  'Heute heißt diese Einrichtung Landesbetrieb Information und Technik Nordrhein-Westfalen.',
#  'Auf dem Markt durchsetzen konnte sich das System nicht.',
#  'Eine weitere Variante ist die gleichzeitige orale und anale Penetration.',
#  'Im Normalfall werden zwei bis drei Jungtiere geboren.',
#  'Hier fehlt jedoch die für eine Kapitulation erforderliche Besetzung und Entwaffnung.',
#  'Die Station Niederursel liegt im alten Ortskern des Stadtteils.',
#  'Ihr eigenes Instrument ist die Gitarre.',
#  'Deswegen sind in der Regel in der Teilungserklärung mehrere Verteilungsschlüssel festgelegt.',
#  'Hierbei handelt es sich um einen Freizeit- und Vergnügungspark mit etlichen Karussells und Kiosken.',
#  'Akademische Institut für Kirchenmusik zu Berlin.',
#  'Ist das offensichtlich oder bedarf es einer Erläuterung?',
#  '"Das kann kein Dauerzustand sein", stellte ein Sprecher vor laufenden Kameras klar.',
#  'In unmittelbarer Nähe der Siedlung lag das Wrack der "Maud".',
#  'Zusätzlich dient dieses Gewicht dann auch dem Fahrkomfort und der Laufruhe des Schleppers.',
#  'Kannst du mir halbwegs folgen?',
#  'Da gibt es nichts zu beschönigen.',
#  'Die Autobahnabfahrt nach Kempten',
#  'Der Saunabereich ist textilfreie Zone.',
#  'Zuflüsse sind nur Gräben aus den Wiesen der nahen Umgebung.',
#  'Alle in Frankreich geltenden Gesetze wurden eingeführt.',
#  'Der übliche Unfallhergang ist ein Sturz, der mit der Hand abgefangen wird.',
#  'Der Claim der Station ist «Die beste Musik».',
#  'Sie sind die eindrucksvollsten Klippen der South Downs in Sussex im Süden Englands.',
#  'Auf dem Fußballplatz war er als harter, aber technisch versierter Verteidiger bekannt.',
#  'In seinen zehn Jahren als Extraordinarius beschäftigte sich Kaegi vor allem mit dem Altgriechischen.',
#  'Das Original befindet sich heute im Teylers Museum der niederländischen Stadt Haarlem.',
#  'Acht Jahre später hatte die "Stadtverkehr GmbH" das Busnetz auf sechs Linien ausgebaut.',
#  'In seiner Karriere nahm er an zwei Weltmeisterschaften teil.',
#  'Da Dafydd diese Angriffe nicht dulden konnte, kam es zu Grenzkonflikten.',
#  'Als nächster Punkt folgt die Debatte zu den fünf Entschließungsanträgen zum Iran.',
#  'Wolfgang Philipps: ""Vergangenheit und Zukunft.',
#  'Ich glaube, dass eine präventive und dauerhafte Sicherheitspolitik damit nicht vereinbar ist.',
#  'In Berlin war er Mitglied der Freimaurerloge „Pythagoras zum flammenden Stern“.',
#  'Wir alle sind die Erben dieses großen Europäers Jean Monnet.',
#  'Mit der gemeinsamen Währung werden wir nicht nur die Integration vertiefen.',
#  'Wir verstehen das.',
#  'Trotzdem versucht Max weiter, seinem Vater zu helfen.',
#  'In den Planungsregionen sind jeweils mehrere Kreise zusammengefasst.',
#  'sieben',
#  'sechs',
#  'Damaskus ist die Hauptstadt von Syrien.',
#  'Was kommt heute Abend im Fernsehen?',
#  'Anlässlich seiner Heirat trat er vom lutherischen zum orthodoxen Glauben über.',
#  'Der Grund für das Sinken des Bootes wurde nie bekannt.',
#  'Von seinen Lebensdaten ist nichts bekannt.',
#  'Sie arbeiten in ihren jeweiligen Fachgebieten eng mit in der Lehre eingesetzten Lehrbeauftragten zusammen.',
#  'Ohne sie hätten wir diese Arbeit nicht bewerkstelligen können.',
#  'Wohl eher unter deren Reparatur, sozusagen, denn es gibt heute bereits eine Verbindung.',
#  'Abu Dhabi ist die Hauptstadt der Vereinigten Arabischen Emirate.',
#  'Der Zug kam dreizehn Minuten zu spät.',
#  'Gibt es in Mainz eine Straßenbahn?',
#  'Oh Gott, ein Monster!',
#  'Dies ist in meinen Augen ein Fehler.',
#  'Allerdings haben sie für den von Elmar Brok eingereichten Entschließungsantrag votiert.',
#  'ja',
#  'sechs',
#  'Hans Rampf wuchs im niederbayerischen Laberweinting auf, wo er eine Ausbildung zum Bäcker absolvierte.',
#  'Der Großteil der Bevölkerung sind Kurden.',
#  ...]

# %%
tokenized_sentences = []
segmentss = []
space = tokenizer.IdToPiece(5)

# specifically for zh-CN
# pattern = ",|\?|・|\u3002|\uff1f|\uff01|\uff0c|\u3001|\uff1b|\uff1a|\u201c|\u201d|\u2018|\u2019|\uff08|\uff09|\u300a|\u300b|\u3008|\u3009|\u3010|\u3011|\u300e|\u300f|\u300c|\u300d|\ufe43|\ufe44|\u3014|\u3015|\u2026|\u2014|\uff5e|\ufe4f|\uffe5" + punctuation
# for sent in sentences:
#     tokens = tokenizer.EncodeAsPieces(sent)
#     segments = []
#     for idx, token in enumerate(tokens):
#         if token != space and token not in pattern:
#             segments.append((idx, idx))
#     tokenized_sentence = []
#     for seg in segments:
#         tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

#     segmentss.append(segments)
#     tokenized_sentences.append(tokenized_sentence)

# for other languages
for sent in tqdm(sentences):
    tokens = tokenizer.EncodeAsPieces(sent)
    segments = []
    last = -1
    for idx, token in enumerate(tokens):
        if token.startswith(space) or token in punctuation:
            if last != -1 and last <= idx - 1:
                segments.append((last, idx - 1))
            last = idx + (token in punctuation)
    if last < len(tokens):
        segments.append((last, len(tokens) - 1))

    tokenized_sentence = []
    for seg in segments:
        tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

    tokenized_sentences.append(tokenized_sentence)
    segmentss.append(segments)
# Out:
# 100%|██████████| 765790/765790 [00:21<00:00, 35349.43it/s]

# %%
tokenized_sentences
# Out:
# [['Zieht', 'euch', 'bitte', 'draußen', 'die', 'Schuhe', 'aus'],
#  ['Es', 'gibt', 'auch', 'mehrere', 'Campingplätze'],
#  ['Es', 'kommt', 'zum', 'Showdown', 'in', 'Gstaad'],
#  ['Ihre',
#   'Fotostrecken',
#   'erschienen',
#   'in',
#   'Modemagazinen',
#   'wie',
#   'der',
#   'Vogue',
#   'Harper’s',
#   'Bazaar',
#   'und',
#   'Marie',
#   'Claire'],
#  ['Aber',
#   'weißt',
#   'du',
#   'wer',
#   'den',
#   'Stein',
#   'wirklich',
#   'ins',
#   'Rollen',
#   'gebracht',
#   'hat'],
#  ['Felipe',
#   'hat',
#   'eine',
#   'auch',
#   'für',
#   'Monarchen',
#   'ungewöhnlich',
#   'lange',
#   'Titelliste'],
#  ['Was', 'solls', 'ich', 'bin', 'bereit'],
#  ['Sein',
#   'Atelier',
#   'diente',
#   'nebenher',
#   'zur',
#   'Tarnung',
#   'unerlaubter',
#   'politischer',
#   'Aktivitäten'],
#  ['Das',
#   'Internet',
#   'besteht',
#   'aus',
#   'vielen',
#   'Computern',
#   'die',
#   'miteinander',
#   'verbunden',
#   'sind'],
#  ['Jörg',
#   'van',
#   'Essen',
#   'ist',
#   'stets',
#   'über',
#   'die',
#   'Landesliste',
#   'Nordrhein',
#   'Westfalen',
#   'in',
#   'den',
#   'Deutschen',
#   'Bundestag',
#   'eingezogen'],
#  ['Der',
#   'Uranus',
#   'ist',
#   'der',
#   'siebente',
#   'Planet',
#   'in',
#   'unserem',
#   'Sonnensystem'],
#  ['Sie', 'gewannen', 'das', 'Match', 'mit', 'sechs', 'Löchern', 'Vorsprung'],
#  ['Die',
#   'Wagen',
#   'erhielten',
#   'ein',
#   'einheitliches',
#   'Erscheinungsbild',
#   'in',
#   'weiß',
#   'mit',
#   'rotem',
#   'Fensterband'],
#  ['Seinen',
#   'Vornamen',
#   'erhielt',
#   'er',
#   'in',
#   'Gedenken',
#   'an',
#   'seinen',
#   'früh',
#   'verstorbenen',
#   'Onkel'],
#  ['Mit',
#   'den',
#   'Senators',
#   'nahm',
#   'er',
#   'an',
#   'drei',
#   'All',
#   'Star',
#   'Spielen',
#   'teil'],
#  ['Vorher', 'und', 'danach', 'war', 'der', 'Löwe', 'im', 'Wappen'],
#  ['Insgesamt', 'ist', 'der', 'Sound', 'etwas', 'zu', 'basslastig'],
#  ['Wie', 'ist', 'die', 'derzeitige', 'Verkehrssituation'],
#  ['Vielleicht',
#   'können',
#   'Sie',
#   'uns',
#   'diese',
#   'Frage',
#   'am',
#   'Ende',
#   'der',
#   'Aussprache',
#   'beantworten'],
#  ['Dieses', 'Maß', 'wird', 'in', 'Zoll', 'angegeben'],
#  ['Aus',
#   'den',
#   'Prozessakten',
#   'der',
#   'Hexenverfolgung',
#   'sind',
#   'keine',
#   'authentischen',
#   'Rezepte',
#   'bekannt'],
#  ['Ein',
#   'großer',
#   'Teil',
#   'der',
#   'Conciergerie',
#   'wird',
#   'heute',
#   'für',
#   'die',
#   'Pariser',
#   'Gerichte',
#   'genutzt'],
#  ['Weshalb', 'möchtest', 'du', 'nach', 'Bergheim'],
#  ['Auflage', 'des', 'Wettbewerbes'],
#  ['Eislutscher', 'sind', 'viel', 'leckerer', 'als', 'Eistüten'],
#  ['Seit', 'ihrem', 'achten', 'Lebensjahr', 'bekam', 'sie', 'Tanzunterricht'],
#  ['Wenn',
#   'nicht',
#   'dann',
#   'legt',
#   'man',
#   'sie',
#   'irgendwo',
#   'hin',
#   'wo',
#   'Platz',
#   'ist'],
#  ['Der',
#   'Innenraum',
#   'trägt',
#   'eine',
#   'flache',
#   'Holzdecke',
#   'an',
#   'der',
#   'Nord',
#   'und',
#   'Westwand',
#   'sind',
#   'Emporen',
#   'angebracht'],
#  ['Vier',
#   'Jahre',
#   'später',
#   'erlitt',
#   'sein',
#   'Vater',
#   'einen',
#   'Jagdunfall',
#   'der',
#   'ihn',
#   'arbeitsunfähig',
#   'machte'],
#  ['Durch',
#   'Bestrahlen',
#   'kann',
#   'eine',
#   'Kontamination',
#   'der',
#   'Nahrung',
#   'verhindert',
#   'werden'],
#  ['Ich', 'hätte', 'Sie', 'nicht', 'bestehen', 'lassen'],
#  ['Insbesondere', 'keine', 'Topflappen'],
#  ['Wir', 'werden', 'in', 'diese', 'Debatte', 'nicht', 'erneut', 'eintreten'],
#  ['Im',
#   'Winter',
#   'wird',
#   'Rugby',
#   'Union',
#   'gespielt',
#   'im',
#   'Sommer',
#   'Cricket'],
#  ['Es', 'gibt', 'vier', 'Staubblätter'],
#  ['Die',
#   'bundesdeutsche',
#   'Anti',
#   'Atom',
#   'Bewegung',
#   'erlebte',
#   'in',
#   'Brokdorf',
#   'ihren',
#   'unaufhaltsamen',
#   'Aufstieg',
#   'und',
#   'ihre',
#   'größten',
#   'Niederlagen'],
#  ['Ein',
#   'unbekannter',
#   'Tatverdächtiger',
#   'wird',
#   'in',
#   'seinem',
#   'Wagen',
#   'verfolgt'],
#  ['fünf'],
#  ['Die',
#   'Pfarrkirche',
#   'des',
#   'Ortes',
#   'war',
#   'dem',
#   'Heiligen',
#   'Martin',
#   'gewidmet'],
#  ['Das', 'Publikum', 'fordert', 'lautstark', 'eine', 'Zugabe'],
#  ['Daneben',
#   'veröffentlichte',
#   'er',
#   'mehrere',
#   'Bücher',
#   'über',
#   'den',
#   'Bau',
#   'und',
#   'die',
#   'Konstruktion',
#   'von',
#   'Dampflokomotiven'],
#  ['Es',
#   'ist',
#   'die',
#   'höchste',
#   'Anzahl',
#   'von',
#   'Eukaryoten',
#   'die',
#   'bisher',
#   'bei',
#   'den',
#   'Faultieren',
#   'beobachtet',
#   'wurde'],
#  ['„Dann',
#   'kann',
#   'er',
#   'jetzt',
#   'vergnügt',
#   'sein',
#   'und',
#   'schnell',
#   'laufen“,',
#   'sagte',
#   'Tante',
#   'Dahlia',
#   'lebhaft'],
#  ['Müller', 'geboren'],
#  ['Sie',
#   'liegt',
#   'im',
#   'Osten',
#   'des',
#   'Landes',
#   'an',
#   'der',
#   'Grenze',
#   'zu',
#   'Tansania'],
#  ['Zu',
#   'seinen',
#   'weiteren',
#   'Aufgaben',
#   'gehört',
#   'die',
#   'Abnahme',
#   'von',
#   'neu',
#   'eingekauften',
#   'oder',
#   'geleasten',
#   'Flugzeugen'],
#  ['Der', 'Standesbeamte', 'war', 'ein', 'komischer', 'Vogel'],
#  ['Das', 'kann', 'nicht', 'gehen'],
#  ['Ähnlich',
#   'gefärbte',
#   'Ziegen',
#   'kommen',
#   'auch',
#   'im',
#   'Piemont',
#   'und',
#   'im',
#   'Hochsavoyen',
#   'der',
#   'französischen',
#   'Alpen',
#   'vor'],
#  ['Sie',
#   'trugen',
#   'alle',
#   'sowjetische',
#   'Hoheitszeichen',
#   'als',
#   'sie',
#   'per',
#   'Bahn',
#   'im',
#   'Reich',
#   'eintrafen'],
#  ['Meine', 'Lieblingsfarbe', 'ist', 'schwarz', 'sagte', 'Lola'],
#  ['Nach',
#   'dem',
#   'Verlust',
#   'dieser',
#   'Funktion',
#   'beschäftigten',
#   'sich',
#   'die',
#   'Einwohner',
#   'hauptsächlich',
#   'mit',
#   'Landwirtschaft'],
#  ['Sie', 'wurde', 'nach', 'der', 'Stadt', 'Boise', 'in', 'Idaho', 'benannt'],
#  ['Er',
#   'arbeitete',
#   'anschließend',
#   'am',
#   'Brookhaven',
#   'National',
#   'Laboratory'],
#  ['Macht', 'euch', 'nur', 'darüber', 'lustig'],
#  ['Abschließend',
#   'möchte',
#   'ich',
#   'Ihnen',
#   'gerne',
#   'etwas',
#   'sehr',
#   'Wichtiges',
#   'mitteilen'],
#  ['Dieses',
#   'Rittergut',
#   'wird',
#   'heute',
#   'für',
#   'private',
#   'Wohnzwecke',
#   'genutzt'],
#  ['Als',
#   'staatlicher',
#   'Feiertag',
#   'gilt',
#   'er',
#   'für',
#   'staatliche',
#   'Angestellte',
#   'und',
#   'Beamte'],
#  ['Sowohl',
#   'Thomas',
#   'Howard',
#   'als',
#   'auch',
#   'Margaret',
#   'Douglas',
#   'wurden',
#   'im',
#   'Tower',
#   'of',
#   'London',
#   'gefangen',
#   'gesetzt'],
#  ['Sein', 'Sohn', 'war', 'der', 'Politiker', 'Hartwig', 'von', 'Rheden'],
#  ['Wie', 'ist', 'die', 'derzeitige', 'Verkehrssituation'],
#  ['Hiernach',
#   'war',
#   'er',
#   'Hofmeister',
#   'des',
#   'jungen',
#   'Herrn',
#   'von',
#   'Wilmersdorf'],
#  ['Die', 'Uhr', 'geht', 'falsch'],
#  ['Legislaturperiode',
#   'des',
#   'türkischen',
#   'Parlamentes',
#   'war',
#   'er',
#   'Abgeordneter'],
#  ['Doch',
#   'wie',
#   'sich',
#   'gerade',
#   'zeigt',
#   'ist',
#   'das',
#   'Thema',
#   'aktueller',
#   'denn',
#   'je'],
#  ['acht'],
#  ['Mit',
#   'sechs',
#   'Jahren',
#   'hatte',
#   'Judy',
#   'Weiss',
#   'ihre',
#   'ersten',
#   'Klavierstunden'],
#  ['Während',
#   'der',
#   'Streife',
#   'hatten',
#   'Buffy',
#   'und',
#   'Angel',
#   'einen',
#   'Streit'],
#  ['Katarina',
#   'Srebotnik',
#   'und',
#   'Nenad',
#   'Zimonjić',
#   'waren',
#   'die',
#   'Titelverteidiger'],
#  ['Polnische',
#   'Armee',
#   'sich',
#   'westlich',
#   'der',
#   'Weichsel',
#   'Brückenköpfe',
#   'erkämpften'],
#  ['Sie', 'sind', 'heute', 'noch', 'in', 'Kraft'],
#  ['Der',
#   'Tunnel',
#   'ist',
#   'der',
#   'längste',
#   'dieser',
#   'Eisenbahnstrecke',
#   'und',
#   'bildet',
#   'mit',
#   'den',
#   'zweithöchsten',
#   'Punkt'],
#  ['Später',
#   'übernahm',
#   'die',
#   'Stadt',
#   'Heilbronn',
#   'dies',
#   'als',
#   'offiziellen',
#   'Namen'],
#  ['Der', 'Datenschutz', 'ist', 'gewährleistet'],
#  ['Die',
#   'Frühjahrstagung',
#   'des',
#   'Rates',
#   'hat',
#   'das',
#   'unter',
#   'Beweis',
#   'gestellt'],
#  ['Aus',
#   'dieser',
#   'Ehe',
#   'stammt',
#   'die',
#   'Schauspielerin',
#   'und',
#   'Sängerin',
#   'Laura',
#   'Schneiderhan'],
#  ['Laut',
#   'Clamp',
#   'dienen',
#   'diese',
#   'beiden',
#   'Manga',
#   'dazu',
#   'das',
#   'gesamte',
#   'Clamp',
#   'Universum',
#   'zu',
#   'verbinden'],
#  ['Sie', 'ist', 'eine', 'agile', 'gute', 'Schwimmerin'],
#  ['Unter', 'der', 'Plane', 'wächst', 'nichts'],
#  ['Messe', 'in', 'der', 'Kapelle', 'an', 'allen', 'Festtagen', 'gestattet'],
#  ['drei'],
#  ['Nach',
#   'zwei',
#   'Auftritten',
#   'als',
#   'Gastdarsteller',
#   'in',
#   'der',
#   'Sitcom',
#   'Wer',
#   'ist',
#   'hier',
#   'der',
#   'Boss'],
#  ['Leider', 'ist', 'der', 'Rat', 'hier', 'nicht', 'mehr', 'vertreten'],
#  ['Das',
#   'Land',
#   'musste',
#   'neu',
#   'aufgebaut',
#   'werden',
#   'und',
#   'brauchte',
#   'gebildete',
#   'junge',
#   'Menschen'],
#  ['Ach', 'du', 'Schreck'],
#  ['Hilf', 'mir', 'mal'],
#  ['Der', 'Strahl', 'wird', 'in', 'kleinste', 'Partikel', 'zerstäubt'],
#  ['Vor',
#   'der',
#   'Kirche',
#   'befindet',
#   'sich',
#   'ein',
#   'Taufstein',
#   'in',
#   'den',
#   'Menschendarstellungen',
#   'und',
#   'Symbole',
#   'eingearbeitet',
#   'sind'],
#  ['Die',
#   'Frau',
#   'von',
#   'Justice',
#   'Wilhelmina',
#   'wird',
#   'in',
#   'den',
#   'Filmen',
#   'oft',
#   'erwähnt',
#   'aber',
#   'nie',
#   'gezeigt'],
#  ['Ein',
#   'altes',
#   'Backhaus',
#   'ist',
#   'auch',
#   'heute',
#   'noch',
#   'in',
#   'Betrieb',
#   'und',
#   'Mittelpunkt',
#   'des',
#   'Ortsteiles'],
#  ['Die', 'Sache', 'hat', 'allerdings', 'einen', 'Haken'],
#  ['Louise',
#   'd’Aumont',
#   'entstammte',
#   'einer',
#   'der',
#   'reichsten',
#   'Familien',
#   'Frankreichs'],
#  ['Wie', 'lange', 'ist', 'der', 'letzte', 'Ölwechsel', 'her'],
#  ['Keine', 'Ahnung'],
#  ['Auch',
#   'die',
#   'am',
#   'Platz',
#   'liegende',
#   'Kindertagesstätte',
#   'trägt',
#   'den',
#   'Namen',
#   'der',
#   'beiden',
#   'Kinder'],
#  ['Zwei', 'Softball', 'Spieler', 'versuchen', 'einen', 'Ball', 'zu', 'fangen'],
#  ['Abflussrohre',
#   'sollte',
#   'man',
#   'verschließen',
#   'damit',
#   'der',
#   'Geruch',
#   'der',
#   'Kanalisation',
#   'nicht',
#   'in',
#   'die',
#   'Wohnung',
#   'steigt'],
#  ['Ja', 'gut', 'da', 'kann', 'man', 'nichts', 'machen'],
#  ['Eine',
#   'Nebenstelle',
#   'des',
#   'Rathauses',
#   'ist',
#   'in',
#   '"Cavaliere',
#   'eingerichtet'],
#  ['Bei',
#   'Siebmacher',
#   'ist',
#   'der',
#   'Wappenschild',
#   'waagrecht',
#   'geteilt',
#   'in',
#   'Silber',
#   'und',
#   'Schwarz'],
#  ['Das', 'Attentat', 'war', 'stümperhaft', 'geplant'],
#  ['vier'],
#  ['Er',
#   'ist',
#   'Mitglied',
#   'des',
#   'Landesvorstands',
#   'im',
#   '"Team',
#   'Stronach',
#   'für',
#   'Steiermark".'],
#  ['Sie',
#   'wurde',
#   'nach',
#   'Plänen',
#   'des',
#   'Architekten',
#   'Paul',
#   'Hoppe',
#   'errichtet'],
#  ['Diese',
#   'Körper',
#   'werden',
#   'als',
#   'ein',
#   'Bauteil',
#   'montiert',
#   "'Phase",
#   'Plug',
#   'genannt'],
#  ['Rang', 'im', 'Norden'],
#  ['Dabei',
#   'durfte',
#   'die',
#   'historische',
#   'Fassade',
#   'nicht',
#   'beschädigt',
#   'werden'],
#  ['Haben', 'wir', 'noch', 'genügend', 'Rohstoffe'],
#  ['Der',
#   'Empfänger',
#   'erhält',
#   'also',
#   'ein',
#   'möglicherweise',
#   'verändertes',
#   'Wort'],
#  ['Das',
#   'Fachwissen',
#   'sollte',
#   'in',
#   'Westeuropa',
#   'nicht',
#   'mehr',
#   'interessant',
#   'sein'],
#  ['Bezug',
#   'auf',
#   'diesen',
#   'Text',
#   'nimmt',
#   'beispielsweise',
#   'der',
#   'stadtplanerische',
#   'Entwurf',
#   'von',
#   'Karlsruhe'],
#  ['Daher',
#   'verpasste',
#   'er',
#   'den',
#   'Saisonauftakt',
#   'und',
#   'kehrte',
#   'erst',
#   'Ende',
#   'März',
#   'zurück',
#   'ins',
#   'Training'],
#  ['Ich',
#   'möchte',
#   'ferner',
#   'hinzufügen',
#   'dass',
#   'unsere',
#   'Hersteller',
#   'in',
#   'diesem',
#   'Bereich',
#   'Weltspitze',
#   'sind'],
#  ['Da', 'muss', 'ein', 'rasches', 'Vorgehen', 'geplant', 'werden'],
#  ['Er',
#   'entthronte',
#   'seinen',
#   'Halbbruder',
#   'und',
#   'setzte',
#   'ihn',
#   'gefangen',
#   'anschließend',
#   'ermordete',
#   'er',
#   'Peter',
#   'eigenhändig'],
#  ['Gründer', 'und', 'Geschäftsführer', 'ist', 'Paul', 'Grau'],
#  ['Zum',
#   'zweiten',
#   'möchte',
#   'ich',
#   'einige',
#   'Worte',
#   'an',
#   'die',
#   'Kommission',
#   'richten'],
#  ['Herr', 'Rahn', 'hat', 'gekräuseltes', 'Haar'],
#  ['neun'],
#  ['In', 'den', 'Umkleiden', 'gibt', 'es', 'Spinde'],
#  ['Auf', 'Vereinsebene', 'gewann', 'er', 'drei', 'deutsche', 'Meistertitel'],
#  ['Klasse',
#   'aus',
#   'einem',
#   'Spiel',
#   'zwischen',
#   'diesen',
#   'beiden',
#   'Klubs',
#   'bestand'],
#  ['Hauptaugenmerk',
#   'lag',
#   'zunächst',
#   'auf',
#   'der',
#   'Schaffung',
#   'von',
#   'effizienteren',
#   'Produktionsbedingungen'],
#  ['Der', 'schmale', 'Anbau', 'im', 'Westen', 'hatte', 'ein', 'Giebeldach'],
#  ['Hast', 'du', 'dein', 'Ticket', 'nach', 'Görlitz', 'schon', 'gebucht'],
#  ['Da', 'wird', 'Rebecca', 'sich', 'aber', 'freuen'],
#  ['Es',
#   'entstand',
#   'dadurch',
#   'das',
#   'Gefühl',
#   'dass',
#   'die',
#   'Gerechtigkeit',
#   'niemals',
#   'siegen',
#   'könne'],
#  ['In',
#   'Kontakt',
#   'mit',
#   'anderen',
#   'Menschen',
#   'zu',
#   'bleiben',
#   'senkt',
#   'das',
#   'Risiko',
#   'an',
#   'Demenz',
#   'zu',
#   'erkranken'],
#  ['So',
#   'entschloss',
#   'er',
#   'sich',
#   'nach',
#   'einer',
#   'Auseinandersetzung',
#   'mit',
#   'einem',
#   'Vorgesetzten',
#   'aus',
#   'dem',
#   'Militärdienst',
#   'auszuscheiden'],
#  ['Er',
#   'wurde',
#   'Mitglied',
#   'des',
#   'Heilbronner',
#   'Künstlerbundes',
#   'und',
#   'malte',
#   'gemeinsam',
#   'mit',
#   'Wilhelm',
#   'Schäffer'],
#  ['Zugleich',
#   'werden',
#   'von',
#   'der',
#   'Steuerung',
#   'automatisch',
#   'und',
#   'der',
#   'Fahrweise',
#   'angepasst',
#   'Gas',
#   'und',
#   'Kupplung',
#   'bedient'],
#  ['Die',
#   'junge',
#   'Polizistin',
#   'machte',
#   'den',
#   'Eindruck',
#   'als',
#   'müsste',
#   'sie',
#   'sich',
#   'vor',
#   'ihren',
#   'älteren',
#   'Kollegen',
#   'erst',
#   'noch',
#   'beweisen'],
#  ['Das', 'wird', 'auch', 'geschehen'],
#  ['Du',
#   'benutzt',
#   'ständig',
#   'irgendwelche',
#   'Redewendungen',
#   'die',
#   'ich',
#   'nicht',
#   'kenne'],
#  ['Noch',
#   'im',
#   'Bademantel',
#   'schlurfte',
#   'er',
#   'zum',
#   'Kühlschrank',
#   'und',
#   'griff',
#   'sich',
#   'einen',
#   'Jogurt'],
#  ['Das',
#   'kann',
#   'man',
#   'auch',
#   'einfach',
#   'mit',
#   'einem',
#   'scharfen',
#   'Messer',
#   'machen'],
#  ['Die',
#   'Partei',
#   'war',
#   'damit',
#   'zwar',
#   'gerettet',
#   'doch',
#   'wurde',
#   'die',
#   'Parteiführung',
#   'anschließend',
#   'verhaftet'],
#  ['Er', 'erkrankte', 'zudem', 'an', 'Kinderlähmung'],
#  ['Dieser', 'Anblick', 'zog', 'zahlreiche', 'Neugierige', 'an'],
#  ['In',
#   'diesen',
#   'drei',
#   'Action',
#   'Filmen',
#   'werden',
#   'Themen',
#   'des',
#   'modernen',
#   'organisierten',
#   'Verbrechens',
#   'behandelt'],
#  ['Fördern',
#   'bedeutet',
#   'natürlich',
#   'auch',
#   'immer',
#   'eine',
#   'gewisse',
#   'finanzielle',
#   'Unterstützung'],
#  ['Was', 'hat', 'sich', 'darüber', 'hinaus', 'verändert'],
#  ['Der',
#   'Entwurf',
#   'verfehlte',
#   'dennoch',
#   'die',
#   'notwendige',
#   'Zweidrittelmehrheit'],
#  ['Die',
#   'internationale',
#   'Politik',
#   'vermochte',
#   'erst',
#   'in',
#   'der',
#   'Weimarer',
#   'Republik',
#   'kleine',
#   'Zugeständnisse',
#   'aushandeln'],
#  ['So', 'viel', 'Tiefgründigkeit', 'traue', 'ich', 'denen', 'nicht', 'zu'],
#  ['Noch',
#   'im',
#   'Jahrzehnt',
#   'seines',
#   'Todesjahres',
#   'entstanden',
#   'zwei',
#   'hagiographische',
#   'Lebensbeschreibungen',
#   'Bardos'],
#  ['nan'],
#  ['Aufgrund',
#   'der',
#   'zerklüfteten',
#   'Küstenlinien',
#   'Rügens',
#   'waren',
#   'die',
#   'Umwege',
#   'sonst',
#   'erheblich'],
#  ['Über',
#   'beide',
#   'Kanäle',
#   'steigt',
#   'dadurch',
#   'ein',
#   'Teil',
#   'der',
#   'Schmelze',
#   'bis',
#   'in',
#   'das',
#   'Gefäß',
#   'auf'],
#  ['Die',
#   'Linie',
#   'wurde',
#   'später',
#   'von',
#   'der',
#   'Union',
#   'Pacific',
#   'Railroad',
#   'übernommen'],
#  ['Dazu',
#   'gehören',
#   'ein',
#   'Wetterdienst',
#   'sowie',
#   'Informationen',
#   'zum',
#   'Seegang',
#   'und',
#   'zum',
#   'Schiffsverkehr',
#   'in',
#   'engen',
#   'Passagen'],
#  ['Der',
#   'Burgstall',
#   'wird',
#   'im',
#   'Westen',
#   'durch',
#   'den',
#   'Steilhang',
#   'geschützt'],
#  ['Die',
#   'Lösungen',
#   'können',
#   'nur',
#   'dann',
#   'eine',
#   'Wirkung',
#   'erzielen',
#   'wenn',
#   'sie',
#   'miteinander',
#   'verknüpft',
#   'werden'],
#  ['Mir', 'ist', 'der', 'Appetit', 'vergangen'],
#  ['Ein', 'Wal', 'ist', 'gestrandet'],
#  ['Die', 'Strichfarbe', 'ist', 'weiß'],
#  ['Soweit', 'zu', 'dieser', 'Sache'],
#  ['Es',
#   'ist',
#   'bedauerlich',
#   'wie',
#   'viele',
#   'Kinder',
#   'beim',
#   'Laternenumzug',
#   'nur',
#   'noch',
#   'LED',
#   'Laternen',
#   'tragen',
#   'dürfen'],
#  ['Dort',
#   'existiert',
#   'ein',
#   'Vulkan',
#   'der',
#   'Kahlberg',
#   'der',
#   'kurz',
#   'vor',
#   'dem',
#   'Ausbruch',
#   'steht'],
#  ['Die',
#   'Reaktion',
#   'von',
#   'weißem',
#   'Phosphor',
#   'mit',
#   'Sauerstoff',
#   'ist',
#   'stark',
#   'exotherm'],
#  ['Drittens', 'die', 'wichtige', 'Frage', 'der', 'Einwanderung'],
#  ['Dieses',
#   'Abkommen',
#   'tritt',
#   'mit',
#   'seiner',
#   'Unterschrift',
#   'in',
#   'Kraft'],
#  ['Leonie',
#   'und',
#   'Paul',
#   'streiten',
#   'sich',
#   'darum',
#   'wer',
#   'als',
#   'erstes',
#   'auf',
#   'das',
#   'Schaukelpferd',
#   'darf'],
#  ['Wäre', 'das', 'eine', 'geeignete', 'Kodierung', 'oder', 'eher', 'nicht'],
#  ['Ich', 'bin', 'sehr', 'gespannt'],
#  ['Dies',
#   'waren',
#   'schwierige',
#   'Jahren',
#   'mit',
#   'zahlreichen',
#   'Herausforderungen'],
#  ['Ich',
#   'denke',
#   'die',
#   'maltesische',
#   'Bevölkerung',
#   'sollte',
#   'selbst',
#   'entscheiden',
#   'ob',
#   'Malta',
#   'beitreten',
#   'will',
#   'oder',
#   'nicht'],
#  ['So', 'gesehen', 'kann', 'er', 'nur', 'unausgereift', 'sein'],
#  ['Im',
#   'Personenverkehr',
#   'diente',
#   'die',
#   'Strecke',
#   'vornehmlich',
#   'lokalen',
#   'Interessen'],
#  ['Anna', 'weißt', 'du', 'wo', 'Charlotte', 'ist'],
#  ['ja'],
#  ['sechs'],
#  ['In', 'Österreich', 'ist', 'ebenfalls', 'die', 'U', 'Schreibung', 'üblich'],
#  ['Haben', 'wir', 'noch', 'Nudeln'],
#  ['Der',
#   'ebenfalls',
#   'abgebildete',
#   'Ochse',
#   'soll',
#   'auf',
#   'die',
#   'Gründungslegende',
#   'der',
#   'Kapelle',
#   'Bezug',
#   'nehmen'],
#  ['Aber', 'wie'],
#  ['Die',
#   'Stadt',
#   'Aachen',
#   'verteilt',
#   'bereits',
#   'vorsorglich',
#   'Jodtabletten'],
#  ['Alle', 'Mitgliedstaaten', 'profitieren', 'direkt', 'oder', 'indirekt'],
#  ['Der',
#   'Pfarrhof',
#   'war',
#   'von',
#   'da',
#   'an',
#   'von',
#   'Weltgeistlichen',
#   'bewohnt'],
#  ['acht'],
#  ['Konstantinopel',
#   'war',
#   'die',
#   'Hauptstadt',
#   'des',
#   'Byzantinischen',
#   'Reichs'],
#  ['Sie', 'muss', 'Folge', 'leisten'],
#  ['Der',
#   'Ladenbesitzer',
#   'ist',
#   'überrascht',
#   'und',
#   'verärgert',
#   'und',
#   'bringt',
#   'diese',
#   'Gefühle',
#   'zum',
#   'Ausdruck',
#   'indem',
#   'er',
#   '„Hey!“',
#   'sagt'],
#  ['Ab', 'jetzt', 'noch', 'achtundvierzig', 'Stunden'],
#  ['Daran',
#   'sollten',
#   'wir',
#   'uns',
#   'auch',
#   'heute',
#   'immer',
#   'wieder',
#   'erinnern'],
#  ['Das',
#   'beinhaltet',
#   'Dinge',
#   'wie',
#   'Essen',
#   'Schreiben',
#   'Zähne',
#   'Putzen',
#   'Rasieren',
#   'Kämmen',
#   'und',
#   'Sich',
#   'Waschen'],
#  ['Diese',
#   'Aneignung',
#   'vollzieht',
#   'sich',
#   'vielfach',
#   'auf',
#   'der',
#   'Grundlage',
#   'eingeführter',
#   'esoterischer',
#   'Vorstellungen'],
#  ['Die',
#   'größten',
#   'Städte',
#   'Englands',
#   'sind',
#   'London',
#   'Birmingham',
#   'und',
#   'Manchester'],
#  ['Ursprünglich',
#   'war',
#   'der',
#   'Ort',
#   'nur',
#   'eine',
#   'Alm',
#   'und',
#   'nur',
#   'im',
#   'Sommer',
#   'bewohnt'],
#  ['nan'],
#  ['Die',
#   'Küche',
#   'der',
#   'Stadt',
#   'Livorno',
#   'bietet',
#   'vor',
#   'allem',
#   'Fischgerichte'],
#  ['neun'],
#  ['Anschließend',
#   'wechselte',
#   'er',
#   'in',
#   'die',
#   'Werkstatt',
#   'Cranachs',
#   'nach',
#   'Mechelen'],
#  ['Gorki',
#   'gab',
#   'dem',
#   'angehenden',
#   'Schriftsteller',
#   'den',
#   'Rat',
#   'sich',
#   'mehr',
#   'Lebenserfahrung',
#   'zu',
#   'verschaffen'],
#  ['Wie', 'blöd', 'muss', 'man', 'sein'],
#  ['neun'],
#  ['Hast', 'du', 'noch', 'eine', 'Ersatzpatrone'],
#  ['Die',
#   'unabhängige',
#   'Jury',
#   'kann',
#   'sich',
#   'dabei',
#   'auch',
#   'gegen',
#   'die',
#   'Vergabe',
#   'eines',
#   'Prädikats',
#   'entscheiden'],
#  ['Vielleicht',
#   'nimmt',
#   'ja',
#   'ein',
#   'netter',
#   'Nachbar',
#   'mein',
#   'Paket',
#   'entgegen'],
#  ['Dafür',
#   'benötigen',
#   'sie',
#   'eine',
#   'längere',
#   'Zeit',
#   'bis',
#   'zur',
#   'Sättigung'],
#  ['Das',
#   'Lied',
#   'hat',
#   'sie',
#   'so',
#   'sehr',
#   'berührt',
#   'dass',
#   'sie',
#   'weinen',
#   'musste'],
#  ['Seine',
#   'ersten',
#   'vier',
#   'Lebensjahre',
#   'verbrachte',
#   'er',
#   'in',
#   'seinem',
#   'Geburtsort'],
#  ['Außerdem',
#   'gibt',
#   'es',
#   'ein',
#   'Röhrenwerk',
#   'und',
#   'Betriebe',
#   'der',
#   'Bauwirtschaft'],
#  ['Die', 'Romane', 'erschienen', 'im', 'Kelter', 'Verlag'],
#  ['Er', 'ist', 'verheiratet', 'und', 'hat', 'fünf', 'Kinder'],
#  ['Kettenbriefe', 'leite', 'ich', 'aus', 'Prinzip', 'nicht', 'weiter'],
#  ['Plaaz',
#   'besitzt',
#   'einen',
#   'Bahnhof',
#   'an',
#   'den',
#   'Bahnstrecken',
#   'Rostock–Neustrelitz',
#   'und',
#   'Plaaz–Güstrow'],
#  ['Des', 'Deutschen', 'Volkes', 'Edelstein'],
#  ['Das', 'war', 'im', 'September', 'letzten', 'Jahres'],
#  ['Diệm',
#   'konnte',
#   'zunächst',
#   'fliehen',
#   'wurde',
#   'jedoch',
#   'von',
#   'Suchtrupps',
#   'aufgegriffen',
#   'und',
#   'ermordet'],
#  ['Die',
#   'Lehren',
#   'des',
#   'esoterischen',
#   'Christentums',
#   'und',
#   'die',
#   'Philosophie',
#   'werden',
#   'durch',
#   'Fernkurse',
#   'verbreitet'],
#  ['Damit', 'war', 'der', 'Krieg', 'in', 'Europa', 'beendet'],
#  ['Güngör',
#   'ist',
#   'verheiratet',
#   'hat',
#   'ein',
#   'Kind',
#   'und',
#   'wohnt',
#   'in',
#   'Bremen',
#   'Osterholz'],
#  ['Johann',
#   'Carl',
#   'entstammte',
#   'der',
#   'österreichischen',
#   'Adelsfamilie',
#   'Khevenhüller'],
#  ['Überdeutlich',
#   'wird',
#   'dies',
#   'bei',
#   'jeder',
#   'Form',
#   'von',
#   'Gewalt',
#   'in',
#   'der',
#   'Pflege'],
#  ['ja'],
#  ['Gewerkschaften',
#   'und',
#   'Sozialdemokraten',
#   'riefen',
#   'erfolgreich',
#   'zu',
#   'großen',
#   'Demonstrationen',
#   'auf'],
#  ['In', 'geübter', 'Hand', 'sind', 'die', 'Risiken', 'gering'],
#  ['In',
#   'Deutschland',
#   'ist',
#   'seine',
#   'Verbreitung',
#   'auf',
#   'die',
#   'Nordhälfte',
#   'beschränkt'],
#  ['Was', 'nicht', 'passt', 'wird', 'passend', 'gemacht'],
#  ['Wegen',
#   'Verstoßes',
#   'gegen',
#   'die',
#   'Lizenzauflagen',
#   'wurden',
#   'dem',
#   'Verein',
#   'vier',
#   'Punkte',
#   'abgezogen'],
#  ['Als', 'Produzent'],
#  ['Deswegen', 'ballert', 'es', 'mehr'],
#  ['drei'],
#  ['Dies', 'ist', 'grundsätzlich', 'zu', 'begrüßen'],
#  ['Die',
#   'einzigartige',
#   'Unterwasserwelt',
#   'macht',
#   'die',
#   'Insel',
#   'zu',
#   'einem',
#   'beliebten',
#   'Ziel',
#   'für',
#   'Taucher'],
#  ['In', 'der', 'Bevölkerung', 'wurde', 'es', 'gut', 'angenommen'],
#  ['Die',
#   'aristokratische',
#   'Regierung',
#   'musste',
#   'dem',
#   'Druck',
#   'nachgeben',
#   'und',
#   'zurücktreten'],
#  ['Ihr', 'älterer', 'Sohn', 'Jan', 'Kiepura', 'jun'],
#  ['Conakry', 'ist', 'die', 'Hauptstadt', 'von', 'Guinea'],
#  ['Es', 'sind', 'kaum', 'Gebrauchsspuren', 'zu', 'erkennen'],
#  ['Wie',
#   'wollt',
#   'Ihr',
#   'die',
#   'Leute',
#   'überzeugen',
#   'wenn',
#   'Ihr',
#   'selbst',
#   'so',
#   'unüberzeugt',
#   'klingt'],
#  ['Papperlapapp', 'widersprach', 'Elke'],
#  ['Er', 'war', 'Ersatzmann', 'für', 'weitere', 'Sojus', 'Missionen'],
#  ['Da',
#   'Mykoplasmen',
#   'keine',
#   'Zellwand',
#   'haben',
#   'können',
#   'sie',
#   'nur',
#   'auf',
#   'speziellen',
#   'Nährböden',
#   'angezüchtet',
#   'werden'],
#  ['Linda', 'führt', 'ein', 'Doppelleben'],
#  ['Wie',
#   'pumpt',
#   'ein',
#   'Baum',
#   'das',
#   'Wasser',
#   'aus',
#   'dem',
#   'Boden',
#   'in',
#   'die',
#   'Blätter'],
#  ['Alles', 'anzeigen'],
#  ['Er', 'starb', 'wenige', 'Wochen', 'später'],
#  ['Besonders',
#   'berüchtigt',
#   'für',
#   'seine',
#   'pyroklastischen',
#   'Ströme',
#   'ist',
#   'der',
#   'Unzen',
#   'in',
#   'Japan'],
#  ['Die',
#   'letzten',
#   'Monate',
#   'seiner',
#   'Amtszeit',
#   'waren',
#   'von',
#   'der',
#   'Weltwirtschaftskrise',
#   'überschattet'],
#  ['Das',
#   'neue',
#   'Anti',
#   'Terror',
#   'Gesetz',
#   'ist',
#   'doch',
#   'nur',
#   'eine',
#   'weitere',
#   'Beschneidung',
#   'unserer',
#   'Grundrechte'],
#  ['Zudem',
#   'forschte',
#   'er',
#   'über',
#   'die',
#   'Stadtgeschichte',
#   'von',
#   'Warburg'],
#  ['Der', 'Fluss', 'markiert', 'die', 'Grenze'],
#  ['Der',
#   'oft',
#   'minderwertige',
#   'Schnaps',
#   'wurde',
#   'in',
#   'das',
#   'angrenzende',
#   'hessische',
#   'Gebiet',
#   'eingeschmuggelt'],
#  ['Allein',
#   'die',
#   'Unterstützung',
#   'der',
#   'Völker',
#   'stärkt',
#   'es',
#   'in',
#   'seinem',
#   'Ringen'],
#  ['An', 'dieser', 'Stelle', 'lichtet', 'sich', 'der', 'Wald', 'etwas'],
#  ['Das',
#   'Kaliwerk',
#   'Zielitz',
#   'ist',
#   'das',
#   'größte',
#   'Kalibergwerk',
#   'Deutschlands',
#   'und',
#   'eines',
#   'der',
#   'größten',
#   'weltweit'],
#  ['Minute', 'für', 'Jörgen', 'Pettersson', 'eingewechselt'],
#  ['Zwei',
#   'Täfelchen',
#   'aus',
#   'getriebenem',
#   'Silber',
#   'zeigen',
#   'ihn',
#   'als',
#   'Krieger',
#   'mit',
#   'Schild',
#   'und',
#   'Speer'],
#  ['Wieso', 'das', 'ist', 'doch', 'prima'],
#  ['Zuletzt',
#   'betätigte',
#   'er',
#   'sich',
#   'auch',
#   'als',
#   'politischer',
#   'und',
#   'Romanautor'],
#  ['Deswegen',
#   'haben',
#   'wir',
#   'Schutzvorkehrungen',
#   'für',
#   'jeden',
#   'Fall',
#   'getroffen'],
#  ['Gegenwärtig', 'werden', 'Richtlinien', 'ausgearbeitet'],
#  ['Als', 'Gastgeber', 'ist', 'Frankreich', 'bereits', 'qualifiziert'],
#  ['Die', 'Anlage', 'ist', 'in', 'Privatbesitz', 'und', 'ständig', 'bewohnt'],
#  ['Schildern',
#   'Sie',
#   'das',
#   'Vorgehen',
#   'noch',
#   'mal',
#   'in',
#   'eigenen',
#   'Worten'],
#  ['Zum',
#   'Transport',
#   'von',
#   'Holz',
#   'und',
#   'anderen',
#   'Gütern',
#   'konnten',
#   'die',
#   'Leitern',
#   'abgenommen',
#   'werden'],
#  ['Anders',
#   'als',
#   'sein',
#   'Name',
#   'vermuten',
#   'lässt',
#   'lebt',
#   'der',
#   'Käfer',
#   'hauptsächlich',
#   'an',
#   'Eichen'],
#  ['Dennoch',
#   'gibt',
#   'es',
#   'viele',
#   'Gründe',
#   'die',
#   'diesen',
#   'Optimismus',
#   'rechtfertigen'],
#  ['Sie', 'galt', 'als', 'politischer', 'Gegner', 'der', 'Great', 'Alliance'],
#  ['Kurz',
#   'nachdem',
#   'die',
#   'Räuber',
#   'die',
#   'Bank',
#   'verlassen',
#   'hatten',
#   'wurde',
#   'die',
#   'Polizei',
#   'verständigt'],
#  ['Hier',
#   'steht',
#   'das',
#   'Konzept',
#   'Cassirers',
#   'der',
#   'Theorie',
#   'Adornos',
#   'entgegen'],
#  ['sechs'],
#  ['Hier',
#   'liegt',
#   'ein',
#   'schwerwiegender',
#   'Vorgang',
#   'zugrunde',
#   'ein',
#   'schwerwiegender',
#   'politischer',
#   'Fehler'],
#  ['Angebaut',
#   'werden',
#   'insbesondere',
#   'Zierpflanzen',
#   'Kartoffeln',
#   'und',
#   'Erdbeeren'],
#  ['Alwin', 'Nadja', 'und', 'Andrea', 'spielen', 'Verstecken'],
#  ['ja'],
#  ['Kennst', 'du', 'die', 'Geschichte', 'hinter', 'diesem', 'Song'],
#  ['Geht', 'das', 'nicht', 'auch', 'ohne', 'die', 'schwarzen', 'Balken'],
#  ['Der',
#   'gutaussehende',
#   'und',
#   'begabte',
#   'Soldat',
#   'ist',
#   'bei',
#   'seinen',
#   'Kameraden',
#   'wie',
#   'auch',
#   'den',
#   'Vorgesetzten',
#   'beliebt'],
#  ['Die',
#   'Augen',
#   'liegen',
#   'nicht',
#   'seitlich',
#   'sondern',
#   'nahezu',
#   'auf',
#   'der',
#   'Oberseite',
#   'der',
#   'Larven'],
#  ['Auch',
#   'die',
#   'Villages',
#   'Lagen',
#   'sind',
#   'sehr',
#   'gut',
#   'gemachte',
#   'Weine'],
#  ['Das', 'geht', 'nicht', 'an'],
#  ['Schon', 'in', 'Angola', 'spielte', 'Rafael', 'Fußball'],
#  ['Die',
#   'Thermoplaste',
#   'werden',
#   'erhitzt',
#   'in',
#   'ihre',
#   'Form',
#   'gebracht',
#   'und',
#   'wieder',
#   'abgekühlt'],
#  ['Hinzu',
#   'kommt',
#   'dass',
#   'die',
#   'Fahrt',
#   'jetzt',
#   'vollkommen',
#   'überdacht',
#   'ist'],
#  ['Gegensatz', 'ist', 'die', 'Rückversicherung'],
#  ['Versionsnummern', 'sagen', 'heutzutage', 'nichts', 'mehr', 'aus'],
#  ['Stagnierende', 'Umsätze', 'sind', 'das', 'Resultat'],
#  ['Zugleich',
#   'wurde',
#   'der',
#   'alte',
#   'Name',
#   '"Latina',
#   'wieder',
#   'angenommen'],
#  ['Die',
#   'Schüler',
#   'können',
#   'jederzeit',
#   'ohne',
#   'Probleme',
#   'ins',
#   'Schweizer',
#   'Schulsystem',
#   'wechseln'],
#  ['Er', 'gilt', 'als', 'begabter', 'Songwriter', 'und', 'Musiker'],
#  ['sechs'],
#  ['Die', 'Fruchtknoten', 'sind', 'kahl'],
#  ['fünf'],
#  ['Stattdessen',
#   'geht',
#   'es',
#   'in',
#   'die',
#   'Entwicklung',
#   'von',
#   'Medikamenten',
#   'oder',
#   'Therapien'],
#  ['Der',
#   'Bezirk',
#   'gehört',
#   'zu',
#   'den',
#   'am',
#   'dichtesten',
#   'verbauten',
#   'Bezirken',
#   'Wiens'],
#  ['Er', 'gehörte', 'als', 'Exklave', 'zum', 'Amt', 'Bokeloh'],
#  ['Akupunktur',
#   'funktioniert',
#   'nicht',
#   'wenn',
#   'man',
#   'nicht',
#   'dran',
#   'glaubt'],
#  ['Auch',
#   'aus',
#   'eigener',
#   'Erfahrung',
#   'weiß',
#   'ich',
#   'dass',
#   'Vieles',
#   'oft',
#   'schief',
#   'läuft'],
#  ['Das', 'spart', 'Geschirr'],
#  ['Was', 'für', 'ein', 'Angeber', 'dachte', 'Horst', 'im', 'Stillen'],
#  ['Es',
#   'hat',
#   'ein',
#   'oder',
#   'mehrere',
#   'voneinander',
#   'und',
#   'untereinander',
#   'elektrisch',
#   'isolierte',
#   'Adernpaare'],
#  ['Doch', 'die', 'kolumbianische', 'Regierung', 'blieb', 'untätig'],
#  ['drei'],
#  ['Er', 'ist', 'im', 'Urnenhain', 'Tolkewitz', 'beigesetzt'],
#  ['Dies', 'ist', 'nicht', 'der', 'Zweck', 'der', 'heutigen', 'Debatte'],
#  ['Sie',
#   'würde',
#   'es',
#   'von',
#   'anderen',
#   'abhängig',
#   'machen',
#   'ob',
#   'sie',
#   'kommt',
#   'oder',
#   'nicht'],
#  ['Omi', 'saß', 'im', 'Schaukelstuhl', 'und', 'strickte', 'einen', 'Pullover'],
#  ['Ein',
#   'Jahr',
#   'später',
#   'erhielt',
#   'der',
#   'Torwart',
#   'einen',
#   'Profivertrag',
#   'war',
#   'aber',
#   'nur',
#   'Ersatzmann'],
#  ['Mit',
#   'letzterem',
#   'Album',
#   'war',
#   'der',
#   'Vertrag',
#   'mit',
#   'Epic',
#   'erfüllt'],
#  ['Der',
#   'Bereitschaft',
#   'der',
#   'Behörden',
#   'diese',
#   'Fälle',
#   'aufzuklären',
#   'ist',
#   'nur',
#   'selten',
#   'groß'],
#  ['In',
#   'der',
#   'kurzen',
#   'aber',
#   'turbulenten',
#   'Firmengeschichte',
#   'ging',
#   'es',
#   'auf',
#   'und',
#   'ab'],
#  ['Manche',
#   'Menschen',
#   'empfinden',
#   'den',
#   'Spiegelei',
#   'Effekt',
#   'darüber',
#   'hinaus',
#   'als',
#   'unästhetisch'],
#  ['Seitdem',
#   'firmiert',
#   'das',
#   'Unternehmen',
#   'als',
#   'Strategy',
#   'als',
#   'eigenständiger',
#   'Teil',
#   'des',
#   'PwC',
#   'Firmennetzwerkes'],
#  ['Letzter', 'deutscher', 'Geistlicher', 'war', 'Pfarrer', 'Arno', 'Kopisch'],
#  ['Sie',
#   'werden',
#   'zum',
#   'Teil',
#   'als',
#   'Originale',
#   'in',
#   'der',
#   'Literatur',
#   'beschrieben'],
#  ['Die', 'Trainer', 'sind', 'Klaus', 'und', 'Gabi', 'Bahr'],
#  ['Er', 'hat', 'ihn', 'im', 'Schwitzkasten'],
#  ['Es',
#   'existiert',
#   'auch',
#   'der',
#   '"Transport',
#   'der',
#   'Schiffe',
#   'in',
#   'einem',
#   'wassergefüllten',
#   'Trog'],
#  ['Am', 'Ende', 'der', 'Saison', 'stand', 'der', 'direkte', 'Wiederabstieg'],
#  ['Der', 'Sitz', 'der', 'Bundesarbeitsgemeinschaft', 'ist', 'Berlin'],
#  ['Hersteller',
#   'des',
#   'Bootes',
#   'war',
#   'die',
#   'Schweers',
#   'Werft',
#   'in',
#   'Bardenfleth'],
#  ['Platz', 'der', 'Billboard', 'Charts'],
#  ['Alle', 'vier', 'Seiten', 'waren', 'beschriftet'],
#  ['An',
#   'der',
#   'Bergstation',
#   'gibt',
#   'es',
#   'ein',
#   'Restaurant',
#   'mit',
#   'Bar',
#   'und',
#   'Aussichtsterrasse'],
#  ['Mit', 'der', 'will', 'er', 'das', 'ganze', 'Land', 'erobern'],
#  ['Durch',
#   'die',
#   'Eintragung',
#   'im',
#   'Handelsregister',
#   'entstehen',
#   'Rechtsfolgen',
#   'im',
#   'Verkehr',
#   'mit',
#   'den',
#   'eingetragenen',
#   'Gesellschaften'],
#  ['An',
#   'jeder',
#   'Seite',
#   'liegt',
#   'ein',
#   'monumentales',
#   'Tor',
#   'mit',
#   'seitlichen',
#   'Ecktürmen'],
#  ['Hei'],
#  ['Im',
#   'Bevölkerungsschutz',
#   'wurden',
#   'und',
#   'werden',
#   'Mannschaftstransportwagen',
#   'vielfältig',
#   'eingesetzt'],
#  ['Geh', 'mir', 'nicht', 'auf', 'den', 'Keks'],
#  ['sieben'],
#  ['Ich', 'habe', 'etwas', 'Käse', 'mitgebracht'],
#  ['Ein',
#   'Sieg',
#   'würde',
#   'sie',
#   'an',
#   'die',
#   'Spitze',
#   'der',
#   'Tabelle',
#   'katapultieren'],
#  ['Sie',
#   'entstanden',
#   'wie',
#   'das',
#   'Tal',
#   'selbst',
#   'durch',
#   'Erosion',
#   'des',
#   'weichen',
#   'Felsens'],
#  ['Aber', 'der', 'Petitionsausschuss', 'kann', 'noch', 'mehr', 'leisten'],
#  ['Dessen',
#   'Nachfolger',
#   'John',
#   'Robson',
#   'ernannte',
#   'Davie',
#   'zum',
#   'Attorney',
#   'General'],
#  ['nein'],
#  ['Deshalb',
#   'würde',
#   'ich',
#   'einfach',
#   'diese',
#   'Schutzkappe',
#   'überstülpen',
#   'und',
#   'gut',
#   'ist'],
#  ['Karl',
#   'Eckermann',
#   'war',
#   'Mitglied',
#   'im',
#   'Hannoverschen',
#   'Künstlerverein'],
#  ['"Sie',
#   'werden',
#   'doch',
#   'nicht',
#   'etwa",',
#   'setzte',
#   'ich',
#   'zum',
#   'Protest',
#   'an',
#   'doch',
#   'es',
#   'war',
#   'bereits',
#   'zu',
#   'spät'],
#  ['Wiener', 'Gemeindebezirk', 'Leopoldstadt'],
#  ['Diesen',
#   'musste',
#   'er',
#   'sich',
#   'als',
#   'Kritiker',
#   'bei',
#   'der',
#   '"Berliner',
#   'allgemeinen',
#   'musikalischen',
#   'Zeitung',
#   'verdienen'],
#  ['Sein',
#   'erster',
#   'Studienort',
#   'ist',
#   'nicht',
#   'bekannt',
#   'dürfte',
#   'jedoch',
#   'Leipzig',
#   'gewesen',
#   'sein'],
#  ['Früher', 'war', 'die', 'Kapazität', 'deutlich', 'größer'],
#  ['Dieser',
#   'Laser',
#   'ist',
#   'so',
#   'stark',
#   'dass',
#   'man',
#   'damit',
#   'Metall',
#   'schneiden',
#   'kann'],
#  ['Hier',
#   'war',
#   'Burger',
#   'bald',
#   'wegen',
#   'seiner',
#   'Grausamkeit',
#   'und',
#   'seiner',
#   'Willkür',
#   'gefürchtet'],
#  ['Erstrebt',
#   'wird',
#   'ein',
#   'System',
#   'ausgewogener',
#   'checks',
#   'and',
#   'balances'],
#  ['Das',
#   'älteste',
#   'bekannte',
#   'Exemplar',
#   'in',
#   'der',
#   'Wildnis',
#   'ist',
#   'mit',
#   'fünf',
#   'Jahren',
#   'gestorben'],
#  ['Diese',
#   'Operation',
#   'konnte',
#   'aufgrund',
#   'der',
#   'geringen',
#   'Distanz',
#   'mit',
#   'leichten',
#   'Landungsbooten',
#   'durchgeführt',
#   'werden'],
#  ['Fundamentreste', 'sind', 'aber', 'noch', 'vorhanden'],
#  ['Thursday',
#   'muss',
#   'geduldig',
#   'warten',
#   'bis',
#   'die',
#   'Aufhebung',
#   'seiner',
#   'Ausrottung',
#   '„bestehen',
#   'bleibt“.'],
#  ['Der',
#   'Verwaltungsträger',
#   'ist',
#   'dabei',
#   'eine',
#   'juristische',
#   'Person',
#   'des',
#   'öffentlichen',
#   'Rechts',
#   'oder',
#   'des',
#   'Privatrechts'],
#  ['neun'],
#  ['Der', '"', 'floh'],
#  ['The',
#   'Coup',
#   'ist',
#   'bekannt',
#   'für',
#   'seine',
#   'offen',
#   'antikapitalistische',
#   'Einstellung'],
#  ['Der',
#   'Einsatz',
#   'weiterer',
#   'Multicast',
#   'Protokolle',
#   'ist',
#   'daher',
#   'unumgänglich'],
#  ['Daher',
#   'schrieb',
#   'er',
#   'sei',
#   'es',
#   'mit',
#   'einer',
#   'speziellen',
#   'Technik',
#   'möglich',
#   'sie',
#   'sprechen',
#   'zu',
#   'lehren'],
#  ['eins'],
#  ['Er', 'zählt', 'zu', 'den', 'bekanntesten', 'mexikanischen', 'Sängern'],
#  ['Sehr', 'viele', 'Bürger', 'im', 'Osten', 'sind', 'konfessionslos'],
#  ['Oberhalb',
#   'der',
#   'Einmündung',
#   'des',
#   'Steinbachs',
#   'trägt',
#   'er',
#   'auch',
#   'den',
#   'Namen',
#   'Mühlbach'],
#  ['Er',
#   'kehrte',
#   'daraufhin',
#   'wieder',
#   'zu',
#   'Lok',
#   'Delitzsch',
#   'in',
#   'die',
#   'drittklassige',
#   'Bezirksliga',
#   'zurück'],
#  ['Die', 'Autobahnabfahrt', 'nach', 'Kempten'],
#  ['Wer',
#   'das',
#   'sieht',
#   'der',
#   'weiß',
#   'dass',
#   'diesem',
#   'Schiff',
#   'großes',
#   'Unglück',
#   'geschehen',
#   'wird'],
#  ['Wie', 'gefährlich', 'sind', 'E', 'Zigaretten'],
#  ['Georg',
#   'Talbot',
#   'führte',
#   'den',
#   'Ehrentitel',
#   '"',
#   'Geheimer',
#   'Kommerzienrat'],
#  ['Ich',
#   'finde',
#   'aber',
#   'dass',
#   'wir',
#   'das',
#   'Problem',
#   'im',
#   'großen',
#   'und',
#   'ganzen',
#   'gut',
#   'gelöst',
#   'haben'],
#  ['Jugendliche',
#   'aus',
#   'anderen',
#   'Orten',
#   'waren',
#   'dabei',
#   'gern',
#   'gesehene',
#   'Gäste'],
#  ['Dadurch',
#   'gibt',
#   'es',
#   'auch',
#   'einige',
#   'größere',
#   'Hotels',
#   'und',
#   'Kurhotels'],
#  ['Suche', 'Züge', 'nach', 'Düsseldorf'],
#  ['Ist', 'dies', 'eine', 'Anpassung', 'an', 'die', 'Globalisierung'],
#  ['Mit',
#   'Tempomat',
#   'wird',
#   'mir',
#   'immer',
#   'so',
#   'langweilig',
#   'dass',
#   'ich',
#   'nicht',
#   'mehr',
#   'richtig',
#   'aufpasse'],
#  ['ja'],
#  ['Königswarter', 'Ehrenpreis“', 'verliehen'],
#  ['Dylan', 'sollte', 'das', 'Stück', 'kürzen', 'was', 'er', 'ablehnte'],
#  ['Dies', 'waren', 'die', 'ersten', 'Lokomotiven', 'aus', 'Mödling'],
#  ['Der',
#   'Ortsname',
#   'leitet',
#   'sich',
#   'von',
#   'einem',
#   'gleichlautenden',
#   'Flurnamen',
#   'ab'],
#  ['Seitdem',
#   'betreibt',
#   'Speckmann',
#   'die',
#   'Band',
#   'von',
#   'dort',
#   'aus',
#   'weiter'],
#  ['Dort',
#   'informierte',
#   'ein',
#   'preußischer',
#   'Armeeangehöriger',
#   'Schleinitz',
#   'vom',
#   'Kriegsausbruch'],
#  ['zwei'],
#  ['Man',
#   'sollte',
#   'die',
#   'Fragen',
#   'also',
#   'geschickt',
#   'so',
#   'formulieren',
#   'dass',
#   'sie',
#   'erwartungsgemäß',
#   'bejaht',
#   'werden'],
#  ['Uwe', 'holt', 'die', 'Fliegenklatsche'],
#  ['Die', 'Fahrt', 'nach', 'Köln', 'konnte', 'er', 'sich', 'nicht', 'leisten'],
#  ['Bynum', 'wechselte', 'die', 'High', 'School', 'insgesamt', 'drei', 'Mal'],
#  ['Direkt', 'an', 'der', 'Autobahn', 'zu', 'tanken', 'ist', 'teuer'],
#  ['Beide',
#   'Male',
#   'mussten',
#   'sie',
#   'sich',
#   'der',
#   'Konkurrenz',
#   'aus',
#   'dem',
#   'eigenen',
#   'Land',
#   'geschlagen',
#   'geben'],
#  ['Per',
#   'Räuberleiter',
#   'könnten',
#   'wir',
#   'es',
#   'über',
#   'die',
#   'Mauer',
#   'schaffen'],
#  ['Jeder',
#   'hat',
#   'es',
#   'gedacht',
#   'aber',
#   'keiner',
#   'traute',
#   'sich',
#   'es',
#   'zu',
#   'verbalisieren'],
#  ['Die', 'Kassiererin', 'kann', 'den', 'Barcode', 'nicht', 'finden'],
#  ['Vorsichtig', 'steigen', 'sie', 'durch', 'die', 'Dachluke'],
#  ['Die',
#   'Messtechnik',
#   'ist',
#   'in',
#   'Verbindung',
#   'mit',
#   'Steuerungs',
#   'und',
#   'Regelungstechnik',
#   'eine',
#   'Voraussetzung',
#   'der',
#   'Automatisierungstechnik'],
#  ['Heute',
#   'wird',
#   'sie',
#   'in',
#   'den',
#   'meisten',
#   'Armeen',
#   'nur',
#   'noch',
#   'bei',
#   'Paraden',
#   'getragen'],
#  ['Außerdem',
#   'scheut',
#   'Coelho',
#   'sich',
#   'nicht',
#   'gleich',
#   'zu',
#   'Beginn',
#   'einen',
#   'Selbstbezug',
#   'herzustellen'],
#  ['Ebenso', 'ist', 'auch', 'die', 'Ortsverwaltung', 'hier', 'untergebracht'],
#  ['Der', 'Neuling', 'sollte', 'sich', 'lieber', 'warm', 'anziehen'],
#  ['Deshalb',
#   'ist',
#   'die',
#   'flexible',
#   'Anpassung',
#   'der',
#   'amtlichen',
#   'Kontrollen',
#   'an',
#   'die',
#   'Größe',
#   'des',
#   'Betriebes',
#   'notwendig'],
#  ['Fünf', 'Jahre', 'später', 'wanderte', 'er', 'nach', 'Schweden', 'aus'],
#  ['Aus',
#   'seinem',
#   'Rucksack',
#   'nahm',
#   'er',
#   'einen',
#   'Adapter',
#   'von',
#   'HDMI',
#   'auf',
#   'DVI'],
#  ['Wir', 'telefonieren', 'später'],
#  ['ja'],
#  ['Es',
#   'implementiert',
#   'dazu',
#   'nur',
#   'einen',
#   'Ausschnitt',
#   'der',
#   'Programmiersprache',
#   'Java'],
#  ['Azevedo',
#   'wurde',
#   'als',
#   'Sohn',
#   'eines',
#   'Schreiners',
#   'in',
#   'einem',
#   'nordportugiesischen',
#   'Dorf',
#   'geboren'],
#  ['drei'],
#  ['Weitergehende',
#   'Dokumente',
#   'mit',
#   'genaueren',
#   'Daten',
#   'sind',
#   'jedoch',
#   'nicht',
#   'existent'],
#  ['Über',
#   'die',
#   'Jahre',
#   'wurden',
#   'seine',
#   'Verantwortungen',
#   'immer',
#   'umfangreicher'],
#  ['Er',
#   'hat',
#   'sich',
#   'außerdem',
#   'um',
#   'den',
#   'sozialen',
#   'Wohnungsbau',
#   'in',
#   'Heilbronn',
#   'verdient',
#   'gemacht'],
#  ['Meine', 'Arbeit', 'endet', 'hier'],
#  ['In', 'England', 'ist', 'sie', 'lokal', 'verbreitet'],
#  ['nein'],
#  ['Platz', 'und', 'wurde', 'zum', 'Chefcoach', 'befördert'],
#  ['Zu',
#   'Beginn',
#   'der',
#   'folgenden',
#   'Saison',
#   'gewann',
#   'man',
#   'den',
#   'Superpokal'],
#  ['Deshalb',
#   'habe',
#   'ich',
#   'einen',
#   'eigenen',
#   'Gesetzentwurf',
#   'geschrieben',
#   '".'],
#  ['Besonders',
#   'auch',
#   'historisch',
#   'wertvoll',
#   'sind',
#   'seine',
#   'Zyklen',
#   'aus',
#   'Prag',
#   'und',
#   'Paris'],
#  ['Er', 'kassierte', 'das', 'Tor', 'das', 'dieses', 'Spiel', 'beendete'],
#  ['Der',
#   'Gerichtsmediziner',
#   'Thomas',
#   'Noguchi',
#   'stufte',
#   'den',
#   'Fall',
#   'als',
#   'Unfalltod',
#   'durch',
#   'Ertrinken',
#   'und',
#   'Unterkühlung',
#   'ein'],
#  ['ja'],
#  ['In', 'Reims', 'ist', 'eine', 'Straße', 'nach', 'Halbwachs', 'benannt'],
#  ['Gegebenenfalls',
#   'leiten',
#   'sie',
#   'Ratsuchende',
#   'an',
#   'Gynäkologen',
#   'Hebammen',
#   'und',
#   'andere',
#   'Fachdienste',
#   'weiter'],
#  ['Aus',
#   'finanziellen',
#   'Gründen',
#   'begann',
#   'er',
#   'später',
#   'Unterhaltungsromane',
#   'zu',
#   'schreiben'],
#  ['Dazu', 'entstand', 'eine', 'Kriegsgräberstätte', 'in', 'der', 'Ortsmitte'],
#  ['Dennoch',
#   'gelten',
#   'die',
#   'Begriffe',
#   'heute',
#   'auch',
#   'mit',
#   'Bezug',
#   'auf',
#   'einzelne',
#   'Kunstwerke',
#   'als',
#   'weitgehend',
#   'austauschbar'],
#  ['eins'],
#  ['Auf',
#   'der',
#   'Brücke',
#   'warteten',
#   'der',
#   'König',
#   'und',
#   'der',
#   'Kronprinz'],
#  ['Mein', 'Aquarium', 'muss', 'mal', 'wieder', 'gereinigt', 'werden'],
#  ['Sein',
#   'Gemälde',
#   'ist',
#   'in',
#   'der',
#   'National',
#   'Gallery',
#   'in',
#   'London',
#   'zu',
#   'sehen'],
#  ['Baker', 'ist', 'verheiratet', 'und', 'hat', 'drei', 'Kinder'],
#  ['Die',
#   'Touring',
#   'Version',
#   'wurde',
#   'allerdings',
#   'nicht',
#   'in',
#   'Serie',
#   'produziert'],
#  ['Beide',
#   'Systeme',
#   'können',
#   'also',
#   'nur',
#   'mit',
#   'eingeschränkter',
#   'Geschwindigkeit',
#   'arbeiten'],
#  ['Auch',
#   'wenn',
#   'mir',
#   'die',
#   'Kunden',
#   'auf',
#   'die',
#   'Nerven',
#   'gehen',
#   'muss',
#   'ich',
#   'Höflichkeit',
#   'bewahren'],
#  ['Man',
#   'kann',
#   'stattdessen',
#   'auch',
#   'Rapsöl',
#   'oder',
#   'Sonnenblumenöl',
#   'nehmen'],
#  ['Gleichzeitig',
#   'erfolgte',
#   'die',
#   'Umbenennung',
#   'des',
#   'Schachtes',
#   'Justus',
#   'in',
#   '"Wittekind".'],
#  ['vier'],
#  ['Ich',
#   'habe',
#   'Ihnen',
#   'nochmals',
#   'einen',
#   'Brief',
#   'geschrieben',
#   'aber',
#   'keine',
#   'Antwort',
#   'erhalten'],
#  ['Nach', 'Kriegsende', 'wurde', 'der', 'Ortskern', 'neu', 'aufgebaut'],
#  ['ja'],
#  ['Es',
#   'ist',
#   'dann',
#   'vielmehr',
#   'ein',
#   'Sammelsurium',
#   'unkonkreter',
#   'Aussagen',
#   'ohne',
#   'klare',
#   'Leitlinien'],
#  ['Das',
#   'Abgeordnetenhaus',
#   'kann',
#   'die',
#   'Regierung',
#   'als',
#   'Ganzes',
#   'durch',
#   'ein',
#   'Misstrauensvotum',
#   'zum',
#   'Rücktritt',
#   'zwingen'],
#  ['Auch', 'als', 'Synchronsprecher', 'war', 'er', 'aktiv'],
#  ['Hier', 'soll', 'sich', 'sein', 'Schicksal', 'erfüllen'],
#  ['Ein',
#   'weiter',
#   'bekannter',
#   'Enkel',
#   'war',
#   'der',
#   'Rechtsanwalt',
#   'Gustav',
#   'Eduard',
#   'Nolte'],
#  ['Der',
#   'nördliche',
#   'Abschnitt',
#   'wird',
#   'mittels',
#   'der',
#   'S',
#   'Bahn',
#   'vom',
#   'Bahnhof',
#   'Friedrichshagen',
#   'erschlossen'],
#  ['Es', 'fehlt', 'das', 'gewisse', 'Etwas'],
#  ['Es',
#   'war',
#   'also',
#   'nur',
#   'Abbau',
#   'von',
#   'Diskriminierungen',
#   'nicht',
#   'Besserstellung',
#   'bezweckt'],
#  ['Kann', 'Spuren', 'von', 'Sellerie', 'enthalten'],
#  ['Produzent', 'sämtlicher', 'Folgen', 'war', 'Helmut', 'Ringelmann'],
#  ['nan'],
#  ['Sie', 'halten', 'die', 'Zeit', 'reif', 'für', 'ein', 'Umdenken'],
#  ['eins'],
#  ['Die',
#   'Elbe',
#   'fließt',
#   'durch',
#   'Dresden',
#   'Magdeburg',
#   'und',
#   'Hamburg',
#   'und',
#   'mündet',
#   'in',
#   'die',
#   'Nordsee'],
#  ['Am', 'Ende', 'kommt', 'es', 'doch', 'anders'],
#  ['Dabei',
#   'werden',
#   'Bewusstsein',
#   'und',
#   'Schmerzempfindung',
#   'ausgeschaltet'],
#  ['Dort',
#   'will',
#   'Rau',
#   'ein',
#   'auf',
#   'internationale',
#   'Tourneen',
#   'spezialisiertes',
#   '„globales',
#   'Volkstheater“',
#   'etablieren'],
#  ['Er',
#   'besuchte',
#   'in',
#   'Kiel',
#   'die',
#   'Oberrealschule',
#   'die',
#   'heutige',
#   'Max',
#   'Planck',
#   'Schule'],
#  ['Nun', 'möchte', 'ich', 'über', 'die', 'Datenerfassung', 'sprechen'],
#  ['Diese',
#   'Dinge',
#   'müssen',
#   'in',
#   'der',
#   'Europäischen',
#   'Union',
#   'schneller',
#   'koordiniert',
#   'werden'],
#  ['Am', 'Freitag', 'will', 'die', 'Geschäftsführung', 'Bilanz', 'ziehen'],
#  ['Geh', 'von', 'der', 'Couch', 'du', 'fauler', 'Hund'],
#  ['An', 'der', 'Rennbahn', 'gibt', 'es', 'eine', 'eigene', 'Haltestelle'],
#  ['Die',
#   'Insel',
#   'liegt',
#   'am',
#   'nördlichen',
#   'Ende',
#   'der',
#   'Bristol',
#   'Bay',
#   'am',
#   'Eingang',
#   'der',
#   'Togiak',
#   'Bay'],
#  ['Diese',
#   'Gemälde',
#   'sind',
#   '„von',
#   'feiner',
#   'Stimmung',
#   'und',
#   'großer',
#   'poetischer',
#   'Wirkung“.'],
#  ['Die',
#   'erste',
#   'Herrenmannschaft',
#   'des',
#   'Clubs',
#   'spielt',
#   'in',
#   'der',
#   'Baseball',
#   'Bundesliga'],
#  ['Deshalb',
#   'wird',
#   'diese',
#   'kompakte',
#   'und',
#   'stromsparende',
#   'Methode',
#   'nur',
#   'bei',
#   'Raumfahrtmissionen',
#   'verwendet'],
#  ['Die',
#   'interaktive',
#   'Installation',
#   'ist',
#   'in',
#   'Karlsruhe',
#   'im',
#   'Zentrum',
#   'für',
#   'Kunst',
#   'und',
#   'Medientechnologie',
#   'zu',
#   'erfahren'],
#  ['Die',
#   'preußisch',
#   'sächsische',
#   'Armee',
#   'marschierte',
#   'am',
#   'Rande',
#   'des',
#   'Thüringer',
#   'Waldes',
#   'auf'],
#  ['Hier',
#   'waren',
#   'Haken',
#   'angebracht',
#   'an',
#   'denen',
#   'der',
#   'Henker',
#   'seine',
#   'Arbeit',
#   'vollzog'],
#  ['Seine',
#   'schriftstellerische',
#   'Tätigkeit',
#   'setzte',
#   'er',
#   'bis',
#   'zu',
#   'seinem',
#   'Tode',
#   'fort'],
#  ['Er', 'war', 'Mitglied', 'der', 'Volkstanzgruppe', 'Ostrołęka'],
#  ['Also', 'lass', 'uns', 'mal', 'lieber', 'höher', 'klettern'],
#  ['Erfolgreichste', 'Gruppe', 'waren', 'die', 'Supremes'],
#  ['Diese',
#   'verbindet',
#   'die',
#   'Gemeinde',
#   'im',
#   'Norden',
#   'mit',
#   'Reutlingen',
#   'und',
#   'im',
#   'Süden',
#   'mit',
#   'Riedlingen'],
#  ['Ihr',
#   'Weg',
#   'führt',
#   'durch',
#   'ein',
#   'bewaldetes',
#   'Tal',
#   'vorbei',
#   'an',
#   'der',
#   'Ortschaft',
#   'Gößl'],
#  ['Es', 'gibt', 'fast', 'keine', 'Übersetzungen', 'ins', 'Deutsche'],
#  ['Es', 'müssen', 'auch', 'alle', 'in', 'die', 'selbe', 'Richtung', 'ziehen'],
#  ['Dennoch',
#   'ist',
#   'es',
#   'notwendig',
#   'wie',
#   'ich',
#   'es',
#   'sehe',
#   'diese',
#   'Änderung',
#   'vorzunehmen'],
#  ['Mit', 'diesem', 'Club', 'begannen', 'seine', 'sportlichen', 'Erfolge'],
#  ['Kurz', 'darauf', 'erschießt', 'sich', 'Tetley'],
#  ['Während',
#   'des',
#   'dänisch',
#   'schwedischen',
#   'Krieges',
#   'war',
#   'er',
#   'als',
#   'kaiserlicher',
#   'Abgesandter',
#   'in',
#   'Kopenhagen'],
#  ['neun'],
#  ['acht'],
#  ['Die', 'Roadmap', 'scheint', 'uns', 'zu', 'lähmen'],
#  ['Dann',
#   'hätte',
#   'Postumius',
#   'auch',
#   'gegen',
#   'religiöse',
#   'Vorschriften',
#   'verstoßen'],
#  ['Unter',
#   'diesem',
#   'Namen',
#   'ist',
#   'ein',
#   'weiterer',
#   'Sohn',
#   'des',
#   'Radjedef',
#   'bekannt'],
#  ['Im',
#   'Sprachgebrauch',
#   'und',
#   'in',
#   'der',
#   'Literatur',
#   'wurde',
#   'es',
#   'weiterhin',
#   'zumeist',
#   'einfach',
#   'als',
#   'Yoshiwara',
#   'bezeichnet'],
#  ['Woher', 'haben', 'Sie', 'meine', 'Nummer'],
#  ['Als',
#   'der',
#   'Funkspruch',
#   'einging',
#   'brach',
#   'im',
#   'Kontrollzentrum',
#   'Hektik',
#   'aus'],
#  ['Die',
#   'Geschichte',
#   'der',
#   'Ahrtalbahn',
#   'beginnt',
#   'als',
#   'Zweigstrecke',
#   'der',
#   'linken',
#   'Rheinstrecke'],
#  ['Sie', 'ist', 'also', 'ansteckend'],
#  ['Nach',
#   'einer',
#   'Desensibilisierung',
#   'kommt',
#   'sie',
#   'mit',
#   'ihrem',
#   'Heuschnupfen',
#   'ganz',
#   'gut',
#   'zurecht'],
#  ['Wo', 'zum', 'Henker', 'sind', 'wir'],
#  ['Neu', 'Delhi', 'ist', 'die', 'Hauptstadt', 'von', 'Indien'],
#  ['Eigentlich', 'war', 'es', 'eher', 'ein', 'Monolog'],
#  ['Temperatur',
#   'im',
#   'Wohnzimmer',
#   'um',
#   'zwei',
#   'Grad',
#   'Celsius',
#   'hochregeln'],
#  ['Finden', 'Sie', 'das', 'witzig'],
#  ['Mit', 'der', 'Gründung', 'der', '"', 'Hör', 'Zu'],
#  ['Die',
#   'Gletscher',
#   'hatten',
#   'das',
#   'weiche',
#   'Gestein',
#   'abgetragen',
#   'und',
#   'das',
#   'harte',
#   'Gestein',
#   'blieb',
#   'stehen'],
#  ['Es',
#   'herrscht',
#   'ein',
#   'Steppenklima',
#   'weshalb',
#   'nebst',
#   'Reben',
#   'auch',
#   'verschiedene',
#   'Kakteenarten',
#   'gedeihen'],
#  ['Natürlich', 'gibt', 'es', 'Probleme', 'oder', 'Unstimmigkeiten'],
#  ['sechs'],
#  ['vier'],
#  ['Diese',
#   'öffnen',
#   'mit',
#   'einem',
#   'Monat',
#   'die',
#   'Augen',
#   'und',
#   'werden',
#   'nach',
#   'zwei',
#   'Monaten',
#   'entwöhnt'],
#  ['Ein',
#   'Großteil',
#   'der',
#   'Einwohner',
#   'pendelt',
#   'nach',
#   'Lund',
#   'und',
#   'Malmö'],
#  ['Das',
#   'Bild',
#   'der',
#   'Gemeinde',
#   'ist',
#   'von',
#   'Weiden',
#   'Wald',
#   'Obstbäumen',
#   'und',
#   'Weinbergen',
#   'geprägt'],
#  ['Dem',
#   'Landgericht',
#   'Arnsberg',
#   'übergeordnet',
#   'ist',
#   'das',
#   'Oberlandesgericht',
#   'Hamm'],
#  ['Conakry', 'ist', 'die', 'Hauptstadt', 'von', 'Guinea'],
#  ['Wieso', 'warst', 'du', 'nicht', 'auf', 'meiner', 'Beerdigung'],
#  ['Er',
#   'wurde',
#   'zum',
#   'Boss',
#   'der',
#   'russischen',
#   'Mafia',
#   'in',
#   'New',
#   'York'],
#  ['Auch', 'geflochtene', 'Gürtel', 'sind', 'bekannt'],
#  ['Gott',
#   'sei',
#   'Dank',
#   'habe',
#   'ich',
#   'gerade',
#   'noch',
#   'die',
#   'Kurve',
#   'gekriegt'],
#  ['Sie',
#   'wird',
#   'in',
#   'Form',
#   'von',
#   'vier',
#   'Zahlen',
#   'geschrieben',
#   'die',
#   'mit',
#   'Punkten',
#   'voneinander',
#   'getrennt',
#   'sind'],
#  ['Sie', 'war', 'die', 'Cousine', 'von', 'Carl', 'Maria', 'von', 'Weber'],
#  ['Er',
#   'beschrieb',
#   'Menschen',
#   'aus',
#   'dem',
#   'bäuerlichen',
#   'Milieu',
#   'in',
#   'moralischen',
#   'und',
#   'religiösen',
#   'Grenzsituationen'],
#  ['Zu',
#   'so',
#   'später',
#   'Stunde',
#   'sind',
#   'die',
#   'meisten',
#   'Schüler',
#   'nicht',
#   'mehr',
#   'besonders',
#   'aufnahmefähig'],
#  ['Die',
#   'Winkelhalbierende',
#   'unterteilt',
#   'das',
#   'Winkelfeld',
#   'in',
#   'zwei',
#   'deckungsgleiche',
#   'Teile'],
#  ['Ja', 'Glenn', 'ist', 'wirklich', 'eine', 'Frostbeule'],
#  ['Britta',
#   'hat',
#   'null',
#   'Bock',
#   'auf',
#   'die',
#   'bevorstehende',
#   'Familienfeier'],
#  ['Es', 'existiert', 'kein', 'Harmonisierungsbedarf'],
#  ['Obwohl',
#   'aus',
#   'der',
#   'Ehe',
#   'vier',
#   'Kinder',
#   'hervorgingen',
#   'verlief',
#   'seine',
#   'Ehe',
#   'unglücklich'],
#  ['An',
#   'meiner',
#   'rechten',
#   'Pedale',
#   'ist',
#   'ein',
#   'Reflektor',
#   'abgebrochen'],
#  ['Andreas', 'anrufen'],
#  ['Wie',
#   'lange',
#   'braucht',
#   'man',
#   'mit',
#   'dem',
#   'Fahrrad',
#   'von',
#   'Regensburg',
#   'bis',
#   'Ludwigsburg'],
#  ['Ich', 'war', 'hier', 'seit', 'Jahren', 'nicht', 'mehr'],
#  ['Das', 'Unternehmen', 'betreibt', 'Bus', 'und', 'Straßenbahnlinien'],
#  ['Lassen',
#   'Sie',
#   'mich',
#   'zunächst',
#   'ein',
#   'paar',
# ...
#   'eröffnet',
#   'haben'],
#  ['Dort', 'kam', 'er', 'nur', 'fünfmal', 'zum', 'Einsatz'],
#  ['Tschechoslowakische', 'Liga', 'aufstieg'],
#  ['Während',
#   'dieser',
#   'Zeit',
#   'erhielt',
#   'er',
#   'auch',
#   'von',
#   'Jaki',
#   'Byard',
#   'und',
#   'Herb',
#   'Pomeroy',
#   'privaten',
#   'Unterricht'],
#  ['Der', 'Begriff', 'leitet', 'sich', 'vom', 'griech'],
#  ['Eine', 'Speicherung', 'von', 'E', 'Mails', 'ist', 'nicht', 'vorgesehen'],
#  ['Die',
#   'genaue',
#   'Unfallursache',
#   'konnte',
#   'dem',
#   'Vernehmen',
#   'nach',
#   'nie',
#   'ermittelt',
#   'werden'],
#  ['An',
#   'diesem',
#   'Grundsatz',
#   'halten',
#   'wir',
#   'fest',
#   'und',
#   'das',
#   'wissen',
#   'auch',
#   'die',
#   'Mitgliedstaaten'],
#  ['Beides', 'ist', 'gleichermaßen', 'unbefriedigend'],
#  ['Die', 'Siedlung', 'selbst', 'ist', 'völlig', 'autofrei'],
#  ['Dieser', 'brachte', 'ihm', 'auch', 'das', 'Lesen', 'bei'],
#  ['Daneben',
#   'hat',
#   'er',
#   'vor',
#   'allem',
#   'Kammermusikwerke',
#   'geschrieben',
#   'unter',
#   'denen',
#   'zehn',
#   'Streichquartette',
#   'hervorheben',
#   'sind'],
#  ['In', 'Celle', 'verwaltete', 'er', 'das', 'Finanzressort'],
#  ['Er', 'ist', 'lobenswert', 'und', 'sollte', 'angenommen', 'werden'],
#  ['Sie',
#   'wurden',
#   'nacheinander',
#   'im',
#   'Verlauf',
#   'mehrerer',
#   'Jahre',
#   'getötet',
#   'oder',
#   'lebendig',
#   'begraben'],
#  ['Eine', 'interaktive', 'Landkarte', 'ist', 'online', 'verfügbar'],
#  ['Sie',
#   'jagen',
#   'mit',
#   'Pfeil',
#   'und',
#   'Bogen',
#   'auf',
#   'Wildschweine',
#   'Reptilien',
#   'und',
#   'Vögel'],
#  ['Ohne',
#   'die',
#   'geostationären',
#   'Satelliten',
#   'kommt',
#   'das',
#   'System',
#   'nicht',
#   'aus'],
#  ['Mercedes', 'ist', 'eigentlich', 'ein', 'weiblicher', 'Vorname'],
#  ['Auf',
#   'diesen',
#   'Moment',
#   'hat',
#   'unser',
#   'Haus',
#   'lange',
#   'Zeit',
#   'gewartet',
#   'und',
#   'hingearbeitet'],
#  ['Wenn',
#   'das',
#   'Klopapier',
#   'ausverkauft',
#   'ist',
#   'kaufe',
#   'ich',
#   'stattdessen',
#   'eine',
#   'Bildzeitung'],
#  ['Kurt',
#   'Dietrich',
#   'Otto',
#   'Heinrich',
#   'und',
#   'Hans',
#   'Georg',
#   'aus',
#   'dem',
#   'Winckel',
#   'sind',
#   'seine',
#   'jüngeren',
#   'Brüder'],
#  ['Sein', 'Bruder', 'Dick', 'führte', 'das', 'Ölgeschäft', 'weiter'],
#  ['zwei'],
#  ['neun'],
#  ['Die',
#   'Gemeinde',
#   'verfügt',
#   'über',
#   'einen',
#   'Kindergarten',
#   'eine',
#   'Grundschule',
#   'und',
#   'eine',
#   'weiterführende',
#   'Schule'],
#  ['Wechselnd',
#   'tauchen',
#   'Nebendarsteller',
#   'auf',
#   'und',
#   'verschwinden',
#   'wieder'],
#  ['nein'],
#  ['ja'],
#  ['So',
#   'kam',
#   'es',
#   'in',
#   'der',
#   'Vergangenheit',
#   'dort',
#   'immer',
#   'wieder',
#   'zu',
#   'Protesten',
#   'und',
#   'staatlichen',
#   'Repressalien'],
#  ['Monsheim',
#   'liegt',
#   'an',
#   'der',
#   'Pfrimm',
#   'im',
#   'südlichen',
#   'Wonnegau',
#   'in',
#   'Rheinhessen'],
#  ['Daher',
#   'möchte',
#   'ich',
#   'dass',
#   'diese',
#   'wohlbekannten',
#   'Akzente',
#   'auch',
#   'finanziell',
#   'gut',
#   'versehen',
#   'sind'],
#  ['Sie',
#   'folgt',
#   'damit',
#   'der',
#   'Klassifikation',
#   'des',
#   'Aarne',
#   'Thompson',
#   'Index'],
#  ['Mir', 'ist', 'der', 'Appetit', 'vergangen'],
#  ['Gaborone', 'ist', 'die', 'Hauptstadt', 'von', 'Botswana'],
#  ['Über',
#   'eine',
#   'schlechte',
#   'Vergütung',
#   'kann',
#   'ich',
#   'mich',
#   'jedenfalls',
#   'nicht',
#   'beklagen'],
#  ['Es', 'kommt', 'auf', 'die', 'Inhaltsstoffe', 'an'],
#  ['Die',
#   'bekannteste',
#   'Farm',
#   'war',
#   'im',
#   'Besitz',
#   'von',
#   'David',
#   'Strawbridge',
#   'der',
#   'ihr',
#   'den',
#   'Namen',
#   'Castle',
#   'Shanahan',
#   'gab'],
#  ['Die',
#   'Bezeichnung',
#   '„Nalgene“',
#   'ist',
#   'ein',
#   'eingetragenes',
#   'Warenzeichen'],
#  ['Dadurch', 'ist', 'der', 'Unterlauf', 'nicht', 'schiffbar'],
#  ['Robert', 'vergibt', 'ihr', 'doch', 'Mrs'],
#  ['Eine',
#   'schnelle',
#   'psychosoziale',
#   'Unterstützung',
#   'reagiert',
#   'als',
#   'eine',
#   'Psychosoziale',
#   'Notfallversorgung',
#   'auf',
#   'akute',
#   'Ereignisse'],
#  ['Bei',
#   'den',
#   'Präsidentschaftswahlen',
#   'hatte',
#   'Palmer',
#   'aber',
#   'keine',
#   'Chance'],
#  ['Viele', 'wurden', 'später', 'erneut', 'aufgelegt'],
#  ['Diese', 'wurden', 'in', 'älteren', 'Normen', 'als', '"Typen', 'bezeichnet'],
#  ['Drei',
#   'Monate',
#   'nach',
#   'dem',
#   'Rücktritt',
#   'ließ',
#   'er',
#   'sich',
#   'erneut',
#   'von',
#   'Jassir',
#   'Arafat',
#   'berufen'],
#  ['Auch',
#   'im',
#   'Free',
#   'Jazz',
#   'findet',
#   'die',
#   'Inside',
#   'Outside',
#   'Improvisation',
#   'immer',
#   'wieder',
#   'Anwendung'],
#  ['Diese',
#   'wurde',
#   'im',
#   'Zweiten',
#   'Weltkrieg',
#   'vollständig',
#   'vertrieben',
#   'oder',
#   'ausgelöscht'],
#  ['Die', 'Schneide', 'ist', 'typischerweise', 'aus', 'gehärtetem', 'Stahl'],
#  ['acht'],
#  ['eins'],
#  ['Weiterhin',
#   'führte',
#   'er',
#   'die',
#   'erste',
#   'Volkszählung',
#   'in',
#   'Navarra',
#   'durch'],
#  ['Ein',
#   'Wanderweg',
#   'führt',
#   'durch',
#   'die',
#   'Schlucht',
#   'zum',
#   'Gipfel',
#   'des',
#   'Großen',
#   'Falkensteins'],
#  ['Seine', 'Rede', 'kann', 'man', 'nur', 'als', 'zynisch', 'bezeichnen'],
#  ['Kreissägen',
#   'und',
#   'Bohrmaschinen',
#   'sollten',
#   'nie',
#   'mit',
#   'Handschuhen',
#   'bedient',
#   'werden'],
#  ['Wie', 'war', 'es', 'für', 'Teenies', 'in', 'den', 'Sechzigern'],
#  ['Zu', 'schneller', 'Reichtum', 'kann', 'den', 'Charakter', 'zerstören'],
#  ['Alle', 'fünf', 'starben', 'während', 'ihrer', 'Rückkehr'],
#  ['Unordnung', 'auf', 'großen', 'Skalen'],
#  ['Hierbei',
#   'nimmt',
#   'die',
#   'Farbintensität',
#   'mit',
#   'sinkendem',
#   'Eisengehalt',
#   'ab'],
#  ['Sein',
#   'erster',
#   'Musiklehrer',
#   'mit',
#   'Liedern',
#   'aus',
#   'der',
#   'Sprache',
#   'und',
#   'Literatur',
#   'Paschtu',
#   'war',
#   'Jafar'],
#  ['Sind',
#   'Sie',
#   'erstens',
#   'nicht',
#   'auch',
#   'der',
#   'Meinung',
#   'dass',
#   'Herr',
#   'Heaton',
#   'Harris',
#   'Betrügern',
#   'grünes',
#   'Licht',
#   'gibt'],
#  ['Sie',
#   'wird',
#   'damit',
#   'eine',
#   'der',
#   'ersten',
#   'und',
#   'vielleicht',
#   'bekanntesten',
#   'Performance',
#   'Künstlerinnen',
#   'der',
#   'Schweiz'],
#  ['Ich',
#   'denke',
#   'nicht',
#   'dass',
#   'die',
#   'Wand',
#   'so',
#   'bemalt',
#   'werden',
#   'sollte'],
#  ['Emil', 'wohnt', 'in', 'der', 'Usedomer', 'Straße'],
#  ['Er', 'erhält', 'eine', 'Kopie', 'der', 'Rechnung', 'zur', 'Kenntnisnahme'],
#  ['Alle',
#   'Arbeiten',
#   'zur',
#   'Wartung',
#   'konnte',
#   'die',
#   'Besatzung',
#   'ohne',
#   'fremde',
#   'Hilfe',
#   'durchführen'],
#  ['Überdies',
#   'verfasste',
#   'er',
#   'eine',
#   'Reihe',
#   'von',
#   'lateinischen',
#   'Lebensbeschreibungen',
#   'der',
#   'Augsburger',
#   'Bürgermeister'],
#  ['Später', 'stieg', 'er', 'zum', 'Leiter', 'der', 'Behörde', 'auf'],
#  ['Dann', 'sind', 'wir', 'bereit', 'mit', 'Ihnen', 'alles', 'durchzufechten'],
#  ['Das',
#   'ist',
#   'ein',
#   'Forum',
#   'in',
#   'dem',
#   'alle',
#   'die',
#   'Minderheiten',
#   'betreffenden',
#   'Fragen',
#   'erörtert',
#   'werden',
#   'können'],
#  ['Paris', 'ist', 'die', 'Hauptstadt', 'von', 'Frankreich'],
#  ['Der',
#   'Atlantische',
#   'Ozean',
#   'bedeckt',
#   'insgesamt',
#   'etwa',
#   'ein',
#   'Fünftel',
#   'der',
#   'Erdoberfläche'],
#  ['Diesen',
#   'Zickenkrieg',
#   'ertrage',
#   'ich',
#   'nicht',
#   'länger',
#   'platzte',
#   'es',
#   'dem',
#   'Vater',
#   'heraus'],
#  ['Ich',
#   'will',
#   'gar',
#   'nicht',
#   'wissen',
#   'was',
#   'in',
#   'seinem',
#   'Kopfkino',
#   'gerade',
#   'abgeht'],
#  ['Haben', 'wir', 'Puderzucker', 'auf', 'Vorrat'],
#  ['Johanna', 'liegt', 'mit', 'einer', 'Magen', 'Darm', 'Erkrankung', 'flach'],
#  ['Hast',
#   'du',
#   'dir',
#   'das',
#   'Kennzeichen',
#   'ausgesucht',
#   'oder',
#   'wurde',
#   'es',
#   'zugeteilt'],
#  ['Zu',
#   'viele',
#   'Goldsucher',
#   'seien',
#   'von',
#   'dort',
#   'oben',
#   'nicht',
#   'zurückgekommen'],
#  ['Alter', 'Falter', 'das', 'hat', 'mir', 'gerade', 'noch', 'gefehlt'],
#  ['Und', 'so', 'geht', 'es', 'im', 'Gänsemarsch', 'bis', 'zum', 'Ärmelkanal'],
#  ['Meine', 'zweite', 'Anmerkung', 'betrifft', 'die', 'Länder'],
#  ['Ihre', 'Pilotprojekte', 'wären', 'ein', 'guter', 'Anfang'],
#  ['Firefox'],
#  ['fünf'],
#  ['Dort',
#   'vertreibt',
#   'er',
#   'die',
#   'synthetisch',
#   'erzeugten',
#   'Lebensmittel',
#   'aus',
#   'seiner',
#   'Fabrik'],
#  ['Sie', 'war', 'Teil', 'der', 'Baltischen', 'Flotte'],
#  ['Er', 'war', 'in', 'einigen', 'Bereichen', 'der', 'Regierung', 'tätig'],
#  ['Im', 'Südwesten', 'grenzt', 'Epping', 'Forest', 'an', 'Greater', 'London'],
#  ['Sein', 'Thron', 'wird', 'von', 'zwei', 'Elefanten', 'getragen'],
#  ['Selbst',
#   'Fachautoren',
#   'verwenden',
#   'die',
#   'Wörter',
#   '„Umgangsformen“',
#   'und',
#   '„Etikette“',
#   'häufig',
#   'bedeutungsgleich'],
#  ['Zweitens',
#   'gibt',
#   'es',
#   'keine',
#   'Möglichkeit',
#   'bei',
#   'einer',
#   'übergeordneten',
#   'Instanz',
#   'Berufung',
#   'einzulegen'],
#  ['Vor', 'Ort', 'befindet', 'sich', 'zudem', 'der', 'Kreuzweg', 'Burrweiler'],
#  ['Als',
#   'Student',
#   'an',
#   'der',
#   'Universität',
#   'Wien',
#   'wurde',
#   'er',
#   'Mitglied',
#   'des',
#   'österreichischen',
#   'Cartellverbandes'],
#  ['Ian',
#   'Carr',
#   'würdigte',
#   'ihn',
#   'als',
#   'selten',
#   'talentierten',
#   'Komponisten',
#   'und',
#   'Arrangeur',
#   'sowie',
#   'als',
#   'charismatischen',
#   'Bigband',
#   'Leiter'],
#  ['Dann', 'kann', 'ich', 'jetzt', 'ja', 'die', 'Wäsche', 'aufhängen'],
#  ['Am',
#   'deutlichsten',
#   'merkt',
#   'man',
#   'den',
#   'Dopplereffekt',
#   'wenn',
#   'ein',
#   'Einsatzwagen',
#   'mit',
#   'Sirene',
#   'an',
#   'einem',
#   'vorbeifährt'],
#  ['Den', 'darauffolgenden', 'Strafstoß', 'parierte', 'er', 'sogar'],
#  ['In',
#   'einer',
#   'Variante',
#   'des',
#   'Antriebs',
#   'drehen',
#   'sich',
#   'zwei',
#   'Propeller',
#   'innerhalb',
#   'eines',
#   'Kragens',
#   'gegeneinander'],
#  ['Dann',
#   'erscheint',
#   'der',
#   'Geist',
#   'seines',
#   'Vaters',
#   'den',
#   'er',
#   'ebenfalls',
#   'verachtet'],
#  ['Der', 'Flughafen', 'kann', 'nur', 'privat', 'angeflogen', 'werden'],
#  ['Als', 'Kind', 'wollte', 'ich', 'immer', 'erwachsen', 'sein'],
#  ['Das', 'sind', 'düstere', 'Aussichten'],
#  ['Ein', 'Wassertropfen', 'fällt', 'von', 'dem', 'Wasserspeier', 'auf', 'ihn'],
#  ['In',
#   'seinen',
#   'Stücken',
#   'übernahm',
#   'er',
#   'häufig',
#   'auch',
#   'die',
#   'Hauptrolle',
#   'auf',
#   'der',
#   'Theaterbühne'],
#  ['In', 'Goldbach', 'liegt', 'der', 'Hund', 'begraben'],
#  ['Der', 'Konzern', 'fürchtet', 'um', 'seine', 'Reputation'],
#  ['Besonders', 'prägte', 'ihn', 'aber', 'Django', 'Reinhardt'],
#  ['Die',
#   'Geschichte',
#   'von',
#   'Salzburg',
#   'war',
#   'immer',
#   'auf',
#   'das',
#   'Engste',
#   'mit',
#   'der',
#   'Salzgewinnung',
#   'verbunden'],
#  ['Heute',
#   'heißt',
#   'diese',
#   'Einrichtung',
#   'Landesbetrieb',
#   'Information',
#   'und',
#   'Technik',
#   'Nordrhein',
#   'Westfalen'],
#  ['Auf',
#   'dem',
#   'Markt',
#   'durchsetzen',
#   'konnte',
#   'sich',
#   'das',
#   'System',
#   'nicht'],
#  ['Eine',
#   'weitere',
#   'Variante',
#   'ist',
#   'die',
#   'gleichzeitige',
#   'orale',
#   'und',
#   'anale',
#   'Penetration'],
#  ['Im', 'Normalfall', 'werden', 'zwei', 'bis', 'drei', 'Jungtiere', 'geboren'],
#  ['Hier',
#   'fehlt',
#   'jedoch',
#   'die',
#   'für',
#   'eine',
#   'Kapitulation',
#   'erforderliche',
#   'Besetzung',
#   'und',
#   'Entwaffnung'],
#  ['Die',
#   'Station',
#   'Niederursel',
#   'liegt',
#   'im',
#   'alten',
#   'Ortskern',
#   'des',
#   'Stadtteils'],
#  ['Ihr', 'eigenes', 'Instrument', 'ist', 'die', 'Gitarre'],
#  ['Deswegen',
#   'sind',
#   'in',
#   'der',
#   'Regel',
#   'in',
#   'der',
#   'Teilungserklärung',
#   'mehrere',
#   'Verteilungsschlüssel',
#   'festgelegt'],
#  ['Hierbei',
#   'handelt',
#   'es',
#   'sich',
#   'um',
#   'einen',
#   'Freizeit',
#   'und',
#   'Vergnügungspark',
#   'mit',
#   'etlichen',
#   'Karussells',
#   'und',
#   'Kiosken'],
#  ['Akademische', 'Institut', 'für', 'Kirchenmusik', 'zu', 'Berlin'],
#  ['Ist',
#   'das',
#   'offensichtlich',
#   'oder',
#   'bedarf',
#   'es',
#   'einer',
#   'Erläuterung'],
#  ['"Das',
#   'kann',
#   'kein',
#   'Dauerzustand',
#   'sein",',
#   'stellte',
#   'ein',
#   'Sprecher',
#   'vor',
#   'laufenden',
#   'Kameras',
#   'klar'],
#  ['In',
#   'unmittelbarer',
#   'Nähe',
#   'der',
#   'Siedlung',
#   'lag',
#   'das',
#   'Wrack',
#   'der',
#   '"Maud".'],
#  ['Zusätzlich',
#   'dient',
#   'dieses',
#   'Gewicht',
#   'dann',
#   'auch',
#   'dem',
#   'Fahrkomfort',
#   'und',
#   'der',
#   'Laufruhe',
#   'des',
#   'Schleppers'],
#  ['Kannst', 'du', 'mir', 'halbwegs', 'folgen'],
#  ['Da', 'gibt', 'es', 'nichts', 'zu', 'beschönigen'],
#  ['Die', 'Autobahnabfahrt', 'nach', 'Kempten'],
#  ['Der', 'Saunabereich', 'ist', 'textilfreie', 'Zone'],
#  ['Zuflüsse',
#   'sind',
#   'nur',
#   'Gräben',
#   'aus',
#   'den',
#   'Wiesen',
#   'der',
#   'nahen',
#   'Umgebung'],
#  ['Alle', 'in', 'Frankreich', 'geltenden', 'Gesetze', 'wurden', 'eingeführt'],
#  ['Der',
#   'übliche',
#   'Unfallhergang',
#   'ist',
#   'ein',
#   'Sturz',
#   'der',
#   'mit',
#   'der',
#   'Hand',
#   'abgefangen',
#   'wird'],
#  ['Der', 'Claim', 'der', 'Station', 'ist', '«Die', 'beste', 'Musik».'],
#  ['Sie',
#   'sind',
#   'die',
#   'eindrucksvollsten',
#   'Klippen',
#   'der',
#   'South',
#   'Downs',
#   'in',
#   'Sussex',
#   'im',
#   'Süden',
#   'Englands'],
#  ['Auf',
#   'dem',
#   'Fußballplatz',
#   'war',
#   'er',
#   'als',
#   'harter',
#   'aber',
#   'technisch',
#   'versierter',
#   'Verteidiger',
#   'bekannt'],
#  ['In',
#   'seinen',
#   'zehn',
#   'Jahren',
#   'als',
#   'Extraordinarius',
#   'beschäftigte',
#   'sich',
#   'Kaegi',
#   'vor',
#   'allem',
#   'mit',
#   'dem',
#   'Altgriechischen'],
#  ['Das',
#   'Original',
#   'befindet',
#   'sich',
#   'heute',
#   'im',
#   'Teylers',
#   'Museum',
#   'der',
#   'niederländischen',
#   'Stadt',
#   'Haarlem'],
#  ['Acht',
#   'Jahre',
#   'später',
#   'hatte',
#   'die',
#   '"Stadtverkehr',
#   'GmbH',
#   'das',
#   'Busnetz',
#   'auf',
#   'sechs',
#   'Linien',
#   'ausgebaut'],
#  ['In',
#   'seiner',
#   'Karriere',
#   'nahm',
#   'er',
#   'an',
#   'zwei',
#   'Weltmeisterschaften',
#   'teil'],
#  ['Da',
#   'Dafydd',
#   'diese',
#   'Angriffe',
#   'nicht',
#   'dulden',
#   'konnte',
#   'kam',
#   'es',
#   'zu',
#   'Grenzkonflikten'],
#  ['Als',
#   'nächster',
#   'Punkt',
#   'folgt',
#   'die',
#   'Debatte',
#   'zu',
#   'den',
#   'fünf',
#   'Entschließungsanträgen',
#   'zum',
#   'Iran'],
#  ['Wolfgang', 'Philipps', '"', 'Vergangenheit', 'und', 'Zukunft'],
#  ['Ich',
#   'glaube',
#   'dass',
#   'eine',
#   'präventive',
#   'und',
#   'dauerhafte',
#   'Sicherheitspolitik',
#   'damit',
#   'nicht',
#   'vereinbar',
#   'ist'],
#  ['In',
#   'Berlin',
#   'war',
#   'er',
#   'Mitglied',
#   'der',
#   'Freimaurerloge',
#   '„Pythagoras',
#   'zum',
#   'flammenden',
#   'Stern“.'],
#  ['Wir',
#   'alle',
#   'sind',
#   'die',
#   'Erben',
#   'dieses',
#   'großen',
#   'Europäers',
#   'Jean',
#   'Monnet'],
#  ['Mit',
#   'der',
#   'gemeinsamen',
#   'Währung',
#   'werden',
#   'wir',
#   'nicht',
#   'nur',
#   'die',
#   'Integration',
#   'vertiefen'],
#  ['Wir', 'verstehen', 'das'],
#  ['Trotzdem', 'versucht', 'Max', 'weiter', 'seinem', 'Vater', 'zu', 'helfen'],
#  ['In',
#   'den',
#   'Planungsregionen',
#   'sind',
#   'jeweils',
#   'mehrere',
#   'Kreise',
#   'zusammengefasst'],
#  ['sieben'],
#  ['sechs'],
#  ['Damaskus', 'ist', 'die', 'Hauptstadt', 'von', 'Syrien'],
#  ['Was', 'kommt', 'heute', 'Abend', 'im', 'Fernsehen'],
#  ['Anlässlich',
#   'seiner',
#   'Heirat',
#   'trat',
#   'er',
#   'vom',
#   'lutherischen',
#   'zum',
#   'orthodoxen',
#   'Glauben',
#   'über'],
#  ['Der',
#   'Grund',
#   'für',
#   'das',
#   'Sinken',
#   'des',
#   'Bootes',
#   'wurde',
#   'nie',
#   'bekannt'],
#  ['Von', 'seinen', 'Lebensdaten', 'ist', 'nichts', 'bekannt'],
#  ['Sie',
#   'arbeiten',
#   'in',
#   'ihren',
#   'jeweiligen',
#   'Fachgebieten',
#   'eng',
#   'mit',
#   'in',
#   'der',
#   'Lehre',
#   'eingesetzten',
#   'Lehrbeauftragten',
#   'zusammen'],
#  ['Ohne',
#   'sie',
#   'hätten',
#   'wir',
#   'diese',
#   'Arbeit',
#   'nicht',
#   'bewerkstelligen',
#   'können'],
#  ['Wohl',
#   'eher',
#   'unter',
#   'deren',
#   'Reparatur',
#   'sozusagen',
#   'denn',
#   'es',
#   'gibt',
#   'heute',
#   'bereits',
#   'eine',
#   'Verbindung'],
#  ['Abu',
#   'Dhabi',
#   'ist',
#   'die',
#   'Hauptstadt',
#   'der',
#   'Vereinigten',
#   'Arabischen',
#   'Emirate'],
#  ['Der', 'Zug', 'kam', 'dreizehn', 'Minuten', 'zu', 'spät'],
#  ['Gibt', 'es', 'in', 'Mainz', 'eine', 'Straßenbahn'],
#  ['Oh', 'Gott', 'ein', 'Monster'],
#  ['Dies', 'ist', 'in', 'meinen', 'Augen', 'ein', 'Fehler'],
#  ['Allerdings',
#   'haben',
#   'sie',
#   'für',
#   'den',
#   'von',
#   'Elmar',
#   'Brok',
#   'eingereichten',
#   'Entschließungsantrag',
#   'votiert'],
#  ['ja'],
#  ['sechs'],
#  ['Hans',
#   'Rampf',
#   'wuchs',
#   'im',
#   'niederbayerischen',
#   'Laberweinting',
#   'auf',
#   'wo',
#   'er',
#   'eine',
#   'Ausbildung',
#   'zum',
#   'Bäcker',
#   'absolvierte'],
#  ['Der', 'Großteil', 'der', 'Bevölkerung', 'sind', 'Kurden'],
#  ...]

# %%
for idx, path in enumerate(tqdm(lang_df['path'])):
    id = path[:-4]
    with open(os.path.join(lang_root, '16kHz', '{}.txt'.format(id)), 'w') as w:
        w.write(' '.join(tokenized_sentences[idx]))
# Out:
# 100%|██████████| 765790/765790 [01:08<00:00, 11104.13it/s]

# %%
filtered_grids = []
n_outlier = 0
for i, path in enumerate(tqdm(lang_df['path'])):
    id = path[:-4]
    # grid_path = os.path.join(dict_lang_root, '16kHz/align_wmseg/{}.TextGrid'.format(id))
    grid_path = os.path.join(lang_root, '16kHz/align_spm/{}.TextGrid'.format(id))
    if os.path.exists(grid_path):
        grid = textgrids.TextGrid(grid_path)
        filtered_grid = [tok for tok in grid['words'] if tok.text != '']

        if len(filtered_grid) != len(tokenized_sentences[i]):
            # print(filtered_grid, tokenized_sentences[i], sep='\n')
            continue

        interval = np.array([(word.xmin, word.xmax) for word in filtered_grid])
        audio_path = os.path.join(lang_root, '16kHz/{}.wav'.format(id))
        info = torchaudio.info(audio_path)
        duration = info.num_frames / info.sample_rate
        interval = interval / duration

        th.save([segmentss[i], interval], os.path.join(lang_root, '16kHz', '{}.pt'.format(id)))
# Out:
# 100%|██████████| 765790/765790 [07:33<00:00, 1689.58it/s]

# %%
df = load_df_from_tsv(os.path.join(lang_root, 'train_asr_{}-cv.tsv'.format(lang)))

# %%
mask = np.ones(len(df), dtype=bool)

# %%
for i, id in enumerate(df['id']):
    if not os.path.exists(os.path.join(lang_root, '16kHz', '{}.pt'.format(id))):
        mask[i] = False

# %%
save_df_to_tsv(df[mask], os.path.join(lang_root, 'train_asr_{}-cv.tsv'.format(lang)))

# %% [markdown]
# # Remove data points in valid and test

# %%
root = '/mnt/data/siqiouyang/datasets/covost2/'

# %%
lang = 'zh-CN'
cv2_lang_root = os.path.join(root, lang)
cv9_lang_root = os.path.join(root, lang + '-cv')

# %%
cv2_lang_root, cv9_lang_root
# Out:
# ('/mnt/data/siqiouyang/datasets/covost2/zh-CN',
#  '/mnt/data/siqiouyang/datasets/covost2/zh-CN-cv')

# %%
dev_df = load_df_from_tsv(os.path.join(cv2_lang_root, 'dev_st_{}_en.tsv'.format(lang)))
test_df = load_df_from_tsv(os.path.join(cv2_lang_root, 'test_st_{}_en.tsv'.format(lang)))

# %%
to_remove = set(dev_df['id'].tolist() + test_df['id'].tolist())

# %%
len(to_remove)
# Out:
# 9741

# %%
def clean(name):
    tsv_path = os.path.join(cv9_lang_root, name)
    train_df = load_df_from_tsv(tsv_path)
    mask = [True] * len(train_df)
    for i in range(len(train_df)):
        if train_df['id'][i] in to_remove:
            mask[i] = False
    train_df = train_df[mask]
    save_df_to_tsv(train_df, tsv_path)

# %%
clean('train_st_{}-cv_en.tsv'.format(lang))

# %%
clean('train_asr_{}-cv.tsv'.format(lang))

# %%
clean('train_asr_{}-cv_full.tsv'.format(lang))
