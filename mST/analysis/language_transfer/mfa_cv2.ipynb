# %%
import os
import re
import random
from string import punctuation
from argparse import Namespace
from collections import defaultdict

import IPython

import torch as th
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
import torchaudio
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sentencepiece as spm

import textgrids
import faiss

from sentence_transformers import SentenceTransformer
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

from fairseq.data import Dictionary
from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)
from fairseq.data.audio.speech_to_text_dataset import get_features_or_waveform
from examples.speech_to_text.data_utils import load_df_from_tsv, save_df_to_tsv
from fairseq.checkpoint_utils import load_checkpoint_to_cpu
from fairseq.data.encoders.sentencepiece_bpe import SentencepieceBPE, SentencepieceConfig

from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)

# %% [markdown]
# # Build Code-Switch for CV 9.0 Language

# %%
root = '/mnt/data/siqiouyang/datasets/covost2/'

# %% [markdown]
# # Tokenization

# %%
tokenizer = spm.SentencePieceProcessor()
tokenizer.Load('/mnt/data/siqiouyang/runs/mST/pretrained/mbart50.ft.n1/sentence.bpe.model')
# Out:
# True

# %%
langs = ['de', 'fr', 'es', '-it-', 'ru', 'zh-CN', 'pt', '-fa-', '-et-', '-mn-', 'nl', 'tr', '-ar-', 'sv-SE', '-lv-', '-sl-', '-ta-', '-ja-', '-id-']

# %%
lang = 'pt'
lang_root = os.path.join(root, lang)

# %%
lang_df = load_df_from_tsv(os.path.join(lang_root, 'train_st_{}_en.tsv'.format(lang)))

# %%
lang_df
# Out:
#                             id                         audio  n_frames  \
# 0     common_voice_pt_19277034  common_voice_pt_19277034.wav     68352
# 1     common_voice_pt_19277037  common_voice_pt_19277037.wav     95232
# 2     common_voice_pt_19277041  common_voice_pt_19277041.wav     43392
# 3     common_voice_pt_19277042  common_voice_pt_19277042.wav     74880
# 4     common_voice_pt_19277044  common_voice_pt_19277044.wav     69120
# ...                        ...                           ...       ...
# 9153  common_voice_pt_19860863  common_voice_pt_19860863.wav     71040
# 9154  common_voice_pt_19860882  common_voice_pt_19860882.wav     59520
# 9155  common_voice_pt_19860892  common_voice_pt_19860892.wav     89472
# 9156  common_voice_pt_19860899  common_voice_pt_19860899.wav    130560
# 9157  common_voice_pt_20157003  common_voice_pt_20157003.wav     65280
#
#                                                src_text  \
# 0               Altere o dispositivo de saída de áudio.
# 1     Até a data-limite, prevista no tratado, vários...
# 2                                 Eu balancei a cabeça.
# 3     Adicione The Cranberries Zombie a playlist de ...
# 4         Um cinegrafista filmando um jogo de basquete.
# ...                                                 ...
# 9153   Existe alguma coisa que eu possa fazer por você?
# 9154                                  Poesia e verdade.
# 9155        Um surfista está fazendo cache de uma onda.
# 9156  Dois homens vestindo roupas escocesas tradicio...
# 9157             O patinet não funciona bem na calçada.
#
#                                                tgt_text  \
# 0                       Change the audio output device.
# 1     By the deadline shown in the treaty, various m...
# 2                                      I shook my head.
# 3     Add The Cranberries Zombie to the classics pla...
# 4                A cameraman filming a basketball game.
# ...                                                 ...
# 9153               Is there something I can do for you?
# 9154                                  Poetry and truth.
# 9155                         A surfer is riding a wave.
# 9156  Two men in traditional Scottish clothes are ho...
# 9157  The scooter doesn’t work very well on the side...
#
#                                                 speaker src_lang tgt_lang
# 0     939991dfcf12d8250739f3b4e5ed47e0dc4bf8ffb69810...       pt       en
# 1     939991dfcf12d8250739f3b4e5ed47e0dc4bf8ffb69810...       pt       en
# 2     939991dfcf12d8250739f3b4e5ed47e0dc4bf8ffb69810...       pt       en
# 3     939991dfcf12d8250739f3b4e5ed47e0dc4bf8ffb69810...       pt       en
# 4     939991dfcf12d8250739f3b4e5ed47e0dc4bf8ffb69810...       pt       en
# ...                                                 ...      ...      ...
# 9153  9d91497cb25399ad6cf6a4d88548fa84ee3c3687363015...       pt       en
# 9154  9d91497cb25399ad6cf6a4d88548fa84ee3c3687363015...       pt       en
# 9155  9d91497cb25399ad6cf6a4d88548fa84ee3c3687363015...       pt       en
# 9156  9d91497cb25399ad6cf6a4d88548fa84ee3c3687363015...       pt       en
# 9157  9d91497cb25399ad6cf6a4d88548fa84ee3c3687363015...       pt       en
#
# [9158 rows x 8 columns]

# %%
sentences = lang_df['src_text'].tolist()
sentences
# Out:
# ['Altere o dispositivo de saída de áudio.',
#  'Até a data-limite, prevista no tratado, vários mísseis foram destruídos.',
#  'Eu balancei a cabeça.',
#  'Adicione The Cranberries Zombie a playlist de clássicas.',
#  'Um cinegrafista filmando um jogo de basquete.',
#  'Ajude meu filho',
#  'Embora o sol seja muito grande',
#  'Cerca de um em vinte.',
#  'O Facebook tem muitos problemas de privacidade.',
#  'Você acabou de dar um tapinha nele.',
#  'Não pode mudar de carro a cada ano',
#  'A mulher com cabelo loiro mantém seus óculos escuros.',
#  'Isso me impressiona!',
#  '"O termo ""apenas meus dois centavos"" é sobre a opinião? não sobre dinheiro."',
#  'Diga-me a previsão do tempo para a França',
#  'Jornal diário desportivo que segue toda a atualidade desportiva com independência e rigor jornalístico.',
#  'O garoto recordou o brilho que havia notado no dia anterior.',
#  'Quanto vale o real no momento?',
#  'Isso não poderia ter esperado até a manhã?',
#  'A areia flutua sobre as soleiras da velha casa.',
#  '"""Não deixe que eles vejam que você está com medo de?"", disse o alquimista."',
#  'um cachorro preso dentro',
#  'Procurando oportunidades futuras em Taiwan',
#  'Pois naquele momento? não lhe ocorreu que poderia ser oco.',
#  'Você precisará saber para criar seu próprio ambiente personalizado.',
#  'Mamãe, feliz dia das mães!',
#  'Sempre que podia, ele procurava um novo caminho para viajar.',
#  'Ele achou? logo depois do amanhecer? e não longe dos poços de areia.',
#  'A vista deveria valer a pena.',
#  'Pegue a partida e bata contra o seu sapato.',
#  'Claro, sempre há tudo.',
#  'O preço unitário será menor e menor',
#  'Coro da sociedade harmônica.',
#  'Olá!',
#  'O que você tem para reportar?',
#  'Eu estou indo para o negócio por mim mesmo.',
#  'Que tal me levar para casa no estilo?',
#  'Precisamos trocar a lâmpada de novo',
#  'Não tenho informações sobre tropas ou sobre o movimento das tribos.',
#  'Eu me pergunto o que Molly colocou nesses tacos?',
#  'Eu não li o resumo do artigo ainda.',
#  'A honestidade é a melhor política.',
#  'Feliz em te conhecer.',
#  'Eu gosto dessa piada.',
#  'No mercado',
#  'Cortando as coisas',
#  'Eu só posso te dizer o que vi.',
#  'Ele de fato encontrou o relógio perdido.',
#  'O menino olhou para o horizonte.',
#  'Mas ele havia encontrado um guia? e não queria perder uma oportunidade.',
#  'Um tolo e seu dinheiro logo se separaram.',
#  'É melhor você começar agora.',
#  'Embora eu não possa me levantar',
#  'Você quer dizer que o discurso que você está escrevendo?',
#  'Então você combinou prazer com negócios!',
#  'Uma equipe de ciclistas trabalhando duro no que parece ser uma moto muito veloz.',
#  'Há peixes deformados naquele lago.',
#  'Quando ele fala em nossa língua, eu posso interpretar o que ele disse.',
#  'Copo com água.',
#  'O pinguim atravessa o gelo juntando-se aos seus companheiros.',
#  'O céu já estava escuro.',
#  'Eles cantaram as mesmas músicas em cada festa.',
#  'Está certo quem vence.',
#  'Benjamin estava comendo tiras de bacon.',
#  'Os banhos romanos são soberbos',
#  'Quatro pessoas estão sentadas em uma rocha em um corpo de água.',
#  'Eu liguei, mas ninguém respondeu.',
#  'Você deveria ficar mais.',
#  'O pai estava cansado do trabalho.',
#  'Ele estava vestido apenas de pijama.',
#  'Uma mulher está bebendo de um canudo verde.',
#  'Você sabe disso?',
#  'Os resultados alcançados estão muito aquém do estado da arte na classificação de imagens.',
#  'Este é um truque para obter sua simpatia.',
#  'Sinto-me grata pelo tempo que passamos juntos.',
#  'Sua voz é tão feliz',
#  'O domínio público e o privado.',
#  'O menino pensou em Fátima.',
#  'Ariana Grande participou de Brilhante Victória.',
#  'Um cachorro atravessa o solo rochoso.',
#  'Ele vagou por um tempo, mantendo as palmeiras do oásis à vista.',
#  'O que é toda essa bagunça?',
#  'Era uma cidade recreativa.',
#  'Eu não queria casar com mais ninguém na cidade.',
#  'Mídia continua a perguntar',
#  'Eu tenho me acostumado com isso uma ou duas vezes.',
#  'quanto custa dez reais em dólares norte americanos',
#  'Você já viu ele?',
#  'Ele pediu um táxi',
#  'Um homem de camisa preta está alcançando acima de sua cabeça.',
#  'Projetar uma interface de ação dedicada',
#  'Como posso dizer que você está em condições de entrar no acampamento?',
#  'Um homem de terno se afasta de um prédio com longas sombras.',
#  'Você faz todas as contratações por aqui.',
#  'Agora a lua está fora.',
#  'Ela espera que seu bolo de aniversário seja rosa, não roxo.',
#  'Eu não cheguei até as sessenta',
#  'Obrigado por ler isso em voz alta.',
#  'Shakespeare nunca disse isso.',
#  'De repente, jogado no grande balde de gelo',
#  'Agradeceram a fartura daquela noite',
#  'O meu teclado está com defeito.',
#  'E a camisola se transformara num belo vestido de casamento.',
#  'Como ela era?',
#  'O som vinha de outra sala',
#  'para manter suas línguas',
#  'Você não leu isso?',
#  'Um menino pequeno vestindo shorts e sem camisa está correndo ao ar livre',
#  'Deve ser algum tipo de piada.',
#  'Havia realmente? Eu acho que? duas ou trezentas pessoas se acotovelam.',
#  'Subconscientemente escolha esquecer',
#  'Você pode pesquisar Milagre na Chuva?',
#  'Verifique o diabetes encontrado',
#  'Quanto é o seu capital nele?',
#  'Seu governo está contando com você.',
#  'Aposto que você não precisa disso.',
#  'Mantenha a organização no programa de área de trabalho.',
#  'Minha revisão do sol é uma estrela.',
#  'Alugue um carro por um dia',
#  'Você come chocolate?',
#  'Você não votou em mim da última vez.',
#  'Mas eu também estava tropeçando porque não conseguia desviar o olhar dessas coisas.',
#  'uma jornada que nunca se cansará',
#  'Como Peter Lovelace conseguiu essa arma?',
#  'A baleia azul é um animal enorme.',
#  'Quantos anos você tem?',
#  'Por favor, não me toque.',
#  'Isso é bom? pensou o inglês.',
#  'Este é o lugar?',
#  'Eu conto vinte pedaços por dia, ok?',
#  'Quais são os filmes animados que estão tocando nas proximidades?',
#  'Inspirado pela letra',
#  'Ele já está encarregado do banco.',
#  'É um momento de grande alegria',
#  'Atitude otimista',
#  'Você quer dizer que você sabe sobre ela o tempo todo?',
#  'Quando a identidade do usuário for aceita pelo servidor?, você será notificado.',
#  'Eu queria subir.',
#  'Isso é um segredo sobre você.',
#  'Uma pequena orquestra de cordas toca em uma igreja onde a multidão assiste.',
#  'Meu irmão Elijah caiu da sua bicicleta.',
#  'Para pegar a ferrovia da cidade para o ônibus',
#  'Por favor nunca jogue pizza de salame fora.',
#  'Eu só estava perguntando.',
#  'Não me pergunte como eu sei.',
#  'Havia vozes levantadas e uma espécie de luta parecia estar acontecendo..',
#  'Eu vou escrever lição de casa na sala.',
#  'Isso é um sistema mecânico sofisticado!',
#  'O discurso do amor está nos olhos.',
#  'Ela encheu novamente o recipiente e foi embora.',
#  'O navio parecia ser construído com alguma forma de exoesqueleto de cromo.',
#  'O estranho falava de coisas que muito poucas pessoas sabiam.',
#  'Você quer uma bolacha?',
#  'Você pode me pegar o filme Terra do Boneco de Neve?',
#  'Houve um baque como a queda de uma grande massa.',
#  'O menino queria pegar a mão dela.',
#  'Remou até chegar na outra margem',
#  'Eu aprendi coisas da ovelha? e aprendi coisas do cristal? ele pensou.',
#  'Essa é uma boa ideia.',
#  'Era melhor que o cheiro dos narguilés.',
#  'O que estava ao seu lado há cinco minutos agora estava do outro lado.',
#  'Eu realmente espero',
#  'Eles gritaram consolo e promessas e voltaram para a cidade novamente para buscar ajuda.',
#  'Três mulheres que se amontoam para aquecer debaixo de um cobertor.',
#  'Ela prometeu sem pensar',
#  'Fazer um handstand precisa de muita prática para aprender.',
#  'E ele não estava se saindo muito melhor.',
#  'E eu disse a Harry que achava que ia ficar entediado até a morte.',
#  'Infelizmente, o período de teste expirou.',
#  'Qualquer que seja.',
#  'O homem senta-se entre bicicletas ao ajustar o pneu em um.',
#  'Era só que ele não conseguia entender o que significava.',
#  'O presidente lutou heroicamente contra tal selvageria.',
#  'Quantidade suficiente',
#  'A atividade era de história, não de português',
#  'Cada personagem tem uma jogada',
#  'Perdi o ônibus de novo.',
#  'Eu acho que eles falam espanhol na Bolívia.',
#  'Isso faz parte do processo de socialização do indivíduo.',
#  'A ejeção de massa coronal da estrela mascarou o sinal.',
#  'Eu pensei que o desaparafusar poderia ser automático.',
#  'Trabalhadores de construções trabalham em uma ferrovia.',
#  'Como está o tempo em Austin, Texas?',
#  'Uma fita fina percorre o meio do campo.',
#  'Ela ensina geografia.',
#  'A neutralidade da rede é fundamental para a liberdade de expressão.',
#  'Um cão e uma pessoa fazendo um curso de agilidade.',
#  'O melhor filme de dois mil e dezoito.',
#  'Duas pessoas caminham por uma calçada entre edifícios.',
#  'O transistor queimou',
#  'Dá uma ideia da temporada.',
#  'Mas eu gosto desse jeito.',
#  'Mas você se importaria de me dizer quem sai?',
#  'Precisamos de mais sabão.',
#  'Bem no segundo andar.',
#  'Eu não vou calar a boca!',
#  'Qual é o seu filme favorito?',
#  'Seu trabalho duro e eficiência no trabalho são conhecidos no campo.',
#  'O primeiro dia passou.',
#  'As garrafas contêm quatro tipos de rum.',
#  'Mas agora os sons dentro pararam.',
#  'E Jesus disse, Sempre eis de comentar teu código.',
#  'Eu acho que talvez seja melhor você.',
#  'Ela salvou a vida de todos os homens naquele transporte.',
#  'O cachorro e o gato eram bons amigos.',
#  'Este é um médico muito poderoso',
#  'Quantas visualizações tem esse clip?',
#  'O trator estava baixando com força.',
#  'Eu acho que vou me juntar ao grupo neste final de semana.',
#  'Sem escolha',
#  'Não consigo pensar em nenhum motivo pelo qual ela foi morta.',
#  'Nós estamos procurando um lugar para tomar café',
#  'Nós fizemos o nosso melhor',
#  'O amor é a força que transforma e melhora a alma do mundo.',
#  'Mas isso me deixou sem nenhum meio honesto de apoio.',
#  'O garoto viu um homem aparecer atrás do balcão.',
#  'É apenas uma questão de dias até o livro ser publicado.',
#  'De Inglês para Português.',
#  'é a versão digital do jornal Correio da Manhã.',
#  'Eu já descrevi a aparência daquele volume colossal que estava embutido no chão.',
#  'Por que você está tão ansioso para chegar ao fim?',
#  'Eu trabalho na construção civil.',
#  'Beba café e coma chocolate',
#  'qual valor há afinal na riqueza, se não o vazio também por ela adquirido?',
#  'Você terá um mau tempo.',
#  'Doutor Estranho.',
#  'Meninos e meninas e música.',
#  'A felicidade fecha os olhos e um acidente os abre.',
#  'A palavra era tão bela',
#  'Então pare de agir como um.',
#  'Windows dez.',
#  'Sobre vida em Marte, eu não sei.',
#  'Tudo o que eles queriam era comida e água.',
#  'O simum explodiu naquele dia como nunca havia explodido antes.',
#  'Eles se tornam parte de tudo...',
#  'Calibração completa.',
#  'Todos são',
#  'Mas esta é uma boa oportunidade para uma oportunidade de educar.',
#  'Por que você está franzindo a testa?',
#  'Foi a Linguagem pura do mundo.',
#  'Pode haver mais chuva no futuro.',
#  'Cenas marcantes.',
#  'E sempre podemos voltar.',
#  'Bruna era professora de matemática.',
#  'Ligue para minha mãe.',
#  'O que você está procurando?',
#  'Um casal de amigos consertando uma bicicleta de cabeça para baixo.',
#  'Como é o clima em Delaware?',
#  'O modelo pode ser inicializado com codificação esparsa.',
#  'Mas os padeiros são pessoas mais importantes que os pastores.',
#  'Pessoas em passeios de gôndola através dos canais de Veneza entre edifícios.',
#  'A Samsung é uma empresa americana?',
#  'Mulher inclinou-se falando no telefone.',
#  'Pessoas no trabalho lendo os procedimentos.',
#  'Eu quero voltar para minhas ovelhas mais rápido.',
#  'Eu posso ajudá-lo!',
#  'Isso não tem nada a ver com isso!',
#  'Eu acho que eles simplesmente não conseguem evitar.',
#  'E aquela outra lua de mel em uma mina de carvão!',
#  'Meu tom indiferente é gentil e gentil.',
#  'Quanta custa essa televisão?',
#  '"""Bem? por que você não vai para Meca agora??"" Perguntou o garoto."',
#  'Preste atenção a este campo',
#  'Os meninos balançam em um balanço verde fora de uma estrutura de madeira velha.',
#  'Estudos clínicos da nova vacina ainda são excelentes.',
#  'No entanto,? era um pouco grande demais para garantia.',
#  'Ele estava deprimido e suicida.',
#  'Mas as luzes são muito bonitas.',
#  'Eu exportei o modelo no formato json.',
#  'O que é isso?',
#  'Cadeiras de garçom são usadas para cair',
#  'Você conhece algum kanji?',
#  'A guerra dizimou um país inteiro',
#  'Duas crianças estão escalando uma parede de pedra.',
#  'As normas de convivência contribuem para criar um ambiente de respeito e tolerância.',
#  'Você deve mostrar que seu método melhora os resultados.',
#  'Me dê a lista de filmes no Santikos Theatres',
#  'O chuveiro está lá dentro.',
#  'O alquimista apagou o círculo na areia e a cobra deslizou entre as rochas.',
#  'Agora pense em como expressar em taiwanês',
#  'Revelando expressão duvidosa',
#  'Foi Linda Keller!',
#  'Um garoto pulando para tocar um dedo do pé na frente de uma árvore.',
#  'Isso não é tão ruim.',
#  'Senhora esperta',
#  'Eu quero ver o Michel Strogoff',
#  'Eu não confio nele.',
#  'Cada local na tela está em uma determinada linha e coluna.',
#  'Tire suas armas.',
#  'Um enorme buraco havia sido feito pelo impacto do projétil.',
#  'Duas crianças estão brincando com um tambor.',
#  'Os peixes devem nadar três vezes: na água, no azeite e no vinho.',
#  'Essa é a primeira vez que você está certo hoje.',
#  'Volte para sentar à esquerda',
#  'Por que você não tenta o Johns Hopkins em Baltimore?',
#  'Eu geralmente assisto à conteúdo na Netflix.',
#  'Emma viu a água-viva.',
#  'Um esquiador com uma jaqueta marrom faz um truque na neve.',
#  'De repente, a porta foi aberta abruptamente',
#  'Definição de veloz.',
#  'O grupo era de fora da cidade.',
#  'Primeira despedida',
#  'Cachorro terá seu dia',
#  'Até a felicidade desaparecerá',
#  'É o que eu quero dizer.',
#  'Isso já faz parte do cotidiano.',
#  'Esse lápis é meu.',
#  'Eles exploraram seus convidados.',
#  'Ela aproveitou sua viagem de fim de semana para o mar báltico.',
#  'Quantas vezes você vai me chamar de?',
#  'Não havia muito ímpeto para terminar nossas tarefas.',
#  'Mas ele teve que seguir em frente.',
#  'O envio falhou!',
#  'Ao nível da comunicação urbana',
#  'Você disse isso para mim também.',
#  'Algumas disposições das emendas',
#  'Eu ouvi um zumbido peculiar vindo do poço.',
#  'Diferentes gotas para pessoas diferentes.',
#  'O inverno passou',
#  'Todos eles dizem que escreveram a carta.',
#  'Meu calendário está cheio.',
#  'Eu sabia que se estivesse me afogando, você tentaria me salvar.',
#  'Qual é o preço do dólar no momento?',
#  'Uma garota é presa a cordas de bungee enquanto a multidão atrás dela observa.',
#  'Estacionamento gratuito no hotel',
#  'Eles queriam salvar o oásis.',
#  'As culturas a serem colhidas são completamente destruídas.',
#  'Caixa de dois homens.',
#  'Apresse-se e vamos sair.',
#  'Ela ergueu a bandeira de pirata.',
#  'Ela deveria estar aqui a qualquer momento.',
#  'O homem negro na camisa quadriculada está jogando o saxofone fora.',
#  'Tinha um diâmetro de cerca de trinta jardas.',
#  'celso conheceu maria no mercado do tio chico enquanto esperavam no caixa',
#  'Foi o que eu fiz antes de me casar com o Charles.',
#  'Alguns caminhantes estão olhando para um mapa.',
#  'Foi o médico aqui?',
#  'A Sra. Jason está no telefone.',
#  'Eles foram para a cozinha na parte de trás do mosteiro.',
#  'A camisa das minhas costas.',
#  'O repórter perguntou três vezes seguidas.',
#  'Demais!',
#  'Ela não respondeu nada.',
#  'De qualquer forma, você tem muitas coisas para fazer.',
#  'Aquele que paga por último nunca paga duas vezes.',
#  'Embora um pouco verde',
#  'Esta bobina mortal',
#  'Somos todos humanos a final',
#  'Como os pesos são calculados?',
#  'Cinco senhoras vestidas em cores vibrantes se divertindo dançando.',
#  'Ele modificou um jogo de t-rex para um evento de Natal.',
#  'Obrigado pela sua colaboração.',
#  'Você tem um lugar para dormir?',
#  'Por favor não me faça.',
#  'Você se importa se eu esperar aqui?',
#  'A festa de aniversário foi uma surpresa.',
#  'O garçom foi até o teclado para destravar a entrada do depósito da adega.',
#  'A faca foi pendurada dentro de sua bainha brilhante.',
#  'Dotada de vários equipamentos para a prática de atividades.',
#  'A vida na encruzilhada é tão frágil',
#  'Marte é quase inabitável.',
#  'Comboio para Otaru',
#  'A saída da vovó',
#  'Imagine se todos saíssem transformando chumbo em ouro.',
#  'Um homem e uma mulher sentada em uma mesa de jogo.',
#  '"""Você me ajudou."" O homem continuou a preparar seu chá sem dizer nada."',
#  'Para ouvir a verdade, você precisa ouvir dois sinos.',
#  'Isso é do governador.',
#  'Qual foi o computador analógico?',
#  'Ele xingou inclusive o juiz',
#  'Eu conheço essa voz em qualquer lugar.',
#  'Eu acho que você esqueceu alguma coisa.',
#  'Isso é chamado de big data.',
#  'Você não terá dificuldade em lê-lo.',
#  'Posso fazer algo Cassie?',
#  'Você não pode entender que?',
#  'Raramente vi uma coleção de métodos simples e pouco motivados.',
#  'Um uísque é o final perfeito para o meu dia.',
#  'Quão triste é ouvir seus ouvidos.',
#  'Parece ser uma piada agora.',
#  'Abra o Netflix.',
#  'Descubra a direção futura',
#  'Saiu um novo episódio ontem.',
#  '"""Não sei?"" foi a resposta."',
#  'Os habitantes da cidade eram unidos.',
#  'Você não entende francês?',
#  'Uso efetivo da terra',
#  'Se você quiser sentir',
#  'Apenas perdendo tempo aqui',
#  'Dois cães em um campo olhando um para o outro.',
#  'Um homem está vestindo uma camisa vermelha e colete.',
#  'Você não vai me deixar ficar aqui.',
#  'Como eu sei?',
#  'Meu químico me disse para tomar esses comprimidos antes de comer.',
#  'Este não é o meu quarto.',
#  'Que dia você pode chorar com confiança?',
#  'Para incentivar novos empreendimentos com potencial internacional',
#  'Eu não cheguei até os trinta e quatro.',
#  'Bens com preços são sempre os mais caros.',
#  'Pode ajudar',
#  'Se você tiver algum desejo ou tiver alguma dúvida',
#  '"""Vá e fale com os chefes tribais?"" disse o motorista do camelo."',
#  'Eu não queria atirar nele.',
#  'Minha chinchila come pão.',
#  'E ele deu ao menino sua bênção.',
#  'O oxigênio é essencial para a vida na terra, assim como a água.',
#  'Mas o que eu poderia fazer?',
#  'É bom, pois assim economiza um pouco mais',
#  'Mas aqui está a parte mais engraçada de tudo.',
#  'Você pode procurar o álbum de Bireswar?',
#  'A comida rápida é conveniente, mas muitas vezes não é saudável.',
#  'O causo era complicado.',
#  'Porque eu não amo ele.',
#  'Várias pessoas brincam e relaxam na praia.',
#  'Vá para a estação depois de comprá-lo.',
#  'Onde é essa cidade?',
#  'Certifique-se de ter os drivers mais recentes da Nvidia instalados.',
#  'O amor é o mais importante',
#  'Coletando problemas após um semestre',
#  'Apenas o treinador ainda está em treinamento',
#  'Uma figura fantasmagórica apareceu.',
#  'Eu posso ter dormido demais.',
#  'Eu pensei que era Peter Parker.',
#  'A massa de um corpo.',
#  'A melhor rota talvez não seja essa',
#  'Nós temos a possibilidade de sucesso',
#  'Equipe de construção aguarda passagem pelos portões de um canteiro de obras.',
#  'O menino aproximou seu cavalo.',
#  'O bom e velho feijão com arroz',
#  'Capaz de cruzar o termo',
#  'Ligue para o meu irmão.',
#  'Afinal, é para isso que existe o sindicato.',
#  'Tempero de arroz.',
#  'Envie as outras pessoas para dentro.',
#  'Eles foram para Denver, Colorado ontem.',
#  'O clima era cinza.',
#  'Também é difícil encontrar',
#  'Eu acho que Jamie fez isso.',
#  'Ele viu o menino aparecer do outro lado das dunas.',
#  'A reportagem era enganosa',
#  'Eu sou o pai dos dragões.',
#  'Mamãe realmente quer',
#  'Não vá longe demais com dinheiro',
#  'Eu finalmente tenho dinheiro suficiente? e todo o tempo que preciso.',
#  'Nós pagaremos todas as suas despesas.',
#  'Um surfista masculino pega um pouco de ar de uma grande onda.',
#  'Que alegria ter um cachorro na vida?',
#  '"""Quais são essas coisas?"", ele perguntou."',
#  'A Apple é doce e barata',
#  'Um homem vestindo uma jaqueta preta, olhando para baixo.',
#  'Que filmes estão tocando no cinema mais próximo',
#  'Diferença entre front end e back end',
#  'Vamos embora.',
#  'Eu finalmente fui sozinha e voltei esta manhã me sentindo feliz e revigorada.',
#  'Alguém nos cortou!',
#  'Alguém bateu a porta vigorosamente',
#  'Apague as luzes.',
#  'Quais aspectos do poema você gostou?',
#  'Um homem está a serrar um pedaço de madeira.',
#  'Ouça o luto da mãe',
#  'Diga-me sua localização, sim?',
#  'Viva e aprenda.',
#  'Porque o cristal estava sujo.',
#  'Um menino de short preto está pulando no oceano.',
#  'Diretor disse que ele foi forçado',
#  'Os agricultores precisam confiar no dia para comer',
#  'Toque alguma música do Green Day.',
#  'Sai de lá.',
#  'A partida de futebol.',
#  'Evidentemente, somos o show de chão.',
#  'Eu recebo trinta dólares por semana.',
#  'Quem inventou o computador?',
#  'Então o velho começou a inspecionar a ovelha e viu que ela era manca.',
#  'Silêncio extraordinário',
#  'Eu olhei para o cilindro novamente e fiquei completamente apavorado.',
#  'Assim como nos velhos tempos.',
#  'Vá ao Museu de Arte Contemporânea para ver a exposição',
#  'O grande cachorro preto está correndo na areia perto da praia.',
#  'Um homem se senta em uma cadeira e verifica seu telefone enquanto relaxa.',
#  'Minha mente correu sobre as possibilidades de seu conteúdo.',
#  '"""O que é que você está procurando?"" perguntou o antigo comerciante."',
#  'O Neymar Jr é um famoso jogador de futebol brasileiro.',
#  'Deve haver algum jeito.',
#  'Porque eu não posso mais comer.',
#  'A nostalgia não é o que costumava ser.',
#  'Soluções locais devem ser preferidas para soluções em nuvem em muitos casos.',
#  'De onde veio então?',
#  'Um homem vestindo uma camisa rosa está tocando violão e cantando',
#  'Uma pessoa nativa fazendo uma dança.',
#  'As três crianças estão segurando guarda-chuvas e assistindo a cerimônia na chuva.',
#  'A barreira de plástico se quebrou.',
#  'Nós sabemos o que você está fazendo.',
#  'Veja as capas dos jornais e revistas de hoje completamente grátis.',
#  'Uma pequena universitária de uma escola de jornalismo!',
#  'Há um melão ao lado dele.',
#  'Eles querem voltar para o hotel',
#  'O negócio deles está indo bem',
#  'Todos se lembram',
#  '"""E é isso que seu filho disse,"" o anjo disse ao homem."',
#  'O sol está descendo a montanha.',
#  'Linus é conhecido por sua linguagem clara e explícita.',
#  'Ele estava em Juneau, no Alasca, no mês passado.',
#  'Ele tinha aproximadamente a mesma idade e altura que o menino.',
#  'Não há cortesia em tudo.',
#  'Me dê aquela ligação no fio de Patrick!',
#  'O resto de vocês entra aqui e motim!',
#  'Um homem e uma criança andando lá fora.',
#  'Você viu o jardim que levou o jardineiro mestre dez anos para criar?',
#  'Um erro ocorreu.',
#  'A casa marrom estava pegando fogo no sótão.',
#  'Seu compromisso foi alterado.',
#  'Comece a bater aquela máquina de escrever.',
#  'Isso sempre ajuda a aprender algo novo e excitante.',
#  'Ela e o juiz são como carne enlatada e repolho.',
#  'Volte novamente em algum momento.',
#  'Maior empresa',
#  'O segredo está aqui no presente.',
#  'O xadrez é uma simulação da guerra.',
#  'Agricultores rurais trabalhando duro na terra',
#  'Eu ouvir falar muito sobre Thomas Jefferson.',
#  'O menino sentiu uma pontada no coração pensando na filha do comerciante.',
#  'As crianças participam de um evento esportivo.',
#  'Um cão tenta pegar um grande pneu com a boca.',
#  'Desde então, não consegui outro.',
#  'Vá para a sua dança!',
#  'Desligar.',
#  'Pensando que sou criança',
#  'Mas você vai amar ela? e ela vai devolver o seu amor.',
#  'O artista decora a parede com um teste padrão azul e branco original.',
#  'Uma maçã é dourada de manhã, prata do meio dia e chumbo à noite.',
#  'O que escolhemos tem que ser a pessoa média típica.',
#  'O céu no oeste é tingido de vermelho alaranjado.',
#  'O que é Comunidade.',
#  'Uma brisa começou a soprar.',
#  'O encantamento foi escrito em itálico.',
#  'Design colocado ao redor',
#  'Ao enumerar as pessoas com quem ela queria conversar com?, ela se acalmou.',
#  'Realmente há um oitenta e sete',
#  'A mesa e as duas cadeiras estavam pintadas de bege.',
#  'ao treinar um modelo todos os fonemas culturais precisam ser avaliados',
#  'os dois bebês usando óculos de olho',
#  'Uma tarde? um de seus servos adoeceu? e parecia que ele iria morrer.',
#  'Você não lembra da casa que eu te prometi?',
#  'Uma noite? o pai teve um sonho.',
#  'Primeiro?, você precisa instalar uma extensão que rotule elementos clicáveis na página.',
#  'Dê-lhes um pouco de terceiro grau.',
#  'Mas ninguém realmente a viu morrer.',
#  'Quanto mais você morar, mais você vê.',
#  'Eu não vou deixar você.',
#  'O trabalho científico é difícil.',
#  'Quais são as novidades para hoje?',
#  'Ele grita',
#  'Como você está fazendo?',
#  'O garoto gostou do presente dele.',
#  'Na minha mente',
#  'Eu não consegui descobrir o motivo.',
#  'A exibição estava abaixo do esperado.',
#  'Um artista está trabalhando em uma escultura em uma oficina.',
#  'Deve haver um novo modelo operacional',
#  'Há um homem correndo em uma estrada.',
#  'A verdade sempre tem uma cabeça comprometida.',
#  'Quando eu era criança, o Ano Novo Chinês estava muito frio.',
#  'Tropeçou no chão e não recuou',
#  'Apenas um compartimento está sobrecarregado',
#  'A ideia o assustou.',
#  'Em um estado muito chocado',
#  'Fiquei chocado com o que você disse',
#  'Um homem olha para uma mulher enquanto ela mostra a mão.',
#  'Você deve ver o outro cara? especificamente? como ele é bom em lutar.',
#  'Uma pessoa está falando ao ar livre em um microfone.',
#  'Um de nós vai para a cadeia!',
#  'Não relacionado à codificação?, mas os codificadores de mãos livres também precisam se divertir.',
#  'Três vivas para Aden Christopher.',
#  'Eu os perdi na quinta-feira passada.',
#  'Agora olhe o que você fez.',
#  'Uma pessoa corre em uma competição na frente dos espectadores.',
#  '"""Para lhe mostrar uma das lições simples da vida?"", respondeu o alquimista."',
#  'O cérebro humano ainda não é totalmente compreendido.',
#  'Ele saiu sem se despedir do comerciante de cristal.',
#  'Ele estava se sentindo melhor',
#  'três pacotes de trigo para três tigres tristes',
#  'Dobrou nossa circulação.',
#  'Não será muito caro.',
#  'Ela tem mais quatro irmãs e dois irmãos mais novos.',
#  'Você não tem filhos.',
#  'Vou tirar meu braço disso.',
#  'Como um velho cavalo de fogo.',
#  'Um homem de camisa azul está segurando uma xícara',
#  'Talvez tenha sido ontem.',
#  'O menino caiu de joelhos e chorou.',
#  'Mostre me imagens de ovelhas pulando.',
#  'Três mulheres descendo um túnel enquanto um homem sentado as observa.',
#  'Henderson entrou na estação de trem para telegrafar as notícias para Londres.',
#  'Não há nada mais bonito que o amor.',
#  'A editora era desconhecida.',
#  'Aquele maldito rato podia sentir minha raiva.',
#  'Quantos quilos?',
#  'Pessoa com dois bastões de esqui que esquiam abaixo uma colina nevada',
#  'Uma grande humanitária e a melhor amiga que os Jessie Bakers têm.',
#  'Eu não o culpo.',
#  'Ele se interessou por pintar? desenhando? e fotografia antes de encontrar sua verdadeira paixão.',
#  'Desligue isso.',
#  'Ajude meu amigo, o Sr. Richard.',
#  'Você gosta de todos os garotos.',
#  'Você vai jogar uma pedra?',
#  'Guia de instruções.',
#  'Eu pensei que você ia me ensinar algumas das coisas que você sabe.',
#  'A verdade não poderia ser dita impunemente.',
#  'Mãe atravessando a rua com o filho dela.',
#  'Você tem minha massa?',
#  'Ele sabe que ela está com raiva.',
#  'Você vale seu peso em ouro.',
#  'Isso é frequentemente devido à sua natureza.',
#  'Volte e compre dois pacotes.',
#  'Três ciclistas passeiam por um caminho cercado perto de bosques.',
#  'Ela deve me odiar? por que ela não iria?',
#  'Meu amigo comprou todas as outras ovelhas imediatamente.',
#  'Eu estou seguindo meu destino.',
#  'Amanhã vai chover?',
#  'Acho que você está certo.',
#  'Tem certeza que esta é Claire.',
#  'Ela fala muitas vezes com aspereza',
#  'Minha amiga ia se casar e me pediu para ser sua dama de honra.',
#  'Eu espero que você seja bom!',
#  'Que tal essa verificação?',
#  'Ela removeu cuidadosamente a evidência da embalagem.',
#  'Participar ativamente de reuniões de bairro',
#  'Depois de terminar o assunto',
#  'Marty ajudou a capturar a ponte Remagen.',
#  'É por isso que estou aqui no meio do deserto.',
#  'Sempre faça uma pergunta objetiva.',
#  'Compramos uma galinha na feira',
#  'A menina asiática nova reza por uma vela.',
#  'Parece que sempre? está sempre escuro aqui.',
#  'É LeviÔsa, não LeviosÁ',
#  'Ser criticado é pensar demais',
#  '"""Mas há uma guerra tribal?"" o garoto reiterou."',
#  'Grátis é a palavra mágica que todos gostamos de ouvir.',
#  'A Letônia e a Estônia estão entre o Mar Báltico e a Rússia.',
#  'Um punhado de nuvens pairava no ar azul.',
#  'Silêncio vale ouro.',
#  'Voleibol de praia do jogo de três mulheres.',
#  'Houve um acidente.',
#  'Em outros momentos? em um momento crucial? Facilito as coisas acontecerem.',
#  'Vovó se senta na porta da cozinha',
#  'Minha mãe me levou para ver um médico.',
#  'Eu fui a sua casa uma centena de vezes.',
#  'É quando ele estará em segurança e nem um minuto antes.',
#  'Os alunos tingem suas cores.',
#  'Acontece que isso é mais fácil do que você poderia esperar.',
#  'Riqueza sem fim',
#  'Você pode imaginar esbarrar em uma carga de policiais?',
#  'Esta cerveja foi fabricada na Alemanha, mais especificamente na Baviera.',
#  'Insira seu cartão para se identificar.',
#  'Volte e ajude todos',
#  'Por que você não está com ele?',
#  'Eles estavam escondendo ele.',
#  'Um pontapé na bunda é um passo em frente.',
#  'Esses bandidos recebem o que merecem.',
#  'Mas? se você puder? tentar tomar suas próprias decisões.',
#  'Um homem sem camisa com tatuagens está trabalhando em andaimes.',
#  'Você apostou seu baixo dólar que nós faríamos!',
#  'Isso não acontece com qualquer um!',
#  'Todos estão de pé no prédio? esperando para entrar.',
#  'Para continuar sua busca pelo tesouro, ele teve que abandonar Fátima.',
#  'Laranja verde.',
#  'Aprenda a julgar por si mesmo',
#  'Eu vou te ver depois.',
#  'Além da criptografia?, ele também pode ser usado para autenticação.',
#  'O aplicativo está realmente com um bug.',
#  'Toda a riqueza vem dos bolsos.',
#  'Eu estive lá',
#  'Amy é um gênio em pesquisa.',
#  'Por que as pessoas têm idéias realmente boas no chuveiro?',
#  'Bem-vindo a todos para praticar juntos',
#  'O cachorro pulou a cerca de dois metros e meio.',
#  'Adicione esta música à minha playlist.',
#  'Centenas de observadores viram a chama naquela noite e na noite seguinte.',
#  'Ela vai perder a cabeça quando descobrir.',
#  'Imediatamente sentiu que o Sr. Ashby lhe fizera um grande desserviço.',
#  'Uma mulher loira em um bar olha por cima do ombro.',
#  'Os paramédicos retiraram o desfibrilador para reanimar o motociclista.',
#  'As pessoas olham ao redor da geleira',
#  'O capitão mandou içar as velas.',
#  'O café já foi entregue na copa',
#  'Você vai confiar nele que ele faz certo?',
#  'Não podemos deixar que o Chronicle nos dê risada!',
#  'E hoje você não escapa.',
#  'Você se mudou e mudou-se antes.',
#  'Eu não vou falar sobre eles.',
#  'Depois de se familiarizar com isso, você vai querer usá-lo para tudo.',
#  'Trabalho em progresso.',
#  'Mas um deles agarrou o menino e puxou-o para fora do buraco.',
#  'Era tímido, mas determinado',
#  'Você pode me emprestar sua bicicleta por um tempo?',
#  'A necessidade estava clara',
#  'Eu tive um memorando da Art hoje.',
#  'A mentira tem perna curta.',
#  'A maionese é feita a partir de ovos, azeite, vinagre e mostarda.',
#  'Crianças asiáticas correm por um longo corredor cinza.',
#  'No instituto de pesquisa, eles têm um microscópio eletrônico.',
#  'Os infiéis tinham um olhar maligno sobre eles.',
#  'Ele não é educado.',
#  'Mas eu vou fazer você e Maria uma proposta de negócios.',
#  'Nós temos que fazer alguma coisa!',
#  'Por que eu deveria me privar da minha vida?',
#  'E o odor dos animais tornou-se um pouco mais tolerável.',
#  'Projeto de construção',
#  'Todo mundo está morrendo',
#  'Você olha para mim como se não me conhecesse.',
#  'Continuar a perseguir a história dos sonhos empreendedores',
#  'Quantas camadas precisamos?',
#  'Ele sabia como cortá-los e como abatê-los.',
#  'Uma criança vestindo uma jaqueta vermelha detém uma borboleta no dedo enlameado.',
#  'Vicky queria não fazer um espetáculo de si mesma.',
#  'Adicionar esta música tomoyasu hotei à minha playlist de concentração',
#  'Aprenda bem todo o conhecimento',
#  'Terra assada.',
#  'E Jesus disse, chamarás isto de bolacha e não de biscoito!',
#  'A aparência rica',
#  'A sensualidade dela era notável.',
#  'inclusive palavras de aparência esdrúxula',
#  'Meus fones de ouvido são muito ruins.',
#  'Seu dentista ligou ontem.',
#  'Viu algum fantasma?',
#  'Eu vejo o que você quer dizer.',
#  'Reduza o risco de câncer',
#  'Canal e Armazém de Otaru',
#  'Teclado, mouse e monitor.',
#  'A bíblia cristã tem visto muitas mudanças ao longo da história.',
#  'Você sabe falar japonês?',
#  'Realmente elogios, vale a pena comprar',
#  'Saberemos quando chegar ao fim',
#  'Mas não deixe isso fora de sua vista.',
#  'Eu sinto calor no meu coração.',
#  'Sua conta ainda está aqui.',
#  'Mulher está procurando algo.',
#  'Era quase como se sua vida tivesse sido apagada.',
#  'Eu não posso ajudar minha amada neta.',
#  'Eu não sei pegar o ônibus.',
#  'Isso dá uma ideia do que estou enfrentando.',
#  'Esse é o seu bebê?',
#  'Uma seção da estrada de Zhongzheng, distrito de Danshui, cidade nova de Taipei',
#  'Eu tenho que descobrir uma maneira de sair dessa coisa!',
#  '"adicione Black Yankee Rock interpretado por Pop Punk\'s Not Dead na minha playlist"',
#  'Eu sinceramente não me lembro da última vez que recebi um e-mail pessoal.',
#  '"""Eu não gosto muito de mudar?"" ele disse."',
#  'O menino ouviu em voz baixa.',
#  'Não havia empatia por ela agora.',
#  'Eu tenho que começar minha entrevista.',
#  'Ele atuou em vários filmes.',
#  'Vamos contribuir com essa causa.',
#  'Para mim, existem metas estabelecidas.',
#  'Para quem você está ligando agora?',
#  'A história do Brasil é antiga.',
#  'Ele se aproximou da massa e ficou surpreso com o tamanho e a forma.',
#  'Você pode citar algumas empresas de tecnologia japonesas?',
#  'Vá para a cidade de carro e compre remédios de volta.',
#  'O futuro é agora.',
#  'No entanto, cada um sentiu seu coração bater um pouco mais rápido.',
#  'Eu nunca percebi o quão alto é o povo norueguês.',
#  'Devo anunciar-lhe?',
#  'Celebrações ecoaram pela terra.',
#  '"""Eu tive o mesmo sonho duas vezes?"", disse ele."',
#  'Um cão marrom e branco entra na água ao olhar para trás.',
#  'Não faça amanhã o que você poderia fazer hoje.',
#  'Eles eram conhecidos como videntes? e eram mantidos com medo por mulheres e idosos.',
#  'Sua conexão com a internet era muito lenta.',
#  'Eu estou no rosa da condição.',
#  'Nós só temos quatro pessoas',
#  'Deixe-me emprestá-la primeiro.',
#  'Eu nunca tive essa ideia.',
#  'Uma moça fica ao lado de desenhos de uma artista de caricatura.',
#  'Então eu só tenho uma hora para me vestir.',
#  'Você não pode tirar sangue de uma pedra.',
#  'A ação ainda é suave',
#  'O que você tem medo de Melissa?',
#  'Ele realmente era um rei sábio.',
#  'Você já sabe sobre alquimia.',
#  'por parte dos Estados Unidos e por parte da União Soviética.',
#  'Não é possível solicitar assistência',
#  'Havia o suficiente para comprar muitas armas.',
#  'Conheça as tendências e aplicações futuras',
#  'Uma criança senta-se em frente a um prato de melancia e morangos.',
#  'Pessoas em uma aula de kickboxing.',
#  'Então apenas tente',
#  'Mesmo que as ovelhas não me ensinassem a falar árabe.',
#  'Ele estará pronto a tempo.',
#  'Eu te imploro para não fazer isso.',
#  'Mas, confesso que estou sem coragem',
#  'Um conceito assustador ocorreu a Jennifer.',
#  'Ela deveria descer e pegar você.',
#  'Empresa de catering',
#  'Era uma forma oblonga.',
#  'Para mim é difícil.',
#  'O animal escapou da armadilha.',
#  'duas mulheres asiáticas andando na frente de uma porta verde',
#  'E um milhão e uma outras coisas.',
#  'Quando ela entrou na pista de dança, todos na boate estavam olhando para ela.',
#  'Palavras boas não maculam o repolho.',
#  'A perda de uma pessoa é o lucro de outra pessoa.',
#  'Mas o inglês estava exultante.',
#  'Eu faço o melhor que posso para ajudar.',
#  'Você pode ler tudo sobre isso nos jornais de lá.',
#  'Você tem certeza de que está confortável?',
#  'Você não sabe que a menina está muito doente?',
#  'Em que ano essa música foi lançada?',
#  'Eu estou acostumada com o chefe.',
#  'Mas você tem que me deixar em paz.',
#  'Criminosos choram por isso.',
#  'Satã sabe disso.',
#  'Eles foram inspirados por esse desastre para nunca deixar acontecer de novo.',
#  'O asfalto dificulta o escoamento da água.',
#  'O que você quer dizer com isso?',
#  'Quanto custa esse notebook?',
#  'Licorice é um alimento preto mastigável.',
#  'O menino pensou no comerciante de cristal.',
#  'Coloque sua confiança em Deus',
#  'Todos eles se encontraram durante o expediente.',
#  'Ele é bem jovem para esse trabalho.',
#  'Um alpinista com um capacete branco está repelindo.',
#  'O medo é frequentemente a causa da violência.',
#  'Equipe de busca e resgate de vários municípios e cidades',
#  'Em vez de fazer tudo no mundo',
#  'Mas as mãos de Fátima seguraram as alças de seu jarro.',
#  'O pai dela está muito preocupado com ela.',
#  'Eu gostaria de tomar um banho.',
#  'O menino levou-os para o penhasco onde estivera no dia anterior.',
#  'Eu acho que a tradução automática vai melhorar com o tempo.',
#  'Às vezes me sinto entediado',
#  'Muitos pastores passaram por? vendendo sua lã.',
#  'Que horas são em Londres?',
#  'Ele pausou? e seus olhos ainda eram hostis.',
#  'Como eles conseguiram improvisar em tão pouco tempo? ela nunca saberá.',
#  'Derretido no ar fino',
#  'O céu estava claro.',
#  'Utilizamos cookies para melhorar a experiência do utilizador, personalizar conteúdo e anúncios.',
#  'Aplicação de aconselhamento para vários incentivos',
#  'Ela é aquela a quem todo mundo vende coisas.',
#  'Receita de bolo de abacaxi.',
#  'Alegria compartilhada é alegria dupla O sofrimento compartilhado é apenas meio pesar.',
#  'Não precisava ter dito algo tão rude',
#  'A morte não muda nada? o menino pensou.',
#  'Faça uma busca por artistas nacionais.',
#  'As raposas são criaturas realmente inteligentes.',
#  'Você também é claro sobre si mesmo',
#  'Vá agora e volte depois.',
#  'Os homens estão andando descalços em uma corda bamba.',
#  'Eu não me importo se ela fez ou não.',
#  'Não pode salvar-se primeiro, então é ainda menos provável que salve os outros',
#  'Peça uma pizza.',
#  'Tia Tiffany e caixa de banco na janela.',
#  'Eu já sei que deve haver semelhanças.',
#  'O estudo da Antropologia.',
#  'Uma vez ao ladrão? e uma vez ao geral.',
#  'Seu coração apertou? como se seu peito tivesse subitamente comprimido.',
#  'Para onde vais?',
#  'Coloque um adesivo de tatuagem de primavera no braço',
#  '"""Bem? normalmente eu aprendo mais com minhas ovelhas do que com livros?"" ele respondeu."',
#  'Isso implica que eu não posso mais jogar badminton?',
#  'O menino estava ficando irritado.',
#  'Mister Turner não ficará feliz com isso.',
#  'Eles estavam cansados.',
#  'Toque alguma música do Michael Jackson.',
#  'Esportes? música? culinária e outros tópicos são abordados.',
#  'Todos os dias para encontrar esperanças saudáveis',
#  'Encontre a direção de forma mais eficaz',
#  'O coração do menino começou a falar de medo.',
#  'Abaixo está uma carta que chegou à minha mesa esta manhã.',
#  'Auto-culpa não pode dar às crianças algo melhor',
#  'Um homem com cabelo escuro e curto está soldando.',
#  'Muitas mãos ajudam a fazer o trabalho.',
#  'Este suéter de lã está coçando.',
#  'Deixar nostalgia',
#  'Nós podemos ser mapas uns dos outros',
#  'John e Thomas estavam na mesma sala de aula.',
#  'Programador Web.',
#  'Duas almas solitárias podem acompanhar',
#  'Testemunhas relatam um assassino caucasiano violento equipado com coquetéis Molotov.',
#  'Não tenho tanta certeza de como me sinto sobre os códigos de vestimenta.',
#  'Uma criança pequena que está em um círculo branco em um passeio.',
#  'Uma mulher cobrindo os olhos em um parque como o dia chega ao fim',
#  '"""Eu não precisava perder meu tempo só por esse?"" ele disse."',
#  'Soda tem muito açúcar.',
#  'Virá em um dia, de um jeito ou de outro.',
#  'Para ganhar dinheiro',
#  'Nós vamos carregar a mesa.',
#  'Então suponha que você me dê o dinheiro.',
#  'Espero que o batimento cardíaco não seja mais urgente.',
#  'As prateleiras estavam vazias de geléia ou bolachas.',
#  'Quem eu veria em relação ao retorno do dinheiro do governo roubado?',
#  'Eu achei a fase de compressão problemática.',
#  'Fiquei desapontado com este volume inanimado.',
#  'Eu não vou te deixar.',
#  'As pessoas estão pegando pratos de fogo.',
#  'Como foi seu dia',
#  'A fumaça do tráfego era insuportável.',
#  'O time Coreano se saiu bem nesse campeonato.',
#  'Deixou um rastro esverdeado que brilhou por alguns segundos.',
#  'Cultura pop popular',
#  'Não há mais bilhetes para a esquerda.',
#  'Você não disse a ela?',
#  'O que você disse há um minuto atrás?',
#  'Isto é para as crianças comerem.',
#  'O oxigênio é apenas para ajudá-lo até que o médico chegue aqui.',
#  'Todo mundo já ouviu falar do problema do ovo de galinha.',
#  'Ela tem sessenta yuan',
#  'Algo é o problema com o papai.',
#  'Bem, eu não sei bem o que dizer.',
#  'Ele subiu? e fez o caminho de volta para as palmeiras.',
#  'A União Europeia tem sido frequentemente criticada pelos seus regulamentos.',
#  'Ouvi dizer que é o prêmio mais confiável do mundo.',
#  'Havia trinta meninas no campo de futebol.',
#  'Fortaleza, Ceará.',
#  'Ela permitiu que ele a guiasse pela calçada.',
#  'Os documentos comprovativos devem ser revistos e mantidos',
#  'Você não acha que eu vou contar!',
#  'O primeiro termo passou um ano',
#  'Você fica fora disso.',
#  'Vamos montar um bazar em breve',
#  'Já encontrado',
#  'Então saia daqui.',
#  'Paula e Maria eram irmãs.',
#  'Você viu a foto dele na capa do Tempo?',
#  'Boris, o leão, chorou como um burro.',
#  'Queremos vender botas artesanais de chukka naquele caminhão de comida.',
#  'Mas não foi.',
#  'Desculpe? o período de teste expirou.',
#  'O cão do Collie escava na areia.',
#  'A única sombra era a dos poucos pinheiros espalhados.',
#  'Você não compara diretamente aos métodos de última geração existentes.',
#  'Este é o prefeito.',
#  'Várias pessoas estão sentadas do lado de fora de um prédio.',
#  'Mas todo mundo e sua tia Lilian passaram por essa bolsa.',
#  'Em breve vamos falar com o prefeito.',
#  'Eu quero voltar ao Guanghua Mall às cinco horas.',
#  'Um cão bronzeado persegue um cão branco através da grama frondosa',
#  'Eu achei que a enfermeira era muito poderosa.',
#  'Estavam alinhados em fila dupla',
#  'Um menino empurra outro em um balanço.',
#  'Ele ligou o microfone no momento em que a galinha estava pronta para gritar.',
#  'Fede depois que o mercado se retira',
#  'Muito obrigado!',
#  'Não havia absolutamente nenhuma razão para ela anunciar para toda a empresa.',
#  'As árvores estavam no alto do morro',
#  'Eu me sinto tão bem que eu poderia cuspir.',
#  'Coloque a energia da sua vida no projeto de reconstrução',
#  'E agora eram apenas quatro dias antes que ele voltasse àquela mesma aldeia.',
#  'Ele tinha assumido que ele logo voltaria para suas ovelhas.',
#  'Meu gato deitado lá? absorvendo a luz do sol.',
#  'Eles formaram montes que são visíveis a uma milha e meia de distância.',
#  'Esta manhã encontrei uma calculadora gravada no meu Wii.',
#  'Eu preciso ir para a sala de emergência.',
#  'A televisão pifou',
#  'Servos iam e vinham com bandejas de prata carregadas de especiarias e chá.',
#  'A expressão enigmática permanecia.',
#  'Acima de tudo',
#  'Para encontrar o tesouro? você terá que seguir os presságios.',
#  'O que está acontecendo lá?',
#  'Feche a porta quando sair',
#  'Internet banda larga.',
#  'O oásis é neutro.',
#  'Essa temporada está muito fraca.',
#  'Depois de quase um ano de engenharia',
#  'Ameaçando quebrar seu pé',
#  'Agora suba as escadas e veja o que a pequena Christina quer.',
#  'Você faria algo assim?',
#  'Não até a lua estar alta, o alquimista apareceu.',
#  'Acabei de dizer que estava ocupado com o cachorrinho.',
#  'Estamos olhando para isso agora.',
#  'Ele abriu o pacote? e enfiou em um sanduíche.',
#  'Não se atreva a ser civil comigo!',
#  'E eu tenho medo que a gente queira de volta.',
#  'Natural e vívido',
#  'Fátima apareceu na entrada da tenda.',
#  'Na época de seu prédio, as paredes eram consideradas impenetráveis.',
#  'Foi imediatamente aparente.',
#  'Eu tenho o dinheiro que preciso para comprar minhas ovelhas.',
#  'Poderia ficar muito pior.',
#  'Pare.',
#  '"""Adeus?"" disse o menino."',
#  'Acho que vou migrar para o Ubuntu em breve.',
#  'Vale a pena considerar',
#  'Albert Einstein.',
#  'Por que nós temos que ter todas essas crianças?',
#  'Os traços eram bem definidos.',
#  '"""Eu quero te contar uma história sobre sonhos?"", disse o alquimista."',
#  'Se não houver muito vento? podemos nadar no mar.',
#  'Nem todas as partes estavam na Alemanha e no Japão.',
#  'O filme foi muito bom, ele disse a um amigo.',
#  'Vamos assistir algum filme do Dwayne Jonhson, o The Rock hoje.',
#  'Três âncoras estão rindo enquanto no set.',
#  'Ele não olhou para cima.',
#  'Mas não deixe que ele te interrompa.',
#  '"""Eu tive que testar sua coragem?"", disse o estranho."',
#  'Preservando suas memórias',
#  'Mas essa é a cadeia!',
#  'Nós olhamos o tempo',
#  'Não, não pode desistir',
#  'Um homem de paletó bege está andando sob uma ponte escura.',
#  ...]

# %%
tokenized_sentences = []
segmentss = []
space = tokenizer.IdToPiece(5)

# specifically for zh-CN
# pattern = ",|\?|・|\u3002|\uff1f|\uff01|\uff0c|\u3001|\uff1b|\uff1a|\u201c|\u201d|\u2018|\u2019|\uff08|\uff09|\u300a|\u300b|\u3008|\u3009|\u3010|\u3011|\u300e|\u300f|\u300c|\u300d|\ufe43|\ufe44|\u3014|\u3015|\u2026|\u2014|\uff5e|\ufe4f|\uffe5" + punctuation
# for sent in sentences:
#     tokens = tokenizer.EncodeAsPieces(sent)
#     segments = []
#     for idx, token in enumerate(tokens):
#         if token != space and token not in pattern:
#             segments.append((idx, idx))
#     tokenized_sentence = []
#     for seg in segments:
#         tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

#     segmentss.append(segments)
#     tokenized_sentences.append(tokenized_sentence)

# for other languages
def skip(token, punctuation, space):
    if token.startswith(space):
        token = token[1:]
        if token == '':
            return 1
    for c in token:
        if c not in punctuation:
            return 0
    return 1

# punctuation = '!"#$%&,.:;?'
for sent in tqdm(sentences):
    tokens = tokenizer.EncodeAsPieces(sent)
    segments = []
    last = -1
    for idx, token in enumerate(tokens):
        if token.startswith(space) or token in punctuation:
            if last != -1 and last <= idx - 1:
                segments.append((last, idx - 1))
            last = idx + (token in punctuation)
    if last < len(tokens):
        segments.append((last, len(tokens) - 1))

    tokenized_sentence = []
    for seg in segments:
        tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

    tokenized_sentences.append(tokenized_sentence)
    segmentss.append(segments)

# %%
print(*tokenized_sentences[10:20], sep='\n')
# Out:
# ['收到', '许多人', '指控', '政府', '死', '者', '与', '被', '拘留', '者', '家属', '提出', '抗议', '并', '威胁', '该', '国', '的一些', '人', '权', '护', '卫', '者']
# ['为了', '迈', '向', '环球', '小姐', '而', '努力', '不懈', '日', '夜', '都', '十分', '憧', '憬', '的', '女', '优', '幸', '田', '真理', '子']
# ['果', '敢', '的', '杨', '氏', '土', '司', '原', '为', '兴', '达', '户', '土', '目']
# ['然而', '告知', '旁', '人均', '不', '被', '重视']
# ['该', '网站', '的公司', '还', '开拓', '研究', '服务', '并', '预测', '电影', '的', '可能', '收入']
# ['默', '特', '尔', '敦', '是', '位于', '美国', '加', '利', '福', '尼亚', '州', '洪', '堡', '县', '的一个', '人口', '普', '查', '指定', '地区']
# ['查', '茨', '沃', '思', '是一个', '位于', '美国', '乔治', '亚', '州', '莫', '雷', '县', '的城市']
# ['印', '第', '安', '松', '是', '位于', '美国', '亚', '利', '桑', '那', '州', '纳', '瓦', '霍', '县', '的一个', '非', '建', '制', '地区']
# ['按', '省', '道', '养', '护', '管理', '权', '限', '的不同', '上海', '的', '省', '道', '可以', '分为', '市', '管', '省', '道', '和', '区', '管', '省', '道']
# ['龚', '明', '鑫', '中华', '民', '国', '政治', '人物', '现', '任', '行政院', '政务', '委员']

# %%
print(*sentences[10:20], sep='\n')
# Out:
# 收到许多人指控政府死者与被拘留者家属提出抗议，并威胁该国的一些人权护卫者。
# 为了迈向环球小姐而努力不懈，日夜都十分憧憬的女优：幸田真理子。
# 果敢的杨氏土司原为兴达户土目。
# 然而告知旁人均不被重视。
# 该网站的公司还开拓研究服务并预测电影的可能收入。
# 默特尔敦是位于美国加利福尼亚州洪堡县的一个人口普查指定地区。
# 查茨沃思是一个位于美国乔治亚州莫雷县的城市。
# 印第安松是位于美国亚利桑那州纳瓦霍县的一个非建制地区。
# 按省道养护管理权限的不同，上海的省道可以分为市管省道和区管省道。
# 龚明鑫，中华民国政治人物，现任行政院政务委员。

# %%
# for i, id in enumerate(tqdm(lang_df['id'])):
#     with open(os.path.join(lang_root, '16kHz', '{}.txt'.format(id)), 'w') as w:
#         w.write(' '.join(tokenized_sentences[i]))

# %% [markdown]
# Doing MFA alignment.

# %%
filtered_grids = []
n_outlier = 0
for i, id in enumerate(tqdm(lang_df['id'])):
    # grid_path = os.path.join(dict_lang_root, '16kHz/align_wmseg/{}.TextGrid'.format(id))
    grid_path = os.path.join(lang_root, '16kHz/align_spm/{}.TextGrid'.format(id))
    if os.path.exists(grid_path):
        grid = textgrids.TextGrid(grid_path)
        filtered_grid = [tok for tok in grid['words'] if tok.text != '']

        if len(filtered_grid) != len(tokenized_sentences[i]):
            # print([w.text for w in filtered_grid], tokenized_sentences[i], sep='\n')
            n_outlier += 1
            continue

        interval = np.array([(word.xmin, word.xmax) for word in filtered_grid])
        audio_path = os.path.join(lang_root, '16kHz/{}.wav'.format(id))
        info = torchaudio.info(audio_path)
        duration = info.num_frames / info.sample_rate
        interval = interval / duration

        th.save([segmentss[i], interval], os.path.join(lang_root, '16kHz', '{}.pt'.format(id)))
# Out:
# 100%|██████████| 7085/7085 [00:03<00:00, 2248.74it/s]

# %%
n_outlier / len(lang_df)
# Out:
# 0.009738884968242767

# %%
n_outlier
# Out:
# 69
