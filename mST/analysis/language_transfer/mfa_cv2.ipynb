# %%
import os
import re
import random
from string import punctuation
from argparse import Namespace
from collections import defaultdict

import IPython

import torch as th
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
import torchaudio
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sentencepiece as spm

import textgrids
import faiss

from sentence_transformers import SentenceTransformer
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

from fairseq.data import Dictionary
from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)
from fairseq.data.audio.speech_to_text_dataset import get_features_or_waveform
from examples.speech_to_text.data_utils import load_df_from_tsv, save_df_to_tsv
from fairseq.checkpoint_utils import load_checkpoint_to_cpu
from fairseq.data.encoders.sentencepiece_bpe import SentencepieceBPE, SentencepieceConfig

from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)

# %% [markdown]
# # Build Code-Switch for CV 9.0 Language

# %%
root = '/mnt/data/siqiouyang/datasets/covost2/'

# %% [markdown]
# # Tokenization

# %%
tokenizer = spm.SentencePieceProcessor()
tokenizer.Load('/mnt/data/siqiouyang/runs/mST/pretrained/mbart50.ft.n1/sentence.bpe.model')
# Out:
# True

# %%
langs = ['de', 'fr', 'es', '-it-', 'ru', 'zh-CN', 'pt', '-fa-', '-et-', '-mn-', 'nl', 'tr', '-ar-', 'sv-SE', '-lv-', '-sl-', '-ta-', '-ja-', '-id-']

# %%
lang = 'sv-SE'
lang_root = os.path.join(root, lang)

# %%
lang_df = load_df_from_tsv(os.path.join(lang_root, 'train_st_{}_en.tsv'.format(lang)))

# %%
lang_df
# Out:
#                                id                            audio  n_frames  \
# 0     common_voice_sv-SE_18747821  common_voice_sv-SE_18747821.wav     49536
# 1     common_voice_sv-SE_18747822  common_voice_sv-SE_18747822.wav     64512
# 2     common_voice_sv-SE_18747824  common_voice_sv-SE_18747824.wav     50688
# 3     common_voice_sv-SE_18747826  common_voice_sv-SE_18747826.wav     57600
# 4     common_voice_sv-SE_18748002  common_voice_sv-SE_18748002.wav     61056
# ...                           ...                              ...       ...
# 2155  common_voice_sv-SE_18786940  common_voice_sv-SE_18786940.wav     59520
# 2156  common_voice_sv-SE_18786941  common_voice_sv-SE_18786941.wav     37632
# 2157  common_voice_sv-SE_18786942  common_voice_sv-SE_18786942.wav     41472
# 2158  common_voice_sv-SE_18786943  common_voice_sv-SE_18786943.wav     40320
# 2159  common_voice_sv-SE_18786944  common_voice_sv-SE_18786944.wav     39552
#
#                                             src_text  \
# 0                                 Du ska inte flyga!
# 1            Vi klarar oss tills grödorna har grott.
# 2                             Nej, jag är bara glad.
# 3                   Jag har inte sökt uppmärksamhet.
# 4                       För att du inte har betalat?
# ...                                              ...
# 2155  Herregud, visst, men gör det riktigt snofsigt.
# 2156                       Du får inte ta min Maria.
# 2157                        Nej, för många kalorier.
# 2158                 Det var när de fick bonuslådan.
# 2159                          Jag vet faktiskt inte.
#
#                                        tgt_text  \
# 0                           You should not fly!
# 1     We’ll be fine until the crops have grown.
# 2                           No, I’m just happy.
# 3            I have not been seeking attention.
# 4                      Because you’ve not paid?
# ...                                         ...
# 2155   My God, sure, but make it really swanky.
# 2156                 You mustn’t take my Maria.
# 2157                     No, too many calories.
# 2158        It was when they got the bonus box.
# 2159                     Actually I don’t know.
#
#                                                 speaker src_lang tgt_lang
# 0     2c3ffd78f56f2fefc02b7e5cfd35004f17ff411bacf92f...    sv-SE       en
# 1     2c3ffd78f56f2fefc02b7e5cfd35004f17ff411bacf92f...    sv-SE       en
# 2     2c3ffd78f56f2fefc02b7e5cfd35004f17ff411bacf92f...    sv-SE       en
# 3     2c3ffd78f56f2fefc02b7e5cfd35004f17ff411bacf92f...    sv-SE       en
# 4     2c3ffd78f56f2fefc02b7e5cfd35004f17ff411bacf92f...    sv-SE       en
# ...                                                 ...      ...      ...
# 2155  d24ffe3638b0365e1b653ea982e91d4b7e76a458994db9...    sv-SE       en
# 2156  d24ffe3638b0365e1b653ea982e91d4b7e76a458994db9...    sv-SE       en
# 2157  d24ffe3638b0365e1b653ea982e91d4b7e76a458994db9...    sv-SE       en
# 2158  d24ffe3638b0365e1b653ea982e91d4b7e76a458994db9...    sv-SE       en
# 2159  d24ffe3638b0365e1b653ea982e91d4b7e76a458994db9...    sv-SE       en
#
# [2160 rows x 8 columns]

# %%
sentences = lang_df['src_text'].tolist()
sentences
# Out:
# ['Du ska inte flyga!',
#  'Vi klarar oss tills grödorna har grott.',
#  'Nej, jag är bara glad.',
#  'Jag har inte sökt uppmärksamhet.',
#  'För att du inte har betalat?',
#  'Vi kanske ska lösa in.',
#  'Det visade sig att gruvan hade färre äkta diamanter än en ordinär pantlånare.',
#  'Se från början.',
#  'Paris är så litet.',
#  'Därför startade du ert skitföretag.',
#  'Vi vet redan att skörden kommer att bli dålig i många områden.',
#  'Det här känns som någon smaklös fälla.',
#  'Gör det inte.',
#  'Jag vet inte vad han håller på med.',
#  'Du har rätt i det.',
#  'En blek kopia av henne.',
#  'Och den nya ägaren kommer att drabbas av olycka.',
#  'Lägg ner fågelmetaforerna.',
#  'Till och med fångar får en sista måltid.',
#  'Och som ägare, var jag skyldig.',
#  'Man kan dö för den.',
#  'Vem bryr sig?',
#  'Det var ett snabbt beslut.',
#  'Nej, jag är förbannad.',
#  'Har du glömt vår dejt?',
#  'Så om vi kopplar ihop några.',
#  'Gav du mig alla de klyschorna för detta?',
#  'Jag tror att folk matar dem varje dag.',
#  'Hon såg dig på min Instagram.',
#  'Inte för att ni skulle sätta på.',
#  'Ja, allting är.',
#  'Vill ni prova?',
#  'Vad stilig du är.',
#  'Jag fick dem från hans kontor.',
#  'Talar er vän ungerska?',
#  'Har du hört om klocktorn?',
#  'Jag har väntat på en i tre år.',
#  'Det är en buss.',
#  'Jag har betalat underhåll till honom samtidigt som jag tar hand om barnen.',
#  'Det här samtalet kommer inte att leda till något bra.',
#  'Var fan är bombgruppen?',
#  'Män skjuter skallen av sig eller hänger sig själva.',
#  'Det skulle kunna driva en vattenpump.',
#  'Vi måste fixa så att vi kan läsa på kvällen.',
#  'Hur mår Agnes?',
#  'Sluta prata om mig nu!',
#  'Inte mycket, jag följde bara instruktionerna.',
#  'Jag är strax klar.',
#  'Du är en psykopat och en mördare.',
#  'Bär mig på dina vingar så flyger vi bort.',
#  'Det är brått!',
#  'Vänta lite, Vincent!',
#  'Och sen ser man det här, ett halvår innan han kom ut.',
#  'Bara en yrkesmässig iakttagelse.',
#  'Titta nu noga.',
#  'Vi måste bygga en modell och se om det fungerar.',
#  'Gör det för oss.',
#  'Jag vill sitta fram!',
#  'Men vi ska tänka på det.',
#  'Det ser ut som baracker.',
#  'Mindre uselt är bra.',
#  'Nu sover vi.',
#  'Fan, det är polisen.',
#  'Det är översvämning.',
#  'Det är lätt, och det kommer att förändra ditt liv.',
#  'Var snäll och lämna oss ensamma.',
#  'Kan du flytta på väskan?',
#  'Han vill fortsätta själv.',
#  'De är inte för stora?',
#  'Vi förstår dig!',
#  'Hur vet du det?',
#  'Hon kanske inte hade något val?',
#  'Jag föredrar faktiskt dem mot våra.',
#  'Ja, om ni bara sjunger ihop är det okej.',
#  'Där är den.',
#  'Lägg inte på!',
#  'Prata franska med henne.',
#  'Då gjorde min far rätt som inte lämnade den åt dig.',
#  'Efter att ha känt din bror förväntade jag mig något mer.',
#  'Du vet att presidenten kommer?',
#  'Var försiktig när du använder den.',
#  'Hur som helst måste ni ge er av nu.',
#  'Jag älskar den låten.',
#  'Vad skriver jag?',
#  'Att fråga varför vi är här är idiotiskt.',
#  'Jag vet inte heller det.',
#  'Du ska få igen senare.',
#  'Det är min bästa väns svensexa.',
#  'Skulle jag bli dödad.',
#  'En bedrövlig vana vi tog efter vid reformationen.',
#  'Men herregud, vad har hänt?',
#  'Det var Johns mark att lämna till vem han ville.',
#  'Håll oss inte i ovisshet.',
#  'Jag ringde bruden.',
#  'Allt han rör blir.',
#  'Väggen är inte bärande.',
#  'Jag har en svit på takvåningen.',
#  'Är det okej att äta efter att man nästan dött?',
#  'Nej, jag vill åka.',
#  'Har du tittat i garderoben?',
#  'Hon borde dö.',
#  'Jag ska försöka att inte göra det.',
#  'Snälla, inte det.',
#  'Ja, lite fikon med.',
#  'Problem med en grupp!',
#  'Jag trodde att hon aldrig skulle gå!',
#  'Jag antar att hon fattade beslutet.',
#  'Oj, en helsida.',
#  'Vi kan inte ge uppskov.',
#  'Det där vet jag inte.',
#  'Han ska gifta sig!',
#  'En halv macka?',
#  'För att jag förolämpade din vän?',
#  'Den är i alligatorskinn.',
#  'Han krossar min hand.',
#  'Men skumt, för det ser ut.',
#  'Jag vill gärna se hela huset.',
#  'Skål för mig.',
#  'Vill du med in?',
#  'Jag ska berätta hemligheten för dig.',
#  'Hon är snarare min fru.',
#  'När invigdes kyrkan?',
#  'Jag brukar spela med högre insatser.',
#  'Varför du vill göra det?',
#  'Berätta vem som kommer att hjälpa oss när maten tar slut.',
#  'Hur många dansklubbar finns det i stan?',
#  'En av brytarna kan vara den superladdade idiotsäkra.',
#  'Jag ska nog ta något sött.',
#  'Det tycker jag.',
#  'Utredare undersöker nog vad som kunde ha orsakat den plötsliga explosionen.',
#  'Hur mycket har du druckit egentligen?',
#  'Tänker du räkna?',
#  'Jag skrev även ett kontrakt för att mejsla ut alla små frågetecken.',
#  'Är det allt?',
#  'Jag är stor.',
#  'Han var ju på kaféet.',
#  'Livet är väl lustigt?',
#  'Ni kan fira upp den nu.',
#  'Det är styrkan hos de rättmätiga.',
#  'Varför tog du då upp det?',
#  'Om det vore upp till mig.',
#  'Det är ju ett viktigt uppdrag.',
#  'Jag undrar om mina föräldrars död gjorde mig lite galen.',
#  'Vad består det egentligen av?',
#  'Så vi vill planera svensexan åt dig.',
#  'Böj på knäna och vänd upp händerna.',
#  'Vi borde hänga någon dag.',
#  'Men se upp.',
#  'Mina data innehåller hans kunskap, minnen och personlighet.',
#  'Jag känner igen honom.',
#  'Du vet att hon drogade mig.',
#  'Han är inte nödvändig längre.',
#  'Vi brukade skratta åt honom, för vad duger en ärlig affärsman till?',
#  'Är du galen?',
#  'Den här ritningen är nyckeln till planen.',
#  'Kom, så drar vi.',
#  'Vi är igång!',
#  'Vad sysslar du med?',
#  'Är det där?',
#  'Jag fick just veta.',
#  'Varför tror du att han är besatt av dig?',
#  'Du oroar dig mycket för ditt sodiumintag för någon som försökte begå självmord.',
#  'Jag sa ju, batterierna är dåliga.',
#  'Du kanske kan hitta något i biblioteket.',
#  'Nej, det är en besatthet av mat.',
#  'Har ni en fast linje?',
#  'Mina värdesaker är inlåsta.',
#  'Å andra sidan.',
#  'Så där ska det vara!',
#  'Det kan vi inte.',
#  'Bryr sig om?',
#  'Men om du misslyckas gör vi på mitt sätt.',
#  'Men den skapar en idealisk atmosfär för dem.',
#  'Jag har information om hans plan.',
#  'Så just nu dyrkar ni en bedragare.',
#  'Vad har du tänkt dig, Thomas?',
#  'Nu är vi här.',
#  'Väldigt gullig och han är bra med aggressiva hundar.',
#  'Kan du hålla här?',
#  'Vi behöver inte berätta allt.',
#  'Vad är detta för lammkött?',
#  'Sen garanterar vi er hemresa till Paris, på söndag kväll.',
#  'Du tror fortfarande att du är den enda som kan rädda staden.',
#  'Han satt där nere.',
#  'Har du tappat förståndet?',
#  'För vår hundrade svensexa!',
#  'Du gjorde ditt värsta.',
#  'Han var amerikansk affärsman väldigt liten och allvarlig.',
#  'Jag ska försöka med något.',
#  'Han berättade vad han tjänade och att han skulle försörja mig.',
#  'Företagsmannen, jag skriver på.',
#  'Vad är det för fel på mina kläder?',
#  'Det är min fru.',
#  'Nu sticker vi innan hon spränger oss i småbitar.',
#  'Jag ville träffa hövdingen men han är döende.',
#  'Den blå strömbrytaren aktiverar smygläge.',
#  'Att hon födde dig?',
#  'Varför pratade du med din fru?',
#  'Herregud, tänker du följa mig överallt?',
#  'Bara så ni vet är den här byggnaden inom explosionsradien.',
#  'Tänk på hur många liv som står på spel.',
#  'Vad gör du här?',
#  'Vi lägger inte ett finger på dem.',
#  'Hur mår du i dag?',
#  'Det är så pinsamt.',
#  'Men med Högsta domstolen och läget i världen är det kört för alla.',
#  'Och leva gott.',
#  'Den här gamla saken?',
#  'Jag är så glad att dela den här glada stunden med er alla.',
#  'Ska jag gå?',
#  'Vad är det för en gubbe?',
#  'Det här kändes skitbra!',
#  'Det är upp till mig om jag vill avsluta det eller ej!',
#  'Jag ville fan dö!',
#  'Hade de två huvuden?',
#  'Häng med nu.',
#  'Ni måste följa med oss.',
#  'Så även om marken är torr.',
#  'Nej, han heter Poul Severin.',
#  'Vad fan har du på dig?',
#  'Jag ställde medvetet till med en scen.',
#  'Då kan jag styra den och slåss mot skurkarna!',
#  'Ni behöver inte säga något, men det ni säger kan användas som bevis.',
#  'Sms:ar du honom?',
#  'Kanske för evigt.',
#  'Dina föräldrar låter dig nog komma tillbaka under rådande omständigheter.',
#  'Mörkret omger oss, men vår herre visar vägen mot ljuset.',
#  'Varför tror du att du brinner?',
#  'Jag såg lycklig ut, men det fanns inget på insidan.',
#  'Det är min replik.',
#  'Man har uteslutande riktat in sig på robotingenjörer och deras familjer.',
#  'Det är en innovativ teori som förenar biologiska system och robotstyrning.',
#  'Låt hövdingen tala.',
#  'Hon fick veta om uppsägningen i dag.',
#  'Varför lämnade inte din bror marken till dig?',
#  'Du ska få tala med vår försäljningschef.',
#  'På en båt.',
#  'Ni utnyttjar folk.',
#  'Så jag tror inte att vi får några problem.',
#  'Är den bra?',
#  'Det är olikt mig att köpa nytt innan det gamla är sålt.',
#  'Min exmakes pappa.',
#  'Okej, då sätter vi igång.',
#  'Herregud, jag kan inte kissa när du står där.',
#  'Ibland är det drömmar och ibland är det bara lögner.',
#  'Jag lånade av en karlakarl.',
#  'Ja, jag tror att den lossnade.',
#  'Stanna här med.',
#  'Se hur det gick!',
#  'Du låter galen.',
#  'Se er omkring.',
#  'Det är jag.',
#  'Det är just därför.',
#  'Landningen var lite hård, men.',
#  'Och vad står du där och hänger för?',
#  'Åtminstone tills hon kommer tillbaka.',
#  'Följer du med mig?',
#  'Hallå, inte röra.',
#  'Nej, det är ju helt sjukt.',
#  'Det är inte det jag säger.',
#  'Du låter inte mig uttrycka mig.',
#  'Om jag bestämde så skulle du få den.',
#  'Vi får inte riskera att han känner igen dig.',
#  'Du måste inte gå.',
#  'Jag tänker inte riskera livet för några jävla smycken och gamla bärbara datorer.',
#  'Är du snart klar?',
#  'Har jag fel?',
#  'Därför att de är köttätare.',
#  'Du ska väl dit i kväll?',
#  'Gå till mamma.',
#  'Är någon annan hemma?',
#  'Ska jag ta den sista?',
#  'Få inte panik.',
#  'Han sitter på så mycket kunskap.',
#  'Han bosatte sig nära de följande offren.',
#  'Hur står det till?',
#  'Hur mycket?',
#  'Tänk om han vanärar henne och berättar för alla?',
#  'Jag ska kolla.',
#  'Jag är ingen modell.',
#  'De kommer att älska massagen.',
#  'Det sa jag inte!',
#  'Hur gick det till?',
#  'Min kompis ska gifta sig i sommar.',
#  'Ni kan träffa Daniel på min spelkväll.',
#  'Det har jag sagt många gånger.',
#  'Vi har honom om några dagar.',
#  'Är allt som det ska?',
#  'Så du visste att jag gick där?',
#  'Jag ville bara vidare med karriären.',
#  'Falska poliser dyker upp.',
#  'Jag kommer inte åt.',
#  'Jag hoppas du inte blev förkyld i min brors grav.',
#  'Var hittade du stake nog för det?',
#  'Och du har aldrig använt ordet salvia förr.',
#  'Hon talar inte franska.',
#  'Du beter dig som om du är perfekt.',
#  'Så jag uppskattar verkligen.',
#  'Kan du sänka lite?',
#  'Jag följer med.',
#  'Vad har du tänkt dig?',
#  'Det är klart vi ska lägga av.',
#  'Du vet, de har namn.',
#  'Behöver du ens sminkas?',
#  'Var inte så melodramatisk.',
#  'Det ärjättefint, med stor trädgård för barnen.',
#  'Och på något vis lyckas din pappa se äldre ut än bägge två.',
#  'Du ska få ett visitkort och så kan du titta på utbudet på nätet.',
#  'Det är nog en tidsparadox.',
#  'Regeringen som slog vår hövding?',
#  'Du har fått nog.',
#  'Bälten på.',
#  'Och flickorna bör närvara för att ge mig blommor.',
#  'Jag är för fan din chef.',
#  'Jag och de andra tjejerna firar i trapphuset.',
#  'Irriterande liten man.',
#  'Tack för att du kom, herr president.',
#  'Han kanske ville straffa dig för att du avböjde hans erbjudande.',
#  'Jag meddelar stället.',
#  'Tyvärr, mamma varnade mig för att låta mig bjudas på drinkar av främlingar.',
#  'Okej, vad fan är det som händer?',
#  'Kämpa inte emot det.',
#  'Ingen spelar ens piano!',
#  'Vad sägs om lite glass?',
#  'Jag skulle kunna springa ikapp henne.',
#  'Hon är min svärmor.',
#  'Och det blir inget milt uppvaknande.',
#  'Jag heter magister.',
#  'Min fru måste ha sett.',
#  'Så att hon lättare skulle ta sig in i himmelriket.',
#  'Han isolerade sig från omgivningen.',
#  'När ska vi sluta förlora saker?',
#  'Den här hann åtminstone i tid.',
#  'Min man hämtar dem i receptionen i morgon.',
#  'Vi har redan fått ett bud av en rysk kille.',
#  'Han kallade det en direkt sekvens.',
#  'Jag hade hoppats få köpa tillbaka det.',
#  'Om ni vill döda någon kan det ske.',
#  'Du duger inte för att styra den.',
#  'Menar du livet efter döden?',
#  'Jag tror att du föddes i en fotostudio.',
#  'Sa han var de skulle träffas?',
#  'Du respekterar inte min händighet.',
#  'Med oss är det inga köer.',
#  'Vilken av er får det att smälla?',
#  'Han kanske kan prata med gårdsägarna.',
#  'Varför är det så förvånande?',
#  'Jag har kontrollerat information om området och inte funnit några problem.',
#  'Vad är det i euro?',
#  'Ni bygger en jätterobot, inte sant?',
#  'Hur går det med bladen?',
#  'Så gå hem, var med Alfred, var trygg.',
#  'Jag måste förklara.',
#  'Det håller många år till.',
#  'Inte om det.',
#  'Tror du inte att jag ser när du smyger ut?',
#  'Titta på sömmarna.',
#  'Finns företaget tack vare henne?',
#  'Ja, det är bra.',
#  'Hans tillstånd har försämrats.',
#  'Han som ville köpa vårt hus.',
#  'Du kunde ha varnat mig.',
#  'Jag är okej.',
#  'Nej, men jag behöver gå på damernas.',
#  'Jag vet inte varför du bryr dig.',
#  'Av dem som ligger bakom teknologin.',
#  'Ja, jag hörde.',
#  'Låt oss äta nu!',
#  'Och underhållet upphör nästa år!',
#  'Äntligen har jag hittat er.',
#  'Låt mig gå hem.',
#  'Kan jag få vapen?',
#  'Varför åker du?',
#  'Jag har migrän och diarré.',
#  'Vad är bonuslådan?',
#  'Jag har en sak att uträtta.',
#  'Din vän drivs snart till vansinne.',
#  'Drick massor av vatten.',
#  'Kan du göra vattenljud?',
#  'Under normala omständigheter skulle jag hålla med.',
#  'Nu ska jag prata!',
#  'Räkna inte med mig.',
#  'Ja, det är ju det med.',
#  'Vad är det där?',
#  'Hej, jag är försäljningschefen.',
#  'Vi är uppe!',
#  'Och om frukten är god måste den.',
#  'Det var inte jag.',
#  'Vi får se om ni inte betalar!',
#  'Nej, de träffas nog bara.',
#  'Sluta med de här dumheterna.',
#  'Vad tar det åt mig?',
#  'Nej, jag är faktiskt okej.',
#  'Man kan bygga ut i trädgården.',
#  'Kanske, men var hittade han i så fall teckningarna?',
#  'Är jag dess rättmätige ägare.',
#  'Men det är över nu.',
#  'Har du förlorat förståndet?',
#  'Det var för över ett år sedan, ditt psyko.',
#  'Är du idiot?',
#  'Vad skulle jag behöva för att göra en egen?',
#  'Vi måste öppna porten.',
#  'Vad är det?',
#  'Få bort det!',
#  'Är du här för att anhålla mig?',
#  'Folk måste få veta vad som pågår.',
#  'Sminkningen är rakt fram.',
#  'Ja, han är yngre där.',
#  'Kom igen nu.',
#  'Varför skiter du inte istället?',
#  'Titta på min arm.',
#  'Harklar du upp dina klienters spyor?',
#  'Och det är åttahundra km bort.',
#  'Mycket mer än man kan kräva.',
#  'Använd hushållssoporna!',
#  'Jag flyttar bara tillbaka ägodelar från en tjuv till en annan.',
#  'De får roa sig kungligt.',
#  'Jag går till auktionshuset.',
#  'Och det är mitt jobb.',
#  'Ska vi ut och festa ikväll?',
#  'Vi kämpade för att ta examen.',
#  'Jag tycker om den.',
#  'Hur många tjejer här har fått er mens?',
#  'Sanningen är avslappnad.',
#  'Hur ska jag kunna åka?',
#  'Jag visste att du skulle säga det.',
#  'Hjälper du mig med soptunnorna?',
#  'Han är inte gammal.',
#  'Jag sa åt honom att inte göra det.',
#  'Under flykten därifrån är förföljarna honom hack i häl.',
#  'Nej, vi jobbar.',
#  'Du åt frukost tillsammans med ett dussin vittnen, vid tiden för rånet.',
#  'För hon förstår inte och försöker inte lära sig.',
#  'Vad ville han?',
#  'De dåliga nyheterna är att jag lever.',
#  'När åkte ni?',
#  'Varför tar du den inte bara?',
#  'Vad fan gjorde ni?',
#  'Du får inte avslöja någotom handlingen eller ta selfies med sminket på.',
#  'Nej, det är ingen stor grej.',
#  'Det blir en gång i livet för honom.',
#  'Tycker du att jag gör det?',
#  'Oj, där var det en bil.',
#  'Ska du renovera det här?',
#  'Det skulle fungera om jag fick använda din cykel.',
#  'Hallå, nu gör vi barn!',
#  'Detta är Vilda västern.',
#  'Vad då för gäng?',
#  'Vi vet inte ens var den finns.',
#  'Vi startar eget ihop.',
#  'Hans folk hittade dig efter explosionen.',
#  'Det betyder att jag nog måste stanna här.',
#  'Hör på, vi kan inte vänta.',
#  'Bara kaviar och champis hela tiden, medan vi andra får göra grovjobbet.',
#  'Är det det här huset?',
#  'Fly medan du kan, lita på mig.',
#  'Vi blir mellanhänderna till ren lycka.',
#  'Jag sa ju åt dig att inte åka.',
#  'Frukost till middag.',
#  'Tänker de ta träden?',
#  'Jag kan inte blunda när han smyger in här.',
#  'Sen kollar vi in klubbarna.',
#  'Motion är bra för själen.',
#  'Rambo i bergen.',
#  'Vad ska vi göra nu?',
#  'Vill du prova den?',
#  'Vi är systrar!',
#  'Banken har sju.',
#  'Så med lite hängivenhet finns det inga skäl.',
#  'Okej, vi hörs!',
#  'Det sägs att man inte ser regnbågen utan regn.',
#  'Lägg dig nu.',
#  'Tänk på era familjer.',
#  'Jag ska göra allt som krävs.',
#  'Jo, för vi startar vårt företag, det måste han.',
#  'Att jag ska vanära min familj?',
#  'Såg du henne?',
#  'Inte så lätt som det ser ut.',
#  'Jag kan inte låtsas känna igen personen jag ser framför mig.',
#  'Ja, kom hit.',
#  'Femtio miljoner, omarkerade sedlar.',
#  'Och vodkan är billigare än cola.',
#  'Min kille i Perugia är kakelexpert.',
#  'Jag lovar att vi sänker volymen.',
#  'Det är faktiskt ganska elegant.',
#  'God natt, hörni.',
#  'Vi har en bil som blir stulen från en bensinmack.',
#  'Vad fan håller du på med?',
#  'Hur kom du ut ur bunkern?',
#  'Jag har inte sagt nåt till Thomas.',
#  'Det är vår grupp.',
#  'Det var skumt.',
#  'Får jag använda biblioteket?',
#  'Hur mycket ska jag behöva förlora?',
#  'Hur visste du att pappa var rätt man för dig?',
#  'Det är ju du.',
#  'Jag hade inte kunnat göra det här utan din hjälp.',
#  'Du höjer inte rösten åt din far.',
#  'För er, fader, är det gratis.',
#  'Du kan inte ta ansvar för alla.',
#  'Tack och lov.',
#  'Men de flesta har inte examen i kommersiell förvaltning.',
#  'Hur ska jag prata när det är barn här?',
#  'Jag ska inte hjälpa dig hålla på.',
#  'Din butler ska visa dig vägen framöver.',
#  'Vi kan åka direkt.',
#  'Jag tänkte berätta det, men har inte fått tillfälle.',
#  'Är det mina shorts?',
#  'Det tycker jag också.',
#  'Tjurar du inte?',
#  'Hur sköter vi betalningen?',
#  'Det är du som vill sluta.',
#  'Vad tänker du göra?',
#  'Vi firar ju Ludvigs nionde och flickorna bör fira med mig.',
#  'Jag gör som jag vill.',
#  'Jag vet vart du är på väg.',
#  'Det vet du väl?',
#  'Vi kan stoppa bomberna från att explodera.',
#  'Får jag vara med?',
#  'Om jag öppnar munnen är du där och klämmer åt mig.',
#  'Att använda mitt bolag till att bygga bomber?',
#  'För att rädda honom måste vi förbereda oss för striden.',
#  'Det finns ingen spårvagn.',
#  'Skjuter du mig, släpper tummen greppet och pang.',
#  'Ta det på högtalare!',
#  'Vi är bara två.',
#  'Det blir mycket smidigare så.',
#  'När jag var liten kände jag en flicka.',
#  'Oj, jag borde ha gett dig en mikrodos.',
#  'Det är löjligt, men.',
#  'Vi är stolta över dig.',
#  'Vi ses då.',
#  'Det är visning i morgon.',
#  'Och som det inte var nog hände en olycka.',
#  'Armén skickade hem honom eftersom han fungerade dåligt socialt.',
#  'Ska du skälla ut mig?',
#  'Han är på kanten!',
#  'Vi sumpade allt på första jobbet.',
#  'Det är vår ettårsdag.',
#  'Vi måste tillbaka till stationen.',
#  'Du fattar inte vad det handlar om.',
#  'Den här är bra.',
#  'Det är inget.',
#  'Världen står inte och faller med dig.',
#  'Har du funderat mer på att ta antidepressiva?',
#  'Hur många bröllop är det varje år?',
#  'Hon klarar sig säkert.',
#  'Jag var där och ska tillbaka nu.',
#  'Ja, det vill vi tjejer verkligen.',
#  'Han visste att jag skulle svika honom.',
#  'Du, med en förkrossande seger.',
#  'Det vet jag inte.',
#  'Det är sant och du är självisk som tvingar mig kvar.',
#  'Ja, vi ses då.',
#  'Här är för mycket folk.',
#  'Jag tycker inte att det är särskilt bra.',
#  'Men det är lätt för mig att säga när jag dricker dagens andra kaffe.',
#  'Länge leve jag.',
#  'Men i en verklig strid är en boxares reflexer snabbare än mina.',
#  'Ska man äta?',
#  'Gjorde du inget med honom?',
#  'Låt oss inte investera utländskt kapital i länder som kämpar.',
#  'Du svarade inte på min fråga.',
#  'Jag hoppas att han blir efterbliven!',
#  'Vad säger du?',
#  'Hur mår du nu?',
#  'Du ser förfärlig ut.',
#  'Nyckeln är självmedicinering.',
#  'Vi var överens om det.',
#  'Spelaren har åtta och är kvar.',
#  'Jag sover inte.',
#  'Det är bra incitament för alla!',
#  'Vad heter din dejt?',
#  'Ingen bryr sig om det.',
#  'Men det är också ditt hem.',
#  'Det måste vara till hans bror.',
#  'Du pratar med din chef.',
#  'Är det störigt?',
#  'Nej, mamma, det behövs inte.',
#  'Nej, inte ett inbrottsjobb.',
#  'De pinar mig genom att inte svara i mobilerna.',
#  'Vänta, vad menar du?',
#  'Har Thomas bjudit in dig på vin?',
#  'Vänta, jag har en bra app för restauranger.',
#  'Det där är inte sant.',
#  'Jag är imponerad.',
#  'Jag var tvungen att bjuda henne på grund av bar mitzvahn och familjen.',
#  'Hon är inte social.',
#  'Hon frågade, så jag sa.',
#  'Och var försiktiga i kväll.',
#  'Vi tar tio minuters paus!',
#  'Du är så hög.',
#  'Tack, mina herrar.',
#  'Svaret finns nog i relationen.',
#  'Vissa av er kommer kanske att hamna i samma sits.',
#  'Genom att blanda in din gode vän, har du besegrat ödet.',
#  'Hon var ovanför mig och började dra mig i håret.',
#  'Och om jag vägrar?',
#  'Ingenting kan växa.',
#  'Stå bara stilla.',
#  'Vi behöver pengarna.',
#  'Jag ska inte börja snacka skit nu.',
#  'Att han kan ha begått skattebrott.',
#  'Vilken feg stackare.',
#  'Sa du att det var fem killar?',
#  'Nu har jag dig, ditt jävla svin.',
#  'Vi har varit tillsammans i tre månader.',
#  'Jag ska göra mitt bästa för att hitta.',
#  'För ingen kan titta på den utan att tänka på dig.',
#  'Hjälp din far att plantera.',
#  'Han är fast i flaggstången.',
#  'Jag tänker göra det, okej?',
#  'Vi är era barnbarn.',
#  'Nej, jag bara vandrade in hit.',
#  'Lite lugn vore bra.',
#  'Jag talade.',
#  'Jag trodde inte att du lyssnade.',
#  'Fel nummer.',
#  'Här ska inte borras.',
#  'Jag har inget att dölja, jag är sanningen.',
#  'Allt kul vi haft ihop, fader?',
#  'Vad är det, gubben?',
#  'För din skull.',
#  'Du är alltid välkommen tillbaka.',
#  'Vi har ett namn.',
#  'Du har aldrig frågat.',
#  'Slå med bollträn.',
#  'Jag ska beställa lite gräs.',
#  'Jag behöver låna hans cykeldynamo.',
#  'Hitta inte på.',
#  'Ska hela klassen med?',
#  'Vi ska till Budapest.',
#  'Jag vill inte att du ska stanna här.',
#  'Jag förstår inte varför någon vill dö.',
#  'Tala inte så där till din mamma!',
#  'Skölden är borta!',
#  'Ja, hon sitter fast.',
#  'Vi ska få in dig på universitet.',
#  'Se hur regnet har varit de senaste åren.',
#  'Nästa gång.',
#  'När såg du senast ditt bakhuvud?',
#  'Be din far att betala avgiften.',
#  'Det hände i morse.',
#  'Går det bra?',
#  'Jag lagar mat åt dig.',
#  'Så vi måste åka till Ungern.',
#  'Om vår skörd är okej ska vi betala för resten av hans skolgång.',
#  'Det säger en företagsjurist.',
#  'Är du på hans sida?',
#  'Jag måste tillbaka och auktionera ut familjens prydnadssaker.',
#  'För att tacka dig.',
#  'Det var bra.',
#  'Jag vet, jag vet.',
#  'Han lämnade oss här.',
#  'Gulligt armband.',
#  'Vi är ju mitt inne i spelet.',
#  'Jag bryter mig inte in var som helst.',
#  'Du måste unna dig det.',
#  'Det är en liten gubbe inuti som gnuggar sina händer.',
#  'Hela mitt liv har jag varit ensam, bortgömd.',
#  'Vi säger att man får döda en ko i månaden.',
#  'Det finns ingen för dig.',
#  'Nu får du sluta, Sam!',
#  'Det är allt!',
#  'Det här är vansinne.',
#  'Du är som han är.',
#  'Ja, vi ska lösa det här.',
#  'Det hjälper oss inte.',
#  'Är ni okej?',
#  'Jag har redan informerat honom om våra villkor.',
#  'Åh, hon är så fin.',
#  'I år är marken för våt.',
#  'Jag har en son.',
#  'Vi organiserar svensexor i Budapest för franska brudgummar.',
#  'Han är utanför och han är inte ensam.',
#  'Vi tar en titt.',
#  'Hur går det på jobbet?',
#  'Vill du verkligen veta?',
#  'Vi behöver veta att all matbrist kommer att kvävas i sin linda!',
#  'Jag är på väg hem.',
#  'Vad gör ni här?',
#  'Han nämnde det för en månad sen.',
#  'Men du får ingen andra chans.',
#  'Gör det inte?',
#  'Du stjäl från varje familj vars barn går på den här skolan.',
#  'Er skolavgift är fortfarande obetald.',
#  'Det kommer inte att regna på flera månader.',
#  'Alligatorskinn är så dyrt.',
#  'Vi uppmärksammar dig bara.',
#  'Jag kan inte.',
#  'Vad fan är ditt problem egentligen?',
#  'Du ska i.',
#  'Jag pratade just med sök och räddningstjänsten, det som sprängde hennes bunker var katastrofalt.',
#  'rappa på!',
#  'Jag har inte riktigt det på mig just nu.',
#  'Lyssna på signalerna!',
#  'Gillar du det?',
#  'Varför väntar vi?',
#  'Tack för den goda maten.',
#  'Ta det lugnt!',
#  'Visst är det det.',
#  'Jag vill inte känna mig som åtta.',
#  'Varje gång jag tar svampar blir jag lyrisk.',
#  'Din dröm om ett nytt city kommer att uppfyllas med min hjälp.',
#  'Nej, du lovade staden sex timmar.',
#  'Din karriär kan ta slut när som helst.',
#  'Är det gamla kylskåpet sönder?',
#  'Varför överlever alltid den minsta tjejen i skräckfilmer?',
#  'Jag har fortfarande ägglossning och jag är fruktbar.',
#  'Jag är fet och jag har töntkläder.',
#  'Varför inte sälja till honom och bespara dig allt besvär?',
#  'Precis som jag har gjort.',
#  'Det är ännu värre.',
#  'Detta är mitt kontor.',
#  'Men ändå blev jag inte tomhänt.',
#  'Det här är bara väldigt roligt.',
#  'Det vill jag inte ha!',
#  'När det slutar regna och skörden är säkrad ska vi betala.',
#  'Nej, vi är inte tillsammans längre.',
#  'Vi praktikanter gör misstag.',
#  'Kolla fingeravtrycken på hänglåset.',
#  'Jag är här för att tjäna dig.',
#  'Det verkar så.',
#  'För dem upp och ner.',
#  'Ska jag hoppa?',
#  'Folk håller tal och förstör allting.',
#  'Målträningen är över.',
#  'Ge mig en minut med er mamma.',
#  'Ändrade du dig?',
#  'Jag är stressad.',
#  'Är det verkligen det?',
#  'Vi har bokat ett bord.',
#  'De hade en hård uppväxt.',
#  'Ska vi ha gäster?',
#  'Tänk inte ens tanken på att dyka upp nu.',
#  'Gick det bra?',
#  'Avslappnad version av sanningen!',
#  'Han är väl din bror?',
#  'Ni kan väl kolla in backstage så möter jag er där?',
#  'Jag leker en lek, vi vill inte bli störda.',
#  'Du har högt uppsatta vänner.',
#  'Ja, och vi är här.',
#  'Hunden gjorde dem.',
#  'Det är okej.',
#  'Vi är från Budapest.',
#  'Han är ingen polis, men han sägs vara bra.',
#  'Hallå, inga bebisar!',
#  'Ta till vara på varenda uns.',
#  'Jag vet inte ens var han bor.',
#  'Hur mår du just nu?',
#  'Killen med gröna mössan är min kusin.',
#  'Då får alla samma idéer.',
#  'Han är en duktig pojke.',
#  'Efter all skit som jag köper här.',
#  'Det kan ha räckt med att hon log, så började han följa efter henne.',
#  'Därför är de fortfarande i numerärt underläge.',
#  'Jag får inte ens tag i en liten skit.',
#  'Ska vi käka ramen efteråt?',
#  'Vad du än gör, rör inte den.',
#  'Hon försöker välta företaget.',
#  'Vad vet du om kvinnor?',
#  'Nån som jobbar med turism.',
#  'Nu kan ge er av nu.',
#  'Hon ska berätta om.',
#  'Oroa er inte för en gammal vän.',
#  'Vad är detta för galenskap?',
#  'Hur länge har den varit uppe?',
#  'En ursäkt för en del ohyfsade saker jag gjort.',
#  'Nej, jag vill inte smaka.',
#  'Jag vill gärna se taket en dag.',
#  'Se till att det händer.',
#  'Vi pratade i en timme.',
#  'Jag gav honom ett piller.',
#  'Så vi delar upp.',
#  'Det går inte.',
#  'Nu är jag här igen.',
#  'Jag börjar tro att du menade allvar i går.',
#  'Jag varnade dig!',
#  'Jag behöver ingen.',
#  'Du begår ett misstag.',
#  'Det är dumt för jag kastade gipset.',
#  'När jag kommer från jobbet.',
#  'Hon undrar om du kan stå modell.',
#  'En i taget.',
#  'Ska du träffa honom igen?',
#  'Du behöver inte insistera.',
#  'Jag jobbar med turism.',
#  'Och jag tror han är skyldig till hela det här eländet med diamantgruvan.',
#  'Din lilla skit.',
#  'Med hjälp av el kan jag framkalla regn.',
#  'Nej, det tror jag inte.',
#  'Jag äter gluten.',
#  'När hans tillstånd förvärrades kände han att hon måste dö.',
#  'Så jag säger det.',
#  'En dag åker du till jobbet och det finns inget jobb för dig.',
#  'Har inte kunnat förhöra honom ännu.',
#  'Men det är ju bara vi tjejer här.',
#  'Ska vi ta en titt?',
#  'Vad ska du göra?',
#  'Du ser ut att ha gjort det här hela livet.',
#  'Det var ord och inga visor.',
#  'Men det fanns en lika lång i stan.',
#  'Jag är så glad.',
#  'Jag fick ett hemligt uppdrag att rädda världen, så jag kunde inte.',
#  'Du gav mig det jag tyckte var mitt livs värsta dag.',
#  'Jag har avverkat min tid.',
#  'Det är inte rättvist!',
#  'Grattis, för det du gör är hängivelse!',
#  'Tobak som såg ut som mjölkchoklad.',
#  'Hur kan ni.',
#  'Ja, han är vild.',
#  'Han skulle plocka druvor för småpengar.',
#  'Jag vet inte vad de stoppar i, men det är typ.',
#  'Jag vill inte bli någon gammal förlorare som rånar familjer.',
#  'Kan du plocka fram telefonen åt mig?',
#  'Se vad vi har uppnåt.',
#  'Du avbryter mig och säger.',
#  'Hur kommer framtiden att förändras?',
#  'Vi använder den fortfarande.',
#  'Du är vidrig.',
#  'Först får de en vild helg.',
#  'Vilken väg ska jag ta till jobbet?',
#  'Jag hör av mig.',
#  'Eftersom du är så ogenerös, tar jag halsbandet trots allt.',
#  'Jag är inte redo för det här.',
#  'Jag skickar det till vår gemensamma vän.',
#  'Kom på ovanliga aktiviteter.',
#  'Han är här.',
#  'Jag måste fixa håret.',
#  'Jag vore så tacksam om ni är lite försiktiga.',
#  'Jag förstod att lyckan skulle vara en dam.',
#  'Nej, lägg av.',
#  'Ja, det är din kväll.',
#  'Litar du inte på mig?',
#  'Han tipsade polisen.',
#  'Sån var min svensexa och den var fantastisk.',
#  'Min man är otrogen mot mig.',
#  'Ta en värktablett.',
#  'Om att pappa har dragit!',
#  'Tyvärr har områdets skönhet bleknat en del sedan ni reste.',
#  'Hon är till och med över.',
#  'Barn, i dag hoppar jag in som naturkunskapslärare.',
#  'Vill du köpa jeans?',
#  'Men jag ser ingen.',
#  'Hej, jag ringer för att anmäla ett inbrott.',
#  'Hur tror du att vi har råd med saker?',
#  'Den här vägen.',
#  'Vakna nu.',
#  'Idag markerar gryningen för ett nytt paradigm.',
#  'Frun, jag har inte ätit på två dagar.',
#  'Lee är förändrad.',
#  'Vem fan bryr sig?',
#  'Vid andra föreställningen på lördag.',
#  'Ja, just därför är vi skilda.',
#  'Vilken mat är den mest överskattade?',
#  'Det är ganska.',
#  'Jag har aldrig träffat någon man som gör det.',
#  'Tunga moln rör sig över sydvästra delarna.',
#  'Du får bara bära henne.',
#  'Din andedräkt stinker.',
#  'Kan vi glömma reglerna för ikväll och bara stanna till?',
#  'Måste jag fråga en sak.',
#  'Vill du ha en öl?',
#  'Vi har fått tips om att ni innehar stöldgods.',
#  'Varför får du det att verka som det, då?',
#  'Vad har vi för alternativ?',
#  'Du säger att vi startar ett företag för svensexor i Ungern.',
#  'Hans fru dog förra året.',
#  'Du kan inte vaka över mig hela tiden.',
#  'När skaffade du en fisk?',
#  'Vi planterar grönsaker.',
#  'Skolan har blivit bombhotad.',
#  'Jag har en känsla.',
#  'Vi måste se till att klienterna gifter sig.',
#  'Jag tjurar inte.',
#  'Vi är trötta.',
#  'Jag hade för mycket med mitt eget.',
#  'Inte du igen!',
#  'Jag är inte säker på om de har några.',
#  'Så alla tillbaka till jobbet.',
#  'Är det här ett jävla skämt?',
#  'Jag menar allvar.',
#  'Men det säger en hel del.',
#  'Nej, inte än.',
#  'Jag vet lika mycket som du.',
#  'Känner ni varandra?',
#  'Jag kan förstås inte ha företaget utan dig.',
#  'Men träskpojken håller sina fötter tre meter ifrån mig hela tiden.',
#  'Jag överför det direkt till din hjärna.',
#  'Nu kör vi.',
#  'Jag kan vid tio.',
#  'Jag är upptagen med att rulla runt bland pengarna.',
#  'Det intrycket fick jag inte av dig senast jag var där.',
#  'En mun mindre.',
#  'Kom inte hit.',
#  'Är han så dum?',
#  'Nu blev helgen lite bättre.',
#  'Vad gillar killar?',
#  'Det är den enda möjligheten.',
#  'Förlåt, men jag tror att du har gjort ett misstag här.',
#  'Det fungerar inte så!',
#  'Det är inte som ni tror.',
#  'Jag träffade telegrampojken utanför.',
#  'Ni måste skoja.',
#  'Slå på matchen.',
#  'Bara le.',
#  'Han mördar inte i affekt.',
#  'Nej, ni pratar nog om aborter.',
#  'Det är som första dagen.',
#  'Det kan inte vara sant.',
#  'Jag lyssnar.',
#  'När jag tittar ut bland er ser jag kärlek.',
#  'Det är vår.',
#  'Peter, du krossade mitt hjärta.',
#  'Åh nej, de är redan här.',
#  'Vad hette mannen du dejtade när du träffade pappa?',
#  'Jag ska berätta.',
#  'Är det inte tidigare än vad ni sa?',
#  'För att vi inte kom in på klubben?',
#  'Be dem fortsätta leta.',
#  'Nej, har inte vi en Bluetoothhögtalare?',
#  'Gå och hämta frön hos hövdingen.',
#  'Men de här då?',
#  'Det ante mig.',
#  'Jag fattar, batteribomber från helvetet.',
#  'Så där ja, nu är jag ingen främling längre.',
#  'Ja, jag kommer.',
#  'Han är inte lika försiktig nu.',
#  'Värdet på en svensexa i Ungern är priset!',
#  'Vi måste ge oss av norrut medan vi kan.',
#  'Du klippte mina vingar!',
#  'Ät inte, hörni.',
#  'Ibland spöar hon mig.',
#  'Där har du bilden.',
#  'Vi är inte i skolan mer.',
#  'Du frågar det för ofta.',
#  'Det är helt rätt som du säger.',
#  'Dörren var låst när jag kom tillbaka, som om du ville bli hittad.',
#  'Vi behöver ett rakt svar.',
#  'Bor du inte här?',
#  'För all del.',
#  'Låt dem inte ha sönder nåt.',
#  'Jag mår bra.',
#  'Du hade fest och förstörde hela huset.',
#  'Ett foto av mig i London!',
#  'Såna gifter man sig inte med.',
#  'Det fanns mycket värdefullt i den asken.',
#  'Jag ville inte förstöra din snygga entré.',
#  'Så om du är ateist, varför vill du dö?',
#  'Jag vet.',
#  'Vi är nära Big Ben.',
#  'Vi har redan gett honom pengar.',
#  'Jag behöver en bild.',
#  'Vi är på alla de små nyhetsinläggen.',
#  'Jag skickar nåt.',
#  'Vi hade grannmöte om katastrofhjälp.',
#  'Halsbandet inbringade en ansenlig summa.',
#  'Du kan döda oss båda senare.',
#  'De tänker inte låta oss svälta.',
#  'Nej, jag är bara nyfiken.',
#  'Hur känner du honom, pappa?',
#  'Jag blir hög!',
#  'De här är två anledningar att leva.',
#  'Vad var det för något?',
#  'Jag såg honom för ett par dagar sen.',
#  'Jag är gammal.',
#  'Inte mitt problem.',
#  'Det hade ändå inte gått.',
#  'Den här pausen är bra för oss.',
#  'En dag orkade jag inte längre.',
#  'Jag blev helt stelfrusen.',
#  'Jag skulle ha berättat för dig.',
#  'Det låter inte lika roligt.',
#  'Jag ska försöka.',
#  'I min jacka.',
#  'De sitter perfekt.',
#  'Lycka till med nya jobbet.',
#  'En väg in, en väg ut.',
#  'Jag kan inte vara överallt.',
#  'Har ni tid med det här?',
#  'Men ni är tvungna.',
#  'Nej, behåll dem.',
#  'Jag skulle inte vilja ändra något av det.',
#  'Ja, jag vet!',
#  'Det har hållit på i en vecka.',
#  'Nej, det är ett trick.',
#  'En timme.',
#  'Varför tror du att jag lyssnar på dig?',
#  'Jag är snart klar.',
#  'Det finns inget jag kan göra.',
#  'Men herregud!',
#  'Jag tänker inte ljuga.',
#  'Gå ut i köket.',
#  'Vill du bli gravid?',
#  'Vad menar du med det?',
#  'Hon är vuxen nu!',
#  'Han har ringt femtio gånger.',
#  'Jag klarar inte det här längre.',
#  'Utan att ta farväl?',
#  'En månad senare.',
#  ...]

# %%
tokenized_sentences = []
segmentss = []
space = tokenizer.IdToPiece(5)

# specifically for zh-CN
# pattern = ",|\?|・|\u3002|\uff1f|\uff01|\uff0c|\u3001|\uff1b|\uff1a|\u201c|\u201d|\u2018|\u2019|\uff08|\uff09|\u300a|\u300b|\u3008|\u3009|\u3010|\u3011|\u300e|\u300f|\u300c|\u300d|\ufe43|\ufe44|\u3014|\u3015|\u2026|\u2014|\uff5e|\ufe4f|\uffe5" + punctuation
# for sent in sentences:
#     tokens = tokenizer.EncodeAsPieces(sent)
#     segments = []
#     for idx, token in enumerate(tokens):
#         if token != space and token not in pattern:
#             segments.append((idx, idx))
#     tokenized_sentence = []
#     for seg in segments:
#         tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

#     segmentss.append(segments)
#     tokenized_sentences.append(tokenized_sentence)

# for other languages
def skip(token, punctuation, space):
    if token.startswith(space):
        token = token[1:]
        if token == '':
            return 1
    for c in token:
        if c not in punctuation:
            return 0
    return 1

# punctuation = '!"#$%&,.:;?'
for sent in tqdm(sentences):
    tokens = tokenizer.EncodeAsPieces(sent)
    segments = []
    last = -1
    for idx, token in enumerate(tokens):
        if token.startswith(space) or token in punctuation:
            if last != -1 and last <= idx - 1:
                segments.append((last, idx - 1))
            last = idx + (token in punctuation)
    if last < len(tokens):
        segments.append((last, len(tokens) - 1))

    tokenized_sentence = []
    for seg in segments:
        tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

    tokenized_sentences.append(tokenized_sentence)
    segmentss.append(segments)
# Out:
# 100%|██████████| 2160/2160 [00:00<00:00, 60373.02it/s]

# %%
print(*tokenized_sentences[10:20], sep='\n')
# Out:
# ['Vi', 'vet', 'redan', 'att', 'skörden', 'kommer', 'att', 'bli', 'dålig', 'i', 'många', 'områden']
# ['Det', 'här', 'känns', 'som', 'någon', 'smaklös', 'fälla']
# ['Gör', 'det', 'inte']
# ['Jag', 'vet', 'inte', 'vad', 'han', 'håller', 'på', 'med']
# ['Du', 'har', 'rätt', 'i', 'det']
# ['En', 'blek', 'kopia', 'av', 'henne']
# ['Och', 'den', 'nya', 'ägaren', 'kommer', 'att', 'drabbas', 'av', 'olycka']
# ['Lägg', 'ner', 'fågelmetaforerna']
# ['Till', 'och', 'med', 'fångar', 'får', 'en', 'sista', 'måltid']
# ['Och', 'som', 'ägare', 'var', 'jag', 'skyldig']

# %%
print(*sentences[10:20], sep='\n')
# Out:
# Vi vet redan att skörden kommer att bli dålig i många områden.
# Det här känns som någon smaklös fälla.
# Gör det inte.
# Jag vet inte vad han håller på med.
# Du har rätt i det.
# En blek kopia av henne.
# Och den nya ägaren kommer att drabbas av olycka.
# Lägg ner fågelmetaforerna.
# Till och med fångar får en sista måltid.
# Och som ägare, var jag skyldig.

# %%
# for i, id in enumerate(tqdm(lang_df['id'])):
#     with open(os.path.join(lang_root, '16kHz', '{}.txt'.format(id)), 'w') as w:
#         w.write(' '.join(tokenized_sentences[i]))

# %% [markdown]
# Doing MFA alignment.

# %%
filtered_grids = []
n_outlier = 0
for i, id in enumerate(tqdm(lang_df['id'])):
    # grid_path = os.path.join(dict_lang_root, '16kHz/align_wmseg/{}.TextGrid'.format(id))
    grid_path = os.path.join(lang_root, '16kHz/align_spm/{}.TextGrid'.format(id))
    if os.path.exists(grid_path):
        grid = textgrids.TextGrid(grid_path)
        filtered_grid = [tok for tok in grid['words'] if tok.text != '']

        if len(filtered_grid) != len(tokenized_sentences[i]):
            # print([w.text for w in filtered_grid], tokenized_sentences[i], sep='\n')
            n_outlier += 1
            continue

        interval = np.array([(word.xmin, word.xmax) for word in filtered_grid])
        audio_path = os.path.join(lang_root, '16kHz/{}.wav'.format(id))
        info = torchaudio.info(audio_path)
        duration = info.num_frames / info.sample_rate
        interval = interval / duration

        th.save([segmentss[i], interval], os.path.join(lang_root, '16kHz', '{}.pt'.format(id)))
# Out:
# 100%|██████████| 2160/2160 [00:00<00:00, 2413.90it/s]

# %%
n_outlier / len(lang_df)
# Out:
# 0.001388888888888889

# %%
n_outlier
# Out:
# 3
