# %%
import os
import re
import random
from argparse import Namespace
from string import punctuation
from collections import defaultdict

import IPython

import torch as th
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm import tqdm
import torchaudio
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sentencepiece as spm

import textgrids
import faiss

from sentence_transformers import SentenceTransformer
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

from fairseq.data import Dictionary
from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)
from fairseq.data.audio.speech_to_text_dataset import get_features_or_waveform
from examples.speech_to_text.data_utils import load_df_from_tsv, save_df_to_tsv
from fairseq.checkpoint_utils import load_checkpoint_to_cpu
from fairseq.data.encoders.sentencepiece_bpe import SentencepieceBPE, SentencepieceConfig

from fairseq.models.mST.w2v2_phone_transformer import W2V2Transformer
from fairseq.data.audio.multilingual_triplet_v2_phone_dataset import (
    MultilingualTripletDataConfig,
    MultilingualTripletDataset,
    MultilingualTripletDatasetCreator
)

# %% [markdown]
# # Build Code-Switch for CV 9.0 Language

# %%
root = '/mnt/data/siqiouyang/datasets/covost2/'

# %% [markdown]
# # Tokenization

# %%
tokenizer = spm.SentencePieceProcessor()
tokenizer.Load('/mnt/data/siqiouyang/runs/mST/pretrained/mbart50.ft.n1/sentence.bpe.model')
# Out:
# True

# %%
langs = ['de', 'fr', 'es', 'it', 'ru', 'zh-CN', 'pt', '-fa-', '-et-', '-mn-', 'nl', 'tr', '-ar-', 'sv-SE', '-lv-', '-sl-', 'ta', '-ja-', '-id-']

# %%
lang = 'fr'
lang_root = os.path.join(root, lang)

# %%
lang_df = load_df_from_tsv(os.path.join(lang_root, 'train_st_{}_en.tsv'.format(lang)))

# %%
# Optionally resample the audio to 16kHz
# os.makedirs(os.path.join(dict_lang_root, '16kHz'))
# for path in tqdm(dict_lang_df['path']):
#     audio_path = os.path.join(dict_lang_root, 'clips/{}'.format(path))
#     waveform, sample_rate = torchaudio.load(audio_path)
#     resampled_waveform = torchaudio.functional.resample(waveform, sample_rate, 16000)
#     torchaudio.save(os.path.join(dict_lang_root, '16kHz/{}.wav'.format(path[:-4])), resampled_waveform, sample_rate=16000)

# %%
lang_df
# Out:
#                               id                         audio  n_frames  \
# 0       common_voice_fr_17732749  common_voice_fr_17732749.wav     62976
# 1       common_voice_fr_17732750  common_voice_fr_17732750.wav    112896
# 2       common_voice_fr_17732751  common_voice_fr_17732751.wav     64512
# 3       common_voice_fr_17732752  common_voice_fr_17732752.wav     87936
# 4       common_voice_fr_17732753  common_voice_fr_17732753.wav     90240
# ...                          ...                           ...       ...
# 207367  common_voice_fr_20001537  common_voice_fr_20001537.wav     41088
# 207368  common_voice_fr_20001539  common_voice_fr_20001539.wav     62592
# 207369  common_voice_fr_20001541  common_voice_fr_20001541.wav     90240
# 207370  common_voice_fr_20001542  common_voice_fr_20001542.wav     85632
# 207371  common_voice_fr_20001544  common_voice_fr_20001544.wav     67200
#
#                                                  src_text  \
# 0                             Madame la baronne Pfeffers.
# 1       Vous savez aussi bien que moi que de nombreuse...
# 2       Oh ! parce que maintenant, quand on parle de b...
# 3       Les questions sanitaires placent l’enfant au c...
# 4       J’ai au moins une satisfaction personnelle : j...
# ...                                                   ...
# 207367                     L’année suivante, il se maria.
# 207368  Pour les amateurs de rouge, un vin de Bourgogn...
# 207369  "Elle borde les côtés sud et ouest de l'hôpita...
# 207370  Le drapeau brésilien est alors porté par la fo...
# 207371  Mais Sébastien Le Balp ne rompt pas ses relati...
#
#                                                  tgt_text  \
# 0                            Madam Pfeffers the baroness.
# 1       You know as well as I do that many new molecul...
# 2       Oh! Because now, when we talk about drinking, ...
# 3       The sanitary issues put the child at the heart...
# 4       I;ve got at least one personal satisfaction: I...
# ...                                                   ...
# 207367                 He got married the following year.
# 207368  For lovers of red wine, a Burgundy wine, such ...
# 207369  It borders the south and west sides of the Geo...
# 207370  The Brazilian flag is then carried by cross-co...
# 207371  But Sébastien Le Balp does not break his relat...
#
#                                                   speaker src_lang tgt_lang
# 0       796d9ae74694eadea3f343a7e0dfe35f89a6a321d53484...       fr       en
# 1       796d9ae74694eadea3f343a7e0dfe35f89a6a321d53484...       fr       en
# 2       796d9ae74694eadea3f343a7e0dfe35f89a6a321d53484...       fr       en
# 3       796d9ae74694eadea3f343a7e0dfe35f89a6a321d53484...       fr       en
# 4       796d9ae74694eadea3f343a7e0dfe35f89a6a321d53484...       fr       en
# ...                                                   ...      ...      ...
# 207367  55e311cdba34f70be4760c1af7f0bcf66afb2bf5b94c35...       fr       en
# 207368  55e311cdba34f70be4760c1af7f0bcf66afb2bf5b94c35...       fr       en
# 207369  55e311cdba34f70be4760c1af7f0bcf66afb2bf5b94c35...       fr       en
# 207370  55e311cdba34f70be4760c1af7f0bcf66afb2bf5b94c35...       fr       en
# 207371  55e311cdba34f70be4760c1af7f0bcf66afb2bf5b94c35...       fr       en
#
# [207372 rows x 8 columns]

# %%
sentences = lang_df['src_text'].tolist()
sentences
# Out:
# ['Madame la baronne Pfeffers.',
#  'Vous savez aussi bien que moi que de nombreuses molécules innovantes ont malheureusement déçu.',
#  'Oh ! parce que maintenant, quand on parle de boire, je m’en vais !',
#  'Les questions sanitaires placent l’enfant au cœur de la problématique de l’évolution humaine.',
#  'J’ai au moins une satisfaction personnelle : j’ai ému Monsieur Piron.',
#  'Avenue du Louvre au numéro trente-huit',
#  'Devant la seconde tour du Louvre… à l’heure du couvre-feu.',
#  'Cette décision déclenche la colère des colons, puis des campagnes de presse enflammées.',
#  'Ce dispositif joue un rôle très important dans la réduction de bruit.',
#  'Il est organisé autour de plusieurs allées.',
#  'Ailleurs ils sont presque transparents.',
#  '"Ces retrouvailles sont très liées à toute l\'affaire des vols."',
#  '"Cette collaboration s\'est poursuivie tout au long de sa vie."',
#  '"Deafheaven attire aussi l\'attention en jouant à plusieurs festivals."',
#  'C’est pourquoi elle a débouté les appelants.',
#  'Il a doublé la voix impérissable de Joyeux dans Blanche-Neige.',
#  'Il traduisit également Zygmunt Krasinski, Eliza Orzeszkowa, Józef Ignacy Kraszewski et Henryk Rzewuski.',
#  'Le pâté de Lapin.',
#  '"Un cratère de la planète Mars a été nommé en l\'honneur de la ville."',
#  'Une desconficture d’hommes ne lui coustoyt qu’ung gentil soubrire.',
#  '"L\'église a remplacé un sanctuaire paléochrétien à abside."',
#  'Emanuela Zardo remporte le simple dames.',
#  '"La légende raconte qu\'elle avait été faite par la Vierge Marie."',
#  'Lord Londonderry prend alors le surnom de Vane, par licence royale.',
#  'Cela me va », répondit Barbicane.',
#  '"Son père, Zafar Nomani, était titulaire d\'un Ph.D de l\'Université Rutgers."',
#  '"On notera particulièrement une jolie cavatine de Cyprien et d\'aimables couplets de Colette."',
#  'Rue Centrale, Tenay',
#  'quatre place Saint-Eloi, zéro six, quatre cent dix à Biot',
#  'quatre cent cinquante et un rue des Prés Château',
#  '"Tu t\'ennuies, n\'est-ce pas ?"',
#  '"Côteaux de l\'Appenthal, soixante-huit, cinq cents Guebwiller"',
#  '"Cami du Mas d\'Arnaud, trente-quatre mille cinq cent soixante Montbazin"',
#  'Au fond, il est purement décoratif.',
#  'François rentre portant un fauteuil de bureau.',
#  'La parole est à Monsieur Charles de Courson, pour soutenir l’amendement numéro quarante-quatre.',
#  'L’ensemble des associations d’élus étaient d’ailleurs représentées la semaine dernière.',
#  '"C\'était les dissoudre."',
#  'Elle balbutia : Votre ciel est fermé.',
#  'Rue de Guingamp au numéro dix',
#  '"Ah ! ça, c\'est la vérité, cria Dutheil."',
#  'Non, je lui ai donné un caractère factice, pour que ce caractère m’appartint…',
#  'Cet amendement est proposé par notre collègue Philippe Gosselin.',
#  'Je suis très réservée sur ce dispositif.',
#  '"Allez à tous les diables, lui cria le marquis comme il s\'en allait."',
#  'J’ai vu sur le toit.',
#  'Rue des Colonnes au numéro sept',
#  'Rue Xavier Jouvin à Voreppe',
#  '"Il mange, mais c\'est avec dégoût."',
#  'Tiens, j’ai faim.',
#  'Il allège et il remplace.',
#  'Ne fais donc pas toujours dévier la conversation pour prendre l’offensive !',
#  'Vous avez quelque chose ?',
#  'Toute réforme fait des perdants',
#  'Quel aveu',
#  'On cite souvent en exemple la Suède et le Danemark.',
#  'Ce n’est pas vrai, n’exagérez pas',
#  'C’est le régime inacceptable de la double peine',
#  'Nous le reconnaissons, cette économie a des conséquences en termes de pouvoir d’achat.',
#  'La question, effectivement, se pose et doit être traitée comme telle.',
#  'On entend un branle-bas sourd dans la chambre.',
#  'C’est suffisant.',
#  'Je suis saisie de l’amendement numéro mille six cent trente-cinq de Monsieur Yannick Moreau.',
#  'La parole est à Monsieur Pascal Terrasse, pour soutenir l’amendement numéro quarante-quatre.',
#  'Le Commissaire Tranquillité superficielle, Monsieur Maltenu…',
#  'Les canards.',
#  'Je ne t’accuse de rien du tout !',
#  'J’insiste sur ce point : un générique n’est pas un biosimilaire.',
#  'Rue Cazaud, Aurillac',
#  'vingt-cinq impasse Roucouyer, quatre-vingt-dix-sept, deux cent dix-huit à Basse-Pointe',
#  'Des Français croyaient la France perdue, et ils applaudissaient.',
#  'Oh ! aïe ! oh ! aïe !',
#  'Mais arrête-toi donc !…',
#  'Il recueille bien entendu notre assentiment.',
#  'Elle est jolie votre raison !…',
#  'Route des Bons Prés, La Croix-de-la-Rochette',
#  'Route de Yenne, soixante-treize, deux cent quarante Saint-Genix-sur-Guiers',
#  'deux avenue Beverini Vico',
#  'Mon cousin, veillez à ce que je puisse causer sans être écoutée.',
#  'Rue du Bois Saint-Martin, soixante, quatre cent quatre-vingts Abbeville-Saint-Lucien',
#  'Ils disposent des sièges autour de la table.',
#  'La parole est à Monsieur Élie Aboud, pour soutenir l’amendement numéro mille cent soixante-trois.',
#  'À quel lieu êtes-vous attaché ?',
#  'Mon salon a l’air d’un cabinet de lecture.',
#  'À gauche de la scène, un canapé légèrement de biais.',
#  'Malheureusement celles dont nous disposons sont anciennes.',
#  'Rue Émile Boyoud à Château-Arnoux-Saint-Auban',
#  'Elle est maman de trois enfants.',
#  'La Restauration arrêta une carrière commencée sous de si brillants auspices.',
#  '"C\'est ainsi que ce procédé reste largement empirique."',
#  'Elle est située dans la municipalité urbaine de Savski venac.',
#  'Durant dix ans, il développe son entreprise.',
#  'Il est également entrepreneur.',
#  'Le commandement militaire sur les anciens Pays-Bas est confié au général Ferrand.',
#  '"Fils d\'un imprimeur de Windsor, il fait son apprentissage chez son père."',
#  '"La compagnie n\'a pas communiqué depuis sur l\'ouverture ou non de ces deux routes."',
#  'Dans certains cas, cela prend plusieurs mois.',
#  'Depuis de nombreuses années, il fait partie de l’élite mondiale de sa profession.',
#  '"Aujourd\'hui Calvi tient un blog sur Médiapart."',
#  'Il compte plusieurs albums solo et collaboratifs, et dirige le label Internal Affairs Entertainment.',
#  '"Le village marque la limite Sud-Ouest d\'un vaste parc naturel."',
#  '"Le tableau ci-dessous reprend toutes les sélections d\'Henri Van Poucke."',
#  '"Il y a un moment que je n\'ai pas préparé de choucroute."',
#  '"C\'est particulièrement stressant pour ceux qui travaillent avec elle."',
#  '"le partage et l\'interopérabilité, c\'est à dire le choix d\'utiliser"',
#  'La journée s’annonce difficile.',
#  'Cavrois le recueillit, opposant sa large carrure aux fureurs des acharnés.',
#  'Ҫa nous promet un certain nombre de moments difficiles.',
#  'Dansez, nous verrons bien.',
#  'Maintenant je savais qu’il avait vraiment compris.',
#  'Elle savait qu’il lui fallait un produit à la fois indispensable et périssable.',
#  '"Il mesura l\'espace en écartant ses doigts au maximum."',
#  'Je verse l’eau et appuie sur le bouton de la cafetière.',
#  'Les objets nous possèdent.',
#  'Tous les goûts sont peut être dans la nature.',
#  'La femme perdit son bonnet.',
#  'Merci, monsieur Dolez.',
#  'Restez modeste',
#  'Très bien',
#  'sur les bancs du groupe UMP, d’avoir une croissance forte.',
#  'La première est que vous avez considérablement surestimé le taux de croissance potentielle.',
#  'On aimerait une réponse du ministre',
#  '"Aux bouches d\'adolescents farceurs, quatre trompettes de cavalerie sonnaient la diane."',
#  '"Je ne comprends pas pourquoi il n\'est pas là."',
#  'Rue de Vilgénis, quatre-vingt-onze, trois cents Massy',
#  'La fête ?… vous l’avez déjà souhaitée hier.',
#  'Alors Monsieur Dumoulin, comment vous sentez-vous?',
#  'Je crois que tu n’es pas de mon monde.',
#  'Elle ne venait que réclamer son casse-croûte.',
#  'Il n’était pas prévu de faire autant de frais d’entretien.',
#  'Ne vous rendez pas complice de cette illusion.',
#  'Le système fonctionne comme prévu.',
#  'dans ces systèmes intégrables on obtient à la fin des trajectoires périodiques',
#  'trente rue de Choiset, cinquante et un, trois cents à Loisy-sur-Marne',
#  'Rien, rien, répondit le père, ça se passera.',
#  'C’est pour cela que nous avons prévu cette disposition.',
#  'six rue de les Aynans, soixante-dix, deux cents, Vouhenans',
#  'trente-deux rue de la Comtesse de Ségur, trente-sept, sept cents, La Ville-aux-Dames',
#  'Route de Louversey, Sainte-Marthe',
#  'Elle fait mine de remonter.',
#  'L’amendement de Monsieur Letchimy apporte donc une précision utile : la commission y est favorable.',
#  'Ce sont des amendements de simplification.',
#  '"L\'Astrée, c\'est le Forez, la Haute-Loire, et Némorin, c\'est le Gardon."',
#  'Conduis monsieur au comble, dit-il.',
#  'Quel est l’avis de la commission sur ces trois amendements ? Défavorable.',
#  'Quel est l’avis de la commission ? Je maintiens les avis défavorables émis en commission.',
#  'Elle trouva la porte ouverte, sur le palier aux carreaux déteints.',
#  'A tout prendre, les soldats mangeront de la farine américaine.',
#  'Cydalise fermait à la colle ces petits paquets dangereux.',
#  'Cette députation fut présentée à sud Monsieur dans le parc de Schoenbrunn.',
#  'Non, répondit le chiffonnier, dans trois jours.',
#  '"C\'est les enfants qui nous poussent à espérer, heureusement qu\'ils sont là."',
#  'Regardant à sa montre.',
#  'On rigolait bien parfois.',
#  'Cela peut représenter des sommes importantes.',
#  'Vous ne le savez pas?',
#  '"Je me suis battu quinze ans sur tous les champs de l\'Europe!"',
#  'Quatre grandes chaises.',
#  'Mains au ciel, les commères geignaient.',
#  '"Je vous fais passer, citoyens directeurs, la lettre que m\'a écrite M."',
#  'Cela peut nous servir…',
#  'La parole est à Madame Michèle Bonneton, pour soutenir l’amendement numéro quatre cent cinquante-huit.',
#  'Ils indiquaient la devanture et les bonnets de linge.',
#  'La France est absolument souveraine dans le domaine de la dissuasion nucléaire.',
#  '"Trois charges successives s\'engagèrent : toutes furent à notre avantage."',
#  'Les flâneurs du jardin ne semblèrent pas en effervescence.',
#  'Parlez plus lentement s’il vous plait.',
#  'Ses cheveux un peu dérangés lui rappelèrent un souvenir délicieux … Il allait céder.',
#  'Après le travail le repos.',
#  'La directrice a un second métier.',
#  'cinq BIS chemin du Village de Penhoat-Quinio',
#  '"Un flocon de neige qui n\'attend pour fondre qu\'un rayon de soleil."',
#  'Elle est encore plus jolie avec son chapeau.',
#  'Le fait est attesté par Plantavit de la Fosse.',
#  'Les investissements ont, par conséquent, été consentis par une grande majorité d’entre elles.',
#  'Mais range-toi donc !',
#  'Que voulez vous ? répéta-t-il ; je suis occupé.',
#  'L’eau est molle.',
#  'Impasse Sainte-Brigitte, trente-quatre mille sept cent vingt-cinq Saint-André-de-Sangonis',
#  'Impasse Ille Fruits à Ille-sur-Têt',
#  '"Assurément elle mentait, cela se voyait, malgré l\'habitude qu\'elle devait avoir de mentir."',
#  'Il me semble que c’est la moindre des choses.',
#  'Ce n’est pas respectueux du rôle des élus locaux.',
#  '"Que croyez-vous qu\'ils vont faire maintenant ? demandai-je à mon compagnon."',
#  'quatre impasse de Raffet',
#  'Il vota à la chambre haute avec les bonapartistes catholiques.',
#  'Ses enregistrements de Scriabine sont perçus par beaucoup comme inégalés.',
#  '"Le Flora est, avec le Levadia l\'un des principaux pourvoyeur d\'internationaux estonien."',
#  'Un portail internet unique permet d’accéder au site de chaque ville.',
#  'La direction artistique est assurée par Daniel Haefliger, Jürg Dähler et Felix Renggli.',
#  'Cinq d’entre eux furent expulsés du monastère et emprisonnés.',
#  'Elle a le même nom que sa propre préfecture, Safi.',
#  'I need him back, but nothing will take back time.',
#  'Le Bryant Park est de forme rectangulaire.',
#  'Il se présente à sa succession dès dans une campagne électorale très agressive.',
#  'Les artefacts de la civilisation autochtone sont significatives.',
#  '"Il fait valoir qu\'il était absent dans la civilisation réussie des Iroquois."',
#  '"Après de longs problèmes de santé, il meurt le à l\'Hôpital universitaire de Tampere."',
#  'Pendant la Première Guerre mondiale, il part avec sa famille pour les États-Unis.',
#  'Sa famille et elle déménagent ensuite à Los Angeles.',
#  'La maison généralice est à Bologne.',
#  '"Plusieurs bureaux régionaux sont présents dans l\'Ouest français."',
#  'Jean décide de se déguiser et de se faire passer pour une ressortissante britannique.',
#  '"D\'autres péripéties interviennent autour de ce quiproquo."',
#  'La ligne irait de Hanoï à Hô-Chi-Minh-Ville.',
#  'Lisa souriait, quand on lui parlait de ces choses à mots couverts.',
#  'La liste ci-dessous est présentée selon la chronologie des événements de la série.',
#  '"Le taux de chômage atteint des sommets; le taux d\'inflation est très élevé."',
#  'Élève au lycée Paul-Éluard de Saint-Denis, il participe rapidement au mouvement lycéen en France.',
#  'Il se rendra compte que ses enfants ont du potentiel pour la musique.',
#  'Il mit fin à ses jours cette même année.',
#  'Des chercheurs ont ainsi utilisé cette approche pour observer des effets sur la mémoire.',
#  '"Il est donc important de renforcer la surveillance et l\'encadrement des activités."',
#  '"Formé pour être un soldat de l\'ère moderne."',
#  '"Toutefois, la société dit que ce n\'est pas le cas."',
#  '"Michel Thierry est un des leaders européens du textile pour l\'automobile."',
#  'Les textes modernes comprennent des œuvres de Natsume Sōseki, Mori Ōgai et Ryūnosuke Akutagawa.',
#  '"Elle est nommée en l\'honneur d\'Ignace d\'Antioche."',
#  '"Ses parents divorcent lorsqu\'elle a un an."',
#  '"Ils l\'achetèrent £ et la construction du stade fut entreprise aussitôt l\'achat effectué."',
#  '"On croirait l\'Enfant Jésus bien vivant mais moins que ce qu\'elle attendait."',
#  '"Sur son rebord oriental s\'élève le mont Rinjani, un volcan culminant à mètres d\'altitude."',
#  'La notion de champion a aussi été collective.',
#  'Son siège social est basé sur la ville de Bilbao.',
#  '"Ayant grandi à Orléans, elle s\'installe adulte à Paris."',
#  'Cette espèce est endémique de Mohéli aux Comores.',
#  '"Il s\'agit formellement du sel d\'hafnium et d\'acide silicique."',
#  'De nombreux témoignages font état de cette modification d’attitude.',
#  'Elle diffère de la néohespéridine dihydrochalcone par un groupement méthyl-éther.',
#  'Oh ! docteur, murmura Raymond.',
#  'Cela ne permet pas une amélioration conséquente des services.',
#  'Je souhaite simplement aborder le problème de l’usage du registre.',
#  'Je vous envoie un exemplaire de la constitution de la république cispadane.',
#  'La réponse à la crise peut être aussi une réponse culturelle.',
#  'La reine mère désirait fort la paix.',
#  'Oh ! là-dessus, vous savez bien que tous les jours j’écoute et j’admire…',
#  'Gautier, évêque de Châlons, tenait tête en cette matière à Othon, duc de Bourgogne.',
#  'Nous verrons bien ce qu’il en sera.',
#  'Impasse de Kerguidoue au numéro six',
#  'La réponse est non, monsieur de Courson.',
#  'Je m’appelle Fulup.',
#  'Rue Cassandre Salviati, Mer',
#  'Cité de Naujac au numéro huit',
#  'Je regardai à mon tour, et je ne pus réprimer un mouvement de répulsion.',
#  'Vous parlez là comme un homme brave et comme un homme honnête.',
#  'La parole est à Monsieur Denys Robiliard, pour soutenir l’amendement numéro cent sept.',
#  'Rue de Peyre Crabère, Lourdes',
#  'Non ! discuter avec une femme…',
#  'Donnez-le-leur.',
#  'Vingt-cinq animaux.',
#  'Condamné à mort pour cet outrage, Zarak doit fuir.',
#  '"Fliegerkorps qui l’amènera à participer à la guerre sur le front de l\'Est."',
#  'Il est aussi la voie navigable Est-Ouest la plus importante.',
#  '"L\'entreprise évoluera vers les métiers de la chimie et de la fibre artificielle."',
#  'Elle est alors la première femme à prendre la tête de la diplomatie danoise.',
#  'Shawville est enclavée dans la municipalité de Clarendon.',
#  '"La compatibilité avec Solaris est annoncée pour l\'année suivante."',
#  '"La commune est à l\'ouest de la plaine de Caen."',
#  'Il est enterré au cimetière des Capucins.',
#  '"Il y reçoit l\'enseignement entre autres de Heinrich Nissen et Theodor Mommsen."',
#  '"Une rue de la ville d\'Al-Jaudariyyah est habitée par les Juifs."',
#  'En arboriculture fruitière, on utilise souvent cette variété comme intermédiaire de greffage.',
#  'Son représentant actuel est Waqjera Terfasa Kebede.',
#  '"Bjorn Heimdall dit au joueur qu\'il croit que l\'Hyperborée était l\'Islande."',
#  'Guennadi Ziouganov aura été son président.',
#  '"J\'ai trois enfants, deux filles et un gars."',
#  'La prochaine fois.',
#  'ma paire de chaussures.',
#  'Le marin.',
#  '"il n\'est pas facile de chercher des arguments économiques alors que l\'on sait pertinemment qu\'il s\'agit d\'un besoin social."',
#  'Saint-Sauveur.',
#  '"Ça c\'est marrant"',
#  'Je suis diplomé de B.E.',
#  'C’est vrai.',
#  'sept maisons.',
#  'Comment ça va ?',
#  'ils ont été aimé.',
#  'Nous nous porterions mieux si nous suivions l’avis du rapporteur.',
#  'deux mille huit cent quarante-cinq route du Roi Théodore, vingt, deux cent soixante-dix, Aléria',
#  'Haut, et passant près de Cyprien.',
#  'quatorze A rue de la Ferté-Alais, quatre-vingt-onze mille huit cent quarante Soisy-sur-École',
#  'La nouvelle embarcation était vaste et spacieuse, et pouvait aisément contenir trente hommes.',
#  'Je veux établir trois ou quatre points.',
#  'D’un jour de fête ?',
#  'La France se sauva seule.',
#  'Quand viendra-t-elle ?',
#  'Britney se confie aussi sur les raisons de sa chute.',
#  'Il joua également au Racing club de France.',
#  '"Sean choisit d\'être euthanasié par Nathan."',
#  'La ville est desservie par la gare de Gijón.',
#  '"L\'album obtiendra le Laser d\'or de l\'Académie du disque."',
#  '"Certaines propositions furent rapportées, dont l\'idée de développer une version surface-surface de ce missile."',
#  'Elle se rencontre dans la grotte Xi’an dans le xian de Fengshan à Hechi.',
#  'En raison des circonstances et de son témoignage, on conclut à un suicide.',
#  '"Mais le château demeurait toujours un fief de l\'évêque du Puy."',
#  'Le Père Éternel, soutenant son fils crucifié, occupe le centre du panneau.',
#  'Fils de boulangers, il naît à Raulhac, petit village du Cantal.',
#  'Qui dépense trop n’est jamais riche.',
#  'Elle fait partie de la commune de Fotokol et du canton de Woromari.',
#  'Motel Bamako marque un tournant musical pour la chanteuse.',
#  '"L\'auteur a mené un reportage photographique en amont."',
#  '"L\'influence méditerranéenne se fait sentir par un ensoleillement assez généreux."',
#  '"Ensemble, ils réalisent plusieurs esquisses pour des projets d\'architecture moderne et de design d\'intérieur."',
#  'Il y existait déjà un petit village maori.',
#  '"Les Allemands occupent des positions à l\'est de Montélimar, route de Dieulefit."',
#  '"C\'est l\'adaptation cinématographique du roman autobiographique homonyme de Frank McCourt."',
#  'Les gentilés sont appelés Valérienois et Valérienoises.',
#  'La rue des Plantes est une voie publique située dans le de Paris.',
#  '"Le propriétaire-exploitant de la centrale nucléaire est l\'entreprise d\'État Rosenergoatom."',
#  'À Belfaux se trouvent aussi trois châteaux ainsi que de nombreuses vieilles demeures.',
#  '"Ses travaux suscitent l\'intérêt de Lazzaro Spallanzani."',
#  'Dans les cinquième et sixième émissions, un seul participant a été éliminé.',
#  'Ce mollusque marin, gastéropode prosobranche, de la famille Fissurellidae est proche de la patelle.',
#  'Les seules personnes qui l’aiment vraiment sont sa fille Angelica et sa servante Tonina.',
#  '"S\'y installent probablement alors des groupes majoritairement originaires du plateau suisse."',
#  'Thomas Björn compte sur le circuit européen.',
#  'Le réservoir à une contenance de de carburants.',
#  'Il a également construit des théâtres et décoré des châteaux.',
#  '"La première étape consiste à protoner l\'atome d\'oxygène terminal de l\'hydroperoxyde."',
#  'Il alliait une grande force physique avec une conduite de balle irréprochable.',
#  '"L\'altitude relativement élevée du domaine permet une exploitation dans des conditions d\'enneigement généralement suffisantes."',
#  'Les premières versions de Usenet utilisaient les logiciels B-News, puis C-News comme logiciels serveurs.',
#  'Après les Championnats du monde, il remporte le Weltklasse Zürich.',
#  '"Ilhéu Sapado et Ilhéu do Rei font partie de l\'ensemble Ilhéu Cima."',
#  '"Après la guerre, il fut nommé responsable d\'une partie des frontières militaires."',
#  'Whiro, ou Whiro Te Tupua, est le dieu de la mort.',
#  '"C\'est une forme française correspondant au prénom allemand Günther."',
#  'Alix fut donc la dernière Dame de l’illustre baronnie provençale.',
#  'C’est le début d’une collaboration qui va durer soixante ans.',
#  'Il possède également un blog assez suivi dans le milieu du management.',
#  'A moitié transformé en cristal, Garokk avait perdu toute intelligence.',
#  'Depuis que Monsieur Hollande est aux responsabilités, tous les indicateurs sont au rouge.',
#  'Regardez le nombre de logements construits',
#  'Voilà ce qu’est la responsabilité',
#  'Le moule en est brise',
#  'Même si vous le supprimez, cela n’aura en réalité aucun effet.',
#  'Si vous ne le retirez pas, la commission sera contrainte d’émettre un avis défavorable.',
#  'Rue du Clos Marie, Arles',
#  '"Mais on l\'entoure habilement."',
#  'deux rue Paul Meurice, soixante-quinze, zéro vingt à Paris',
#  '"Oui, mais comme c\'est de l\'histoire sainte, cela doit être toujours vrai."',
#  'Rue René Renault à Buchelay',
#  'Rue Bonnac à Clion',
#  'La Korigane ? Laisse-la partir, nous serions forcés de la tuer.',
#  'La femme dit à son amant de se cacher dans le coffre à grain.',
#  'Ah çà ! c’est donc une gageure ? on me volera donc toujours mes papiers !',
#  'Qu’avez-vous ? je ne comprends pas.',
#  'Plus c’est loin mieux c’est.',
#  'Aussi, l’activité de conseil auprès des administrations s’est accrue.',
#  'Je demande donc, moi aussi, son retrait.',
#  'La commission a évidemment émis un avis favorable.',
#  '"Cette femme, à l\'aspect du triste réduit, fit un geste d\'effroi et de compassion."',
#  'Depuis, les choses sont organisées un peu différemment.',
#  '"Et, sans discussion, l\'Assemblée vote le redoutable décret."',
#  'Il me semble que ces avantages…',
#  'Il faut autoriser le choix.',
#  'J’ai mal dormi…',
#  'Le domino dénoua lentement les cordons et jeta sur la table le masque détaché.',
#  'douzeº Stances à Buffon, écrites sur un panneau de son cabinet de travail, à Montbard.',
#  'A compter d’aujourd’hui, je double tes gages.',
#  'Route de Sorède, soixante-six, six cent quatre-vingt-dix Saint-André',
#  'on vide des poches, on est des vrais aventuriers et on vous emmerde.',
#  'Rue du Gabion au numéro quatorze',
#  'La parole est à Madame Danielle Auroi, pour soutenir l’amendement numéro trois cent quatre-vingt-deux.',
#  '"Cette comparaison l\'excusa."',
#  '"J\'ajouterai que je ne pouvais en aucune façon arguer de notre santé."',
#  'Au bord de la rivière, c’est bien l’été, pour arroser.',
#  'Elles piaffaient dans le ruisseau, le long du quai.',
#  'Voilà une horlogerie parfaitement huilée, qui fonctionne sans soucis.',
#  'Vingt-sept.',
#  'Pendant six mois, tu pris l’air… aux Madelonnettes ?',
#  'Quel est l’avis du Gouvernement ? Même avis, considérant que cet amendement est satisfait.',
#  'Faut-il le prévenir que Madame est là ?',
#  'Blanche décide, pour le bonheur de sa sœur, de ne pas empêcher son mariage.',
#  '"Des ateliers d\'artiste se sont installés tout autour de la cour intérieure du palais."',
#  'Il rejoint trois ans plus tard le syndicat Solidarność.',
#  '"Charqueadas est la commune la plus peuplée de la région carbonifère de l\'État."',
#  'Ce mot ancien a disparu depuis longtemps en français, mais subsiste en néerlandais.',
#  'Chaque personnage traverse des épreuves délirantes tout au long de la journée.',
#  '"L\'ensemble est cerné de douves."',
#  'Les hôtels parisiens et franciliens représentent près du quart du parc hôtelier national.',
#  'Après les Trois Glorieuses, il est promu maréchal de camp.',
#  'Il y a sexagésimales dans la journée, équivalant à décimales.',
#  '"C\'est par son intermédiaire que le peintre aurait rencontré le président du conseil."',
#  'Il était connu pour avoir animer l’émission télé foot.',
#  'C’est pour cela qu’une morale théorique, à distance de la pratique, ne fonctionne pas.',
#  'Seul quelques plans extérieurs ont en fait été tournés dans les vraies villes.',
#  'La montée fut classée en première catégorie.',
#  'Je vais maintenant reprendre les quelques éléments évoqués par Monsieur Mariton.',
#  'L’avis du Gouvernement est défavorable.',
#  'Cette mesure est donc puissante, efficace, et monte en régime.',
#  'Vous refusez d’organiser un référendum sur toutes ces questions afin de consulter les populations.',
#  'Au bout du compte, la réponse n’a pas été à la hauteur des enjeux.',
#  'Mais il faudrait désormais atténuer la frontière entre emplois protégés et emplois précaires.',
#  'Le chef de file reste cantonné à un rôle d’impulsion.',
#  '"Blaye-les-Mines fait partie de l\'académie de Toulouse."',
#  'Il a travaillé en collaboration avec le comte de Saint-Germain.',
#  'Azrailles est desservie par des trains de la relation de Nancy à Saint-Dié-des-Vosges.',
#  'Les juvéniles sont plus contrastés que les adultes.',
#  'Son frère Markus est également un biathlète de haut niveau.',
#  'L’archipel est situé en bordure de la ceinture des cyclones.',
#  '"L\'Hôpital Hillsborough est un Hôpital psychiatrique situé sur le même campus."',
#  'La capitale de la région est Mbarara.',
#  'La Basilique San Frediano, où la crypte contiendrait son corps, lui est consacrée.',
#  'Un bruit émotionna Étienne et Catherine, qui levèrent la tête.',
#  '"Elle suggère qu\'Albert Camus et Jacques Lemarchand ont écrit son livre à sa place."',
#  'Elle fonde parallèlement une maison de production, dont Pierre Lazareff est le directeur général.',
#  'Il fait ses études secondaires à Lyon.',
#  'Il donne davantage de terres aux abbayes et aux monastères.',
#  'Résistant pendant la guerre, il est déporté à Auschwitz où toute sa famille périra.',
#  '"vingt B chemin de l\'Aillerie, cinquante mille cinq cents Carentan"',
#  'sept impasse des Baladins, quarante-quatre, sept cent soixante à La Bernerie-en-Retz',
#  'Une odeur de roussi.',
#  'D’une voix mourante.',
#  'La parole est à Madame Michèle Delaunay, rapporteure, pour soutenir l’amendement numéro cent cinquante-trois.',
#  'Il est inconcevable que Monsieur Zola ait oublié toutes ces pratiques.',
#  'Tu es sûr que j’aimerai.',
#  '"L\'infirme se tut, pâlit, trembla."',
#  'deux lotissement Punta Rossa',
#  'La parole est à Monsieur Patrick Hetzel, pour soutenir l’amendement numéro cent sept rectifié.',
#  'Êtes-vous allergique à quelque chose ?',
#  '"il est temps d\'y aller."',
#  'Tout aussi grand.',
#  '"comme il faisait sombre dans la chambre, j\'allumai la lumière."',
#  'Je vous ai demandé ?',
#  'tu lis.',
#  'nous pouvons vous proposer des stages de toutes sortes pour les semaines et les mois à venir.',
#  '"Je ne pourrai rien faire avec si peu d\'argent."',
#  'Je lis le Times.',
#  '"Votre prénom, s\'il vous plait ?"',
#  'Nous ne pouvons pas transiger sur ce point.',
#  'trois maisons.',
#  'Quand tombe ton anniversaire ?',
#  'De temps en temps.',
#  'il ne pêche pas.',
#  'Cosette était éveillée.',
#  'Et il se convulsa d’horreur, de pitié, devant ce qu’elle devait souffrir.',
#  'Rue Val des Faulx, cinquante-quatre, six cent soixante-dix Custines',
#  'D’une voix mourante.',
#  'Il y avait du vacarme à la maison.',
#  'Soit parce que la connaissance de la langue bretonne ne serait pas une nécessité dans les postes qu’ils envisagent de créer.',
#  'Chemin de Pey, soixante-quatre, cinq cent trente Pontacq',
#  'Oui ! et tu y a mis de la conscience…',
#  'Les yeux de Justin se baissèrent.',
#  'Elle est en train d’enlever son tablier.',
#  '"Les méthodes modernes de production comprennent l\'extraction liquide-liquide et d\'extraction par un fluide supercritique."',
#  'Désabusée, Gia Carangi abuse de drogues et s’enfonce davantage dans sa dépendance.',
#  'La circonscription Sud-Est élit treize députés au Parlement européen.',
#  'Il participe ainsi à la bataille de la Meuse en mai.',
#  'Alors toutes nos souffrances passées étaient oubliées.',
#  '"Ces bonnes performances attirent l\'œil des recruteurs."',
#  'En été, différentes activités nautiques se déroulent sur le lac y compris le plongeon.',
#  'Elle se rencontre vers Wulicun.',
#  'Le club ne fait pas partie des principaux clubs du comté de Kilkenny.',
#  'Après la guerre, il retourne à la peinture.',
#  '"L\'ouragan a causé beaucoup de dégâts, notamment des coupures de courants."',
#  'Les résultats présentent une attitude favorable aux femmes et aux stéréotypes féminins.',
#  '"Cette espèce est nommée en l\'honneur de Pierre Leonhard Ibisch."',
#  '"Elle a participé à d\'importantes expositions collectives et individuelles internationales."',
#  '"Deux hommes d\'équipage meurent dans cette attaque."',
#  'Je souhaite que vous ayez raison.',
#  'Voilà ce que serait un esprit de précision.',
#  'Le plus possible.',
#  'N’importe quoi !',
#  'Tous, sauf un.',
#  'Je parle deux langues.',
#  'Ce sont deux choses différentes.',
#  'Ce n’est pas la même chose.',
#  'Beaucoup de gens sont restés là-bas.',
#  'Combien de chambres y a-t-il dans la maison ?',
#  '"C\'était d\'autant plus difficile que n\'avais aucun outil."',
#  'une paire de lunettes.',
#  '"Ils n\'achètent pas le journal à la boutique tous les jours"',
#  'La vérité, c’est que vous en rêviez et que nous l’avons fait.',
#  'Je veux entrer en relation avec notre ambassade.',
#  'Rue de la Bousseleygie à Lubersac',
#  'Impasse de la Rousseline, trente mille Nîmes',
#  'La voix d’Edgard , dans la coulisse.',
#  'À qui parlez-vous ? à Quinola ou à Lavradi !',
#  'Ah ! bien, non, tu sais, tu parles d’aplomb !…',
#  'Et sur ce faible indice, vous vous exaltez ainsi !',
#  'C’est bien la preuve que le loup prolifère.',
#  'Eux aussi, les aristocrates, poussaient le cri sauvage : A la lanterne.',
#  'sept rue Robert Turquan',
#  'Vous aviez fait ainsi l’année dernière.',
#  '"Déjà la lampe exhalait ses dernières lueurs ; bientôt l\'obscurité, le froid, allaient envahir la chambre."',
#  'Vous entendez ?',
#  'Eh bien, ça ne paraît pas.',
#  'Ces restes du corps du prince Louis et du général Hitler étaient perdus sans ressource.',
#  'Route du Tridon, cinquante-huit, cent vingt Château-Chinon (Campagne)',
#  '"Heureusement, d\'autres font preuve d\'une vraie modestie."',
#  '"Prends ces grands cartons, s\'il te plaît."',
#  '"Là … voilà Dieu ! qu\'il est beau comme ça le salon de Monsieur Benoît !"',
#  'Impasse Fouchard, quatre-vingt-neuf mille deux cents Sauvigny-le-Bois',
#  'Je sais.',
#  'Le chef de brigade Lahoz a été légèrement blessé.',
#  'Demander sa route et un peu d’aide.',
#  'Voilà des gens qui sont persuadés que vous êtes mon mari !',
#  '"Je n\'éprouve aucune honte, ni aucune fierté, à raconter ce que j\'ai fait."',
#  '"A ton aise ! la porte est là, et la gare n\'est pas loin."',
#  'soixante-quatorze chemin de Torremila, soixante-six, zéro zéro zéro à Perpignan',
#  'On perd beaucoup de temps avec ça.',
#  'Rue des Brillets, vingt-cinq mille trois cent vingt Montferrand-le-Château',
#  'six deux e Impasse du Glacis, quarante et un mille Blois',
#  'Annette restait seule souvent.',
#  'quarante-quatre rue du Cléguer',
#  'Ah ! bon ! les voilà en madapolam, à présent.',
#  'Et ces deux mots, grand et vrai, renferment tout.',
#  '"Rousseau veut élever l\'homme, en général, et croit qu\'il est partout le même."',
#  'alors mets-toi à table, qu’on puisse goûter au pinard',
#  '"Sous la Régence, ils se plaignent de ce qu\'on les exclut de la milice."',
#  'les chauffeurs sont sur la route. Mais les bahuts doivent être là.',
#  'Vous faites chier, merde. Dans deux heures, j’ai rendez-vous',
#  'Dans le conte bas-breton (Luzel, _Légendes_, deux, p.',
#  'cinq rue Daunot, quatre-vingt-quatorze, cent quarante, Alfortville',
#  'Rue de la Brasserie à Molain',
#  'La parole est à Madame Chantal Guittet, pour soutenir l’amendement numéro cent cinquante-huit.',
#  'Allée des Frégates au numéro cinq',
#  'Rue Passageon, Châteauroux',
#  'Route de Bourguignon, Bassigney',
#  'dix-huit rue René Couzinet, quatre-vingt-cinq, quatre cent trente, Aubigny',
#  'trois avenue du Dauphiné, zéro cinq, cent, Briançon',
#  'La parole est à Madame Corinne Erhel, pour soutenir l’amendement.',
#  'Rue des Petites Chaumes au numéro trois',
#  '"Chemin du Pré de l\'Etang Prolongé, quatre-vingt-quatorze, cinq cents Champigny-sur-Marne"',
#  'Rue Paul Ducournau au numéro seize',
#  'Rue des Chéneaux à Sceaux',
#  'Il est donc proposé de remplacer, à l’article L.',
#  '"Ce joueur n\'a pas été repêché."',
#  '"Toutefois, cela confère à l\'œuvre un fort ancrage tonal qui rend celle-ci largement accessible."',
#  'Cependant, le principal Skinner va trouver la parade en recrutant des remplaçants aux professeurs.',
#  '"À l\'origine, le magazine est tiré à exemplaires."',
#  '"En août, la Caisse rachète pour francs l\'immeuble à Godard."',
#  'Une bibliothèque scientifique et un bureau académique sont créés peu après.',
#  'Il est inhumé à Beaulieu-sur-mer dans le caveau familial.',
#  '"Elle est ainsi nommée en l\'honneur des combattants yougoslaves de la Guerre d\'Espagne."',
#  'Les sentiers sont régulièrement marqués par des cairns.',
#  'Ils sont tous fous dans cette sale ville.',
#  'Ce sera le collège de Cornouailles.',
#  '"Directeur de l\'hospice de Grenoble, il doit émigrer à la Révolution."',
#  '"L\'émeute cesse subitement et les meneurs prennent la fuite."',
#  'Il a été le propriétaire de concessionnaire automobile et sponsor de sa propre écurie.',
#  '"Entraîneur qui donna beaucoup d\'importance à l\'entraînement avec le ballon."',
#  'La réalité, c’est que le déficit baisse d’une année sur l’autre.',
#  'Ce n’est évidemment pas acceptable.',
#  '"Mais sur l\'identification du Paradis terrestre au Jardin des Plantes, j\'étais muet."',
#  '"Comme les savants, j\'en étais réduit aux conjectures."',
#  'Elle aurait profité au plus grand nombre',
#  'Ce gouvernement et sa majorité se sont engagés à désendetter le pays.',
#  'Il y a eu de grandes avancées, et je m’en félicite.',
#  'Vous n’avez pas le monopole de l’exigence',
#  '"C\'est le dernier jour pour s\'inscrire sur les listes électorales."',
#  'De quelle manière les apprentis crient-ils?',
#  '"La liberté tout entière, voilà ce qu\'il nous faut!"',
#  'Des personnes reconnues.',
#  'Des écuyères font la promesse de marcher.',
#  'Si elle me reproche mon attitude, je lui réponds par un sourire.',
#  'Polignac allait revenir de Londres.',
#  '"Les blessés s\'enfuirent en arrosant le sol de gouttes vermeilles."',
#  'Sans varier',
#  'Quand est-on allé sur la lune la première fois?',
#  '"L\'intervention américaine fut très impopulaire au Mexique."',
#  'La salle peut être aussi configurée pour les spectacles et concerts avec places.',
#  'Sanchez exécute Krest en le faisant exploser dans une cellule de dépressurisation.',
#  '"Il se montre sous la figure d\'un corbeau et sa voix est rauque."',
#  '"L\'effet Bonaldi est un cas particulier de la loi de Murphy."',
#  'Les poissons le stockent préférentiellement dans la peau et les viscères.',
#  'Il dépensa entre et pour défricher, construire des routes et créer des lacs artificiels.',
#  'Barbicane ne put s’empêcher de sourire à cette repartie de Michel.',
#  '"Il n\'est en revanche pas mentionné par le papyrus de Turin."',
#  'Ambient expérimental, musique acousmatique.',
#  'Elle est interprétée par Gunvor.',
#  '"Il est enterré dans un cimetière militaire près d\'Ipswich."',
#  '"Aux Championnats d\'Europe organisés à Dortmund, Vasyl Fedoryshyn se classe troisième."',
#  'MacBride est surtout connu pour son interprétation de détectives dans des films policiers.',
#  'Chaque conte se déroule en un lieu et un temps différents.',
#  'Et vous pensez être une personne intelligente ?',
#  'Le professeur avait donné une mauvaise note à Mark.',
#  'Notre objectif était double : améliorer le revenu des travailleurs sans pénaliser la compétitivité des entreprises.',
#  'La parole est à Monsieur Guy-Michel Chauveau, inscrit sur l’article quarante-six quater.',
#  'Il boit moins de vin qu’autrefois.',
#  'Le Gouvernement vous rendra compte de l’association des collectivités à la rédaction des ordonnances.',
#  'Tu es sûr que j’aimerais.',
#  'Vous m’avez téléphoné ?',
#  'La parole est à Monsieur Éric Diard, pour soutenir l’amendement numéro trois cent quarante-trois.',
#  'Par cet amendement, nous proposons de passer simplement à quarante-trois pourcent dans un premier temps.',
#  'Seconde faiblesse : les amendements ne contiennent pas de borne.',
#  'Quatre-vingt-onze.',
#  'La parole est à Madame Michèle Bonneton, pour soutenir l’amendement numéro neuf cent soixante.',
#  'Vous me le rappellerez ?',
#  'Elle travaille dans la restauration et le père est conducteur de poids-lourds, ils sont débordés et peu à l’école.',
#  'trois rue Louis Guepey, soixante et onze mille trois cent cinquante Allerey-sur-Saône',
#  'Personne ne répond.',
#  'dix-neuf boulevard des Petites Chenevières, seize mille deux cent trente Mansle',
#  'Rue des Grandes Carrières au numéro trente-neuf',
#  'Il est séparé de sa femme, voilà tout.',
#  'Non, merci… j’ai le Rire.',
#  'L’ancien policier se redressa dans sa chaise en PVC.',
#  'Jean, jeune officier, jette devant lui l’homme qui avait crié à la fenêtre.',
#  'Impasse du Champ Pommier au numéro soixante-cinq',
#  'Mais il avait toujours fermement repoussé toute idée d’enfant.',
#  'Je vous trouve joli !',
#  'Mais, j’y pense, vous ne connaissiez pas ma femme…',
#  'sept rue des Lyanes, soixante-quinze mille vingt Paris',
#  '"L\'économie de la ville a toujours été orientée vers le secteur industriel."',
#  'La ville a aussi mise en place un collecte des déchets permettant leur recyclage.',
#  'Le groupe est composé de camarades de lycées de Horton.',
#  'Le bois énergie constitue une source de revenus non négligeable.',
#  'Amamiya est donc emprisonné pour le meurtre de Shimazu, le tueur en série.',
#  '"Là-bas, elle s\'incline dès le premier tour de nouveau face à Daniela Hantuchová."',
#  '"Louis-Félix Pinault fut également député à l\'Assemblée législative et ministre de la Milice."',
#  '"Faire passer avec un peu de mâche en jus d\'iode vanille."',
#  'Il tente de lui parler, mais elle est rejointe par son compagnon, Christian.',
#  'La voute plantaire et les régions péri-malléolaires peuvent aussi être touchées.',
#  'Ce médicament a été mis au point par et codéveloppé par Regeneron et Sanofi.',
#  'C’est un calcul qui est l’inverse du calcul différentiel, répondit sérieusement Barbicane.',
#  'Elle se rencontre sur le Nevado de Toluca.',
#  'Jugés comme des affabulateurs, les enquêteurs rejettent leurs témoignages et les relâchent.',
#  'Le darkcore est un contre-mouvement du happy, ayant évolué en breakbeat hardcore.',
#  'Vous goûteriez encore ces délices sans nom.',
#  'La veuve joignit les mains.',
#  'Ils vont se promener quand le temps est beau.',
#  'Un pantalon trop grand.',
#  'Seize.',
#  'RUE ETEX, Paris',
#  '"Cet exercice quotidien d\'une sensibilité excessive ne pouvait être sans résultats."',
#  'Sa tête.',
#  'Le monument est situé dans le département français du Calvados, à Bonneville-la-Louvet.',
#  'La fenêtre de citation est de trois ans.',
#  'Rachel Cohen est une jeune fille juive passionnée de photographie.',
#  '"Le premier symptôme classiquement décrit est l\'absence de montée laiteuse dans le post-partum."',
#  '"Toutefois le livret comporte des inexactitudes concernant les dates d\'enregistrement."',
#  'Le prince entraîna son ami vers la fenêtre, le balcon.',
#  'Des saluts se répondaient au large.',
#  'Tu aides la peur à triompher de ma raison!',
#  'Ma sœur, que vous êtes heureuse, vous!',
#  'Je disais ça pour rire, je suis un peu désespéré.',
#  'Le général en profita pour entreprendre son neveu.',
#  'De mon temps, ce n’était pas pareil.',
#  'La délégation pénétra dans la cour du Palais-Royal.',
#  'Pied-de-Jacinthe montrait son œil récemment opéré de la cataracte.',
#  'Il distrayait simplement sa garde. Premier vrai mouvement.',
#  '"L\'écran est mal calibré."',
#  '"Il se décida pour détourner lui-même l\'attention du soldat."',
#  'Un groupe entonna le chant des Girondins.',
#  'Je récupère des contrats pour du loot.',
#  'À la pointe du jour, nous entrâmes dans Neumark.',
#  'Va mettre ta petite veste.',
#  'Je n’arrive pas à imaginer qu’un tel argument soit crédible.',
#  'On demande cou de cygne léger ou plate-forme en très bon état, pressé.',
#  'Tu es sûr qu’elles aimeront.',
#  'On cherche un portrait de ce nouveau roi.',
#  'Mais vous ne le connaissez pas…',
#  '=Angèle.= Drame en cinq actes.',
#  'La parole est à Madame Marie-Christine Dalloz, pour soutenir l’amendement numéro cent huit.',
#  'Rue de Durstel, Drulingen',
#  '"Lamba était capitaine du peuple à l\'époque de son triomphe à Cursolo."',
#  'Ah ! oui, surtout de cette façon-là !',
#  'Vous n’estimez pas un honnête homme plus que tout.',
#  '"CHE DADY HAMIDA, M\'Tsangamouji"',
#  'À deux, il y a plus de chances qu’aucun détail ne nous échappe.',
#  'J’ai essayé de me surpasser.',
#  'Prenez pitié, je vous en prie, de leur futur.',
#  'Vous acceptez de promouvoir les formats de fichiers et les logiciels de cet éditeur.',
#  'Se saisir d’un monopole est une chance rare.',
#  '"Il m\'a expliqué un peu la situation."',
#  'Je ne m’attendais pas à ce résultat.',
#  'Je voulais être heureux un peu plus que mes parents.',
#  '"Je crois qu\'elle a démissionné juste avant les vacances."',
#  'Un ami, tu sais ce que c’est?',
#  'Un nuage de poussière décolla de toutes les surfaces planes et resta en suspension.',
#  'Oh, certes, nous aimerions faire cela.',
#  'Je ne sais pas encore si cela va m’aider à m’endormir.',
#  'deux cuilières à soupe d’huile de noisette',
#  '"De ses griffes elle l\'égratignait au cou."',
#  'Au fond, à gauche, bancs, marchande de gâteaux ; à gauche, marchande de livres.',
#  'Il traite par ailleurs des critères de sélection des jeunes pour remplir ces missions.',
#  'C’est, au contraire, glisser vers le terrorisme intellectuel que de verser dans ces excès.',
#  'Que font les gens ici ?',
#  'Laissez-moi, Monsieur ; je veux être seule.',
#  'Nous en venons aux amendements à l’article trente-quatre.',
#  'Comment !… vous, monsieur Pitois ?',
#  '"Rue Poitou à Saint-Sauveur-d\'Aunis"',
#  'Est-ce que ça vous regarde ?',
#  '"L\'idée de sa visite les réjouissait médiocrement."',
#  'Oui, monsieur : le bon pour vous et le mauvais pour vos amis.',
#  'Il n’y a que Molière qui puisse avoir l’esprit de Molière.',
#  'neuf avenue des Nidoleres, soixante-six, trois cents, Tresserre',
#  'Des cravates blanches ! toujours des cravates blanches !',
#  'Comme vous l’avez mentionné, madame la rapporteure, des initiatives émergent.',
#  'Monsieur Robiliard, retirez-vous votre amendement numéro cent un ? Oui, monsieur le président.',
#  'Rue de Vendat, Saint-Rémy-en-Rollat',
#  'Voyez-vous, mon garçon ! il ne faudrait pas nous parler de noces aujourd’hui !',
#  '"L\'office commence à minuit."',
#  '"C\'est pour la première fois que l\'enseignement universel de la musique est institué."',
#  'Quant à la guerre contre les Génois, elle est juste et on la fera.',
#  'Cet amendement vise à supprimer l’alinéa douze de l’article.',
#  'Moins de tréteaux à Westminster et moins d’échafauds à Tyburn !',
#  'Moi ? Me croyez-vous heureuse ? est-ce possible ? Appuyez la main sur votre coeur, et répondez.',
#  'Droit, et à fond de train.',
#  '"Jamais la curiosité du docteur Legris n\'avait été à ce point excitée."',
#  'Avenue du Petit Clamart au numéro vingt-quatre',
#  'Lotissement du Petit Marcilly, cinquante-trois, cent quatre-vingt-dix Landivy',
#  'C’est, en tant que blason, l’emblème séculaire de la Normandie.',
#  'Cette espèce est endémique de Pemanggil au Johor en Malaisie.',
#  'Après sa carrière, Steve Bowditch travaille comme entraîneur.',
#  'La moitié de son œuvre a paru depuis.',
#  '"L’œuvre de Delalande continuera de jouir d\'une grande popularité."',
#  'Avant de prendre sa retraite, il effectue une ultime saison à Limoges.',
#  '"Il est diplômé en Droit de l\'Université complutense de Madrid."',
#  '"Il est concentré de nos jours dans l\'île de Djerba."',
#  'Sa manipulation ou son utilisation alimentaire présentent donc de réels dangers.',
#  'Il s’est surtout fait connaître par ses travaux sur l’usage des drogues.',
#  'Ça ou Jersey.',
#  'Il fait une chute spectaculaire au Grand Prix de Grande-Bretagne à Silverstone.',
#  'Blessé, il se rend en Irlande où il est soigné par Iseult.',
#  'Après sa mort, Tiedge déménage avec sa famille près de Quedlinbourg.',
#  'Il fut élève de Phidias.',
#  'Revenons donc aux choses sérieuses.',
#  '"Elle l\'avait repris alors, elle l\'avait ramené chez elle avec une joie triomphale."',
#  'Le moule en est brise',
#  'Cependant, aucune mesure concrète n’est prise.',
#  '"La surveillance spirituelle est confiée à l\'abbaye de Kamp."',
#  'Il était composé des cantons de Marmande, Duras, Levignac, Meilhan, Sainte Bazeille et Seiches.',
#  '"Elle se rencontre dans les États du Chiapas et d\'Oaxaca."',
#  'Giuseppe Galletti est le fils de Pietro et Anna Benassi.',
#  'Luce et Rachel se rencontrent le jour du mariage de cette dernière avec Heck.',
#  'C’est le début des taxes pour les conducteurs, et ça ne s’arrête pas là.',
#  'Il est détruit à une date indéterminée.',
#  'Miraculeusement, Gouhier sort indemne du choc.',
#  'Le terme est en principe similaire à celui de sapeur.',
#  '"Il fait des études à l\'école de Joinville-le-Pont, où il deviendra rapidement moniteur."',
#  'Cette séparation des variables conduit à des krigeages simples sur chacune des composantes.',
#  'Ils ne peuvent être délivrés que lors de stages fédéraux.',
#  'Mais ils appréhendent la chose de manière différente.',
#  'Des discussions seraient en cours notamment avec le conglomérat industriel japonais Hitachi.',
#  'Cette relation se concrétise par des échanges socio-culturels.',
#  '"L\'économie de la ville est principalement tournée vers la pêche."',
#  '"Selon la tradition, elle aurait été fondée par l\'évangéliste Marc."',
#  'Le bureau centralisateur est situé à Épinal.',
#  'Il y acquit une passion pour les livres.',
#  'Son directeur général est actuellement François Ouédraogo.',
#  'Je sais bien que pour les messieurs, cela équivaut à sucer son pouce.',
#  'Comme tous les gisements, il contient du gaz dissous dans le pétrole.',
#  '"Pendant la majeure partie de l\'aventure, le joueur incarne Woody Woodpecker."',
#  'Plusieurs lords arrivaient de Windsor.',
#  '"Ce sont des questions délicates posées par le management à l\'auditeur."',
#  '"Ses recherches ont d\'ailleurs inspiré les lois de spectroscopie de Kirchhoff."',
#  '"La communauté est devenue un centre de l\'industrie du textile."',
#  'Cette même année, il fut élevé au grade de brigadier.',
#  'Il est utilisé uniquement au niveau gynécologique et dermatologique.',
#  '"Cette espèce est endémique d\'Arizona aux États-Unis."',
#  'Adopter cet amendement serait donc faire preuve de sagesse.',
#  'MADAME veuve DU BROCARD.',
#  'Et les pauvres morts pourquoi les accuserions-nous?',
#  'Je ne vais quand même pas vous lâcher comme ça dans Paris !',
#  'La grosse femme bondit sur son fauteuil de paille.',
#  'Cela serait une façon de le sécuriser en termes de responsabilité.',
#  'La parole est à Monsieur Sergio Coronado, pour soutenir l’amendement numéro trente-cinq.',
#  'Le conseil scientifique avait été réuni.',
#  'La révocabilité permet de dénouer de manière pacifique ce genre de problème.',
#  'Au pire on sera mouillés.',
#  'Maman Virginie ne cessait pas de paraître forte et contente.',
#  'Rue du Lac Glory, quinze mille trois cents Laveissière',
#  'Parlez, parlez, mon cher ami, je suis tout à vous…',
#  'On devait chauffer seulement à deux heures, pour la reprise du travail.',
#  'Rue Disma, quatre-vingt-dix-sept, six cent soixante Bandrélé',
#  '"Quel homme de guerre c\'eût été !"',
#  'J’ai oublié le sel.',
#  'Quel est cette chose dans l’image ?',
#  'Il importe de clarifier cette situation en supprimant la disposition visée.',
#  'Monsieur le rapporteur, j’ai voté l’article précédent.',
#  'Plusieurs orateurs sont inscrits sur l’article.',
#  'C’est-y de votre famile, cette madame-là ?',
#  'vingt-neuf rue François Marquès, soixante-cinq, zéro zéro zéro, Tarbes',
#  'J’y vois une raison supplémentaire de supprimer cet article.',
#  'on ne veut surtout pas avoir de la soutenir.',
#  'Revenons donc aux choses sérieuses.',
#  'Monsieur Ollier est rassuré',
#  'C’est bien de le dire',
#  'Quand allez-vous vous arrêter?',
#  '"Huit ans plus tard, elle retrouve Gaviria afin de finir l\'enregistrement."',
#  '"La cathédrale est l\'église des Taxiarques à Serrès."',
#  'De Cigualan à Tasco',
#  'Il évolue actuellement au Al Nasr Riyad comme attaquant.',
#  '"Jacques Brunel est nommé nouveau sélectionneur de l\'équipe de France."',
#  '"Ce pont sur l\'Antenne était le lieu de franchissement de la voie romaine Saintes-Lyon."',
#  '"Le commandant prussien, le colonel Bartholomäus d\'O est fait prisonnier par les Autrichiens."',
#  'Son mentor Emil Stricker décède quelques semaines plus tard.',
#  '"Elle est alors remplie d\'herbe à moitié environ."',
#  'Le domaine est privé.',
#  '"C\'est le quatrième album publié par Experience Hendrix et Legacy Recordings."',
#  'Le centre administratif du district est Hapur.',
#  'Il fait partie des rares rameurs à avoir fait son coming-out.',
#  'Il a en outre souvent servi en tant que juré aux concours.',
#  '"Elle est l\'actuelle députée de la du Gard."',
#  'Apple est casse pied avec son icloud?',
#  'Et il marche bien?',
#  'Lui ne croyait guère aux événements tragiques.',
#  '"Le patron s\'attaquera à vos lavabos."',
#  'Papa, un moustique ça pique ou ça suce?',
#  '"Tu sais ce que c\'est une disquette?"',
#  '"L\'ennemi juré de Stéphane Guillon faisait peur aux promesses."',
#  'Discrètement amoureuse, elle se frôlait à lui.',
#  '"Il faut changer une cartouche d\'encre."',
#  'La prof donne des mauvaises notes.',
#  'Franchement, moi, je ne sais pas si je pourrais.',
#  'Une rumeur de louanges les honora.',
#  '"Ensuite elle courait en savates, remuer une vaisselle disparate dans un buffet d\'acajou."',
#  '"Rendez-vous ce soir au Six, ce bar a l\'air top."',
#  'La justice donne raison à Ariane Chemin.',
#  'La cloche de Lough Lene authentique est maintenant conservée au Musée national.',
#  '"L\'hydrogène est \', invitant à \'."',
#  '"L\'histoire du monastère est ponctué régulièrement par les calamités."',
#  'Rosing avait des racines néerlandaises par son père, et était russe par sa mère.',
#  '"Il s\'inscrit au parti communiste d\'Allemagne."',
#  'Elle a le statut de kota et est distincte du Kabupaten de Tegal.',
#  '"Il souligne ensuite que la diplomatie vaticane s\'est renforcée."',
#  '"Une colonne vide peut recevoir n\'importe quelle carte."',
#  'Il est le neveu du cardinal Prospero Marefoschi.',
#  'Il est entouré par les châteaux La Tour Carnet, Belgrave et Lagrange.',
#  '"Surtout, le nombre d\'actes recensés demeure limité."',
#  'On lui doit de nombreuses publications sur les espaces de Banach.',
#  'Les trois meilleures équipes sont qualifiées pour la phase triangulaire.',
#  'La commune est traversée par la Seine.',
#  'Le poste de président, alors occupé par José Ramos-Horta, est principalement honorifique.',
#  'La numérotation disparaît.',
#  'Ces comparaisons seraient fausses.',
#  'On compte quatorze anciennes maisons nobles réparties sur Sainte-Luce-sur-Loire.',
#  'Il émane dans ses constructions plusieurs influences bien distinctes.',
#  'Il fait partie de la famille des Carmenets.',
#  'Les espèces de ce genre se rencontrent en Chine et en Birmanie.',
#  'Les pièges photos ont montré une activité essentiellement nocturne.',
#  'Ces derniers auraient pu faire des ravages chez les professionnels.',
#  'L’eau, du reste, n’entrait pas très vite.',
#  'Ils sont réalisés par de nombreux vidéastes à travers le monde.',
#  'La famille comprend également Gottfried de Linange, évêque de Mayence.',
#  'Elle mène ensuite des fouilles archéologiques en Crète.',
#  'La chapelle abrite un jubé Renaissance en bois de chêne polychrome.',
#  'Goya dessine une dernière charge contre les religieux.',
#  'quatre chaises en bois.',
#  'La séance du trente.',
#  '"Quelqu\'un d\'autre doit venir ?"',
#  '"Qu\'ils écoutent !"',
#  'la rouge.',
#  'Comment sera le temps demain ?',
#  '"tu es sûr qu\'elles auraient aimé."',
#  '"C\'est lui le meilleur."',
#  'Une journaliste.',
#  'Malédiction !',
#  'vingt six chaises jaunes laides.',
#  'Bien jouer.',
#  'Mon chien est aussi fou que le sien.',
#  'Combien de temps dure le vol ?',
#  'Allée du Domaine du Parc, Biarritz',
#  'Tout le monde rit, mais je pense que tout le monde comprend aussi.',
#  'Vous déjeunerez bien mal.',
#  'Certains salons affichaient déjà complet.',
#  'Je n’ai pas osé me manifester.',
#  'Seul ton prénom se décline à l’infini.',
#  '"trois cent vingt allée des Névons, quatre-vingt-quatre, huit cents à L\'Isle-sur-la-Sorgue"',
#  'Sur les dunes trônent des bunkers aux murs épais.',
#  '"vingt-cinq route d\'Argenteuil, quatre-vingt-treize, huit cents, Épinay-sur-Seine"',
#  'À peine avait-il fini sa phrase que les cris reprirent.',
#  'Ils portent un décor de fleurs, écrasé, festonné ou cranté ou de fils torsadés.',
#  'Luché-Pringé est implantée sur la vaste plaine alluviale du Loir.',
#  '"Il manifeste un grand zèle pour les Bourbons durant la Révolution et l\'Empire."',
#  'Très douée, elle trouve rapidement un emploi de couturière, mais aspire à s’élever socialement.',
#  'Le détroit de Rosario obtient ainsi son nom définitif.',
#  'Ce type de matériau grossier était utilisé pour produire entièrement des bols.',
#  '"La même année, la firme se lance dans l\'enregistrement électrique."',
#  'La chambre était peut-être de forme rectangulaire.',
#  'Il coordonne la Politique européenne de sécurité et de défense.',
#  'Il est connu comme un spécialiste de la topographie de la Rome antique.',
#  '"On relève aux l\'existence d\'une famille de Pomoy."',
#  'Dominant le combat au début, Bryan sera finalement éliminé par Jin.',
#  'Le Martínez Campos signe avec le Sultan un traité mettant fin au conflit.',
#  '"Si elle est trop faible, sa tension d\'alimentation le rendra instable."',
#  'Il encourage la prise de conscience sociale à la Barbade.',
#  'Sur le chien mourant les poux, sur le peuple malade les prophètes.',
#  'Aujourd’hui, l’AGS prend en charge l’intégralité des salaires.',
#  'trente-neuf rue Lucien Leducq',
#  'Les Trois Femmes , poussant un cri en l’apercevant.',
#  'deux rue Jean-Pierre Bangue',
#  'Le présent amendement vise à soumettre la délivrance de ces autorisations à une évaluation environnementale.',
#  'La parole est à Madame Valérie Boyer.',
#  'Le voleur avait pénétré dans la maison sans que j’eusse été réveillé.',
#  '"Ruelle de la Gare d\'Eau au numéro cinq"',
#  'Cet amendement vise à soumettre enfin les vendeurs transfrontaliers à la REP française.',
#  'six rue du Château des Quatre Vents, cinquante-cinq, deux cent dix à Vigneulles-lès-Hattonchâtel',
#  'Vous vous êtes déjà exprimé, cher collègue ; je vous demande donc d’être très bref.',
#  'trente et un rue de la Gode Biche',
#  'Il est mis à jour quotidiennement avec un nouveau texte.',
#  '"Times publie alors un erratum officiel en première page concernant l\'histoire de Philips."',
#  'La salle de l’hôpital de Tonnerre possède également une énorme charpente lambrissée.',
#  'Edward Prince est donc très sollicité.',
#  'Il réalise aussi des sketches pour José Garcia et Antoine Decaunes.',
#  '"Durant cette course, il chute comme plusieurs autres coureurs à la sortie d\'un tunnel."',
#  'Elle agrandit aussi son portefeuille de projets de centrale par croissance externe.',
#  '"Or, les œuvres auraient été gardées au secret une quarantaine d\'années."',
#  'Cette station a la particularité de comporter quatre voies.',
#  '"Le projet de construction d\'un musée archéologique régional est en gestation dans la Boumerdès."',
#  'La seconde, de Jean-David Morvan et Nicolas Delestret, aux éditions Delcourt, est plus récente.',
#  '"Ce champignon est présent en Europe ainsi qu\'aux États-Unis et en Australie."',
#  '"Hansen est l\'un des grands historiens de l\'immigration aux États-Unis."',
#  'Il est publié sur YouTube le jour de la sortie du single.',
#  'Ce championnat est souvent considéré comme le véritable championnat du monde.',
#  'car maintenant ils sont taxés :, C’est la réalité, monsieur Robiliard',
#  'Et j’ai pris la suite d’un socialiste',
#  'sur les bancs du groupe UMP, d’avoir une croissance forte.',
#  'Faisons ainsi mon cher ami.',
#  'Tout d’abord, pour la compétitivité sur laquelle je ne reviens pas.',
#  'Les marges de manœuvre sont étroites.',
#  'Au revoir, monsieur de Courson',
#  'Mais nous maintenons évidemment le mécanisme de reconnaissance d’une éventuelle incapacité physique.',
#  'elle lit.',
#  'Elle écrivit une lettre.',
#  'autrefois elle pêcha.',
#  'Je suis Mlle Catherine.',
#  'Où vont-elles ?',
#  'Il ne faut pas que vous y alliez.',
#  '"Ils ne l\'avaient pas écouté."',
#  '"J\'ai fait une erreur."',
#  'Et vous croyez ça ?',
#  'Une chose bien connue des autres animaux.',
#  '"jeudi de l\'Ascension."',
#  'Je suis professeur.',
#  'mon frère.',
#  'se tâcher les vêtements en ramassant des mûres.',
#  'La accueille des élèves de divers pays et de toutes religions.',
#  '"L\'événement principal du festival est un saut à cheval."',
#  'Elle se rencontre sur ʻEua.',
#  '"La reine Emma s\'éteignit le des suites d\'une bronchite."',
#  'Il écrit également des musiques originales pour le cinéma.',
#  'Albin fait des scènes de plus en plus fréquentes à Georges.',
#  'La poudre de cannelle est une source importante de tanins concentrés.',
#  'Et puis plus rien pour les pauvres.',
#  'De votre part, ces éloges feraient perdre la tête...',
#  'La période de croissance principale se situe en automne.',
#  'Plus de personnes ont fui la région.',
#  '"Le lieu de sa sépulture n\'est pas connu."',
#  '"L\'ouverture du bureau de Sfax a été plus tardive."',
#  'On a plus récemment fait la même découverte avec les gorilles.',
#  '"Ce fût la première conquête qu\'ils firent dans les Gaules."',
#  '"Ibn Omar est allé voir Hafsa bint Omar et l\'a informée à ce sujet."',
#  '"L\'insigne sur les épaulettes est composée du cimier."',
#  '"L\'aéroport est le second de la ville après l\'aéroport de Perth."',
#  'Charlotte doit surpasser des problèmes de divorce avec ses parents...',
#  '"Il s\'agit de huit volumes de manuscrits, dont certains sont autographes."',
#  'Le jeu est développé par Imagineer et édité par SouthPeak Interactive.',
#  'C’est à Paris qu’il découvrit l’avant-garde artistique.',
#  'Il reçoit la croix de guerre.',
#  '"Elle permet d\'assurer l\'alimentation en eau et l\'irrigation de zones agricoles de la région."',
#  'Le porte document est monté sur un pantographe commandé par un système électronique.',
#  '"Commune située dans le Quercy, entre Cahors et Tournon-d\'Agenais."',
#  'Avec l’aide du jeune homme, Eliza commence à vendre des fleurs.',
#  'Revenu à Naples, il conspire et est condamné à la prison à perpétuité.',
#  'Il revint ensuite en Europe pour curer une blessure au pied.',
#  '"Cette façade est surmontée d\'un clocher-mur comportant deux arcs en plein cintre."',
#  '"Dans la plupart des applications, c\'est un réfrigérant moins cher que l\'hélium."',
#  'Sa voix était transparente et cristalline dans l’aigu.',
#  '"Plus tard, Ieyasu Tokugawa assigna la province à l\'un de ses alliés."',
#  'Il compte trois sélections en équipe de France de football.',
#  'D’une missions à l’autre, le joueur conserve les mêmes unités, qui gagnent de l’expérience.',
#  'Il fait du ski et du saut à ski dès son plus jeune âge.',
#  'Elle est enclavée dans le parc national du Gros-Morne.',
#  'Joseph Duvet est le plus imposé des Noordpeenois.',
#  '"Ils s\'étaient quittés en très mauvais termes."',
#  'À l’intérieur, des partitions inédites sont découvertes.',
#  'Il y est influencé par les idées de Michel Foucault.',
#  '"Le gayo est parlé par la population du même nom, dans la province d\'Aceh."',
#  '"Dans l\'album, les paroles sur et avec le mal sont toujours aussi présents."',
#  'Le musée de la Marine de Rochefort devient le musée du grand arsenal.',
#  'Sylla passe en Béotie et la réaction d’Archélaos est immédiate.',
#  '"Il a été instituteur, puis directeur d\'école primaire supérieure."',
#  '"S\'il refuse, il lui demandera une deuxième fois de venir."',
#  '"Il occupe ensuite des emplois modestes à l\'académie impériale des sciences de Saint-Pétersbourg."',
#  'Le succès est vite au rendez-vous, aidé par la qualité des matériels.',
#  '"Elle est diplômée de l\'université de Californie à Berkeley."',
#  '"Il décide de s\'engager dans le Génie maritime et entre à l\'école de Lorient."',
#  'Sam est le personnage dirigé par le joueur.',
#  '"Deux médaillons rappellent les protagonistes de l\'Annonciation."',
#  '"L\'intérêt archéologique du site étant prouvé, les travaux n\'auront donc pas lieu."',
#  'Certains extraits en concert circulent sur Internet.',
#  '"Cette version comportait cependant nombre d\'erreurs."',
#  'Les diamètres disponibles correspondent aux diamètres des tubes.',
#  '"Ces deux derniers quittèrent l\'équipe et furent remplacés par Pierre Desproges et Daniel Prévost."',
#  'La romance est née.',
#  '"L\'importance de l\'économie informelle est par essence difficile à évaluer."',
#  'Il était aussi apprécié pour ses qualités humaines, sa simplicité et sa modestie.',
#  '"Les feuillages géométriques correspondent au style naturaliste de l\'époque."',
#  'Le cycle larvaire du Moiré piémontais est encore inconnu.',
#  'Le nombre de Strahler de la Méouzette est donc de quatre.',
#  'Ce que j’ai vécu ne se chiffre pas.',
#  'Bayer tient une place importante dans le club omnisports Bayer Leverkusen.',
#  '"Par ses nombreux nouvelles et romans, il contribue à l\'émergence d\'une littérature ouvrière anarchiste."',
#  '"En tant que tempête tropicale, Cristobal n\'approchera aucune terre, et n\'aura donc aucune conséquence."',
#  'Il faut donc être vigilant, car les sorcières se cachent parmi nous...',
#  'Elle contribue aux débats du Grenelle Environnement.',
#  'Sous le régime français, fusionne avec Cobru, Foy, Recogne et Vaux.',
#  ...]

# %%
tokenized_sentences = []
segmentss = []
space = tokenizer.IdToPiece(5)

# specifically for zh-CN
# pattern = ",|\?|・|\u3002|\uff1f|\uff01|\uff0c|\u3001|\uff1b|\uff1a|\u201c|\u201d|\u2018|\u2019|\uff08|\uff09|\u300a|\u300b|\u3008|\u3009|\u3010|\u3011|\u300e|\u300f|\u300c|\u300d|\ufe43|\ufe44|\u3014|\u3015|\u2026|\u2014|\uff5e|\ufe4f|\uffe5" + punctuation
# for sent in sentences:
#     tokens = tokenizer.EncodeAsPieces(sent)
#     segments = []
#     for idx, token in enumerate(tokens):
#         if token != space and token not in pattern:
#             segments.append((idx, idx))
#     tokenized_sentence = []
#     for seg in segments:
#         tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

#     segmentss.append(segments)
#     tokenized_sentences.append(tokenized_sentence)

# for other languages
for sent in tqdm(sentences):
    tokens = tokenizer.EncodeAsPieces(sent)
    segments = []
    last = -1
    for idx, token in enumerate(tokens):
        if token.startswith(space) or token in punctuation:
            if last != -1 and last <= idx - 1:
                segments.append((last, idx - 1))
            last = idx + (token in punctuation)
    if last < len(tokens):
        segments.append((last, len(tokens) - 1))

    tokenized_sentence = []
    for seg in segments:
        tokenized_sentence.append(''.join(tokens[seg[0] : seg[1] + 1]).replace(space, ''))

    tokenized_sentences.append(tokenized_sentence)
    segmentss.append(segments)
# Out:
# 100%|██████████| 207372/207372 [00:05<00:00, 35612.91it/s]

# %%
for i, id in enumerate(tqdm(lang_df['id'])):
    with open(os.path.join(lang_root, '16kHz', '{}.txt'.format(id)), 'w') as w:
        w.write(' '.join(tokenized_sentences[i]))
# Out:
# 100%|██████████| 207372/207372 [00:08<00:00, 23581.16it/s]

# %% [markdown]
# Doing MFA alignment.

# %%
filtered_grids = []
n_outlier = 0
for i, id in enumerate(tqdm(lang_df['id'])):
    # grid_path = os.path.join(dict_lang_root, '16kHz/align_wmseg/{}.TextGrid'.format(id))
    grid_path = os.path.join(lang_root, '16kHz/align_spm/{}.TextGrid'.format(id))
    if os.path.exists(grid_path):
        grid = textgrids.TextGrid(grid_path)
        filtered_grid = [tok for tok in grid['words'] if tok.text != '']

        if len(filtered_grid) != len(tokenized_sentences[i]):
            # print(filtered_grid, tokenized_sentences[i], sep='\n')
            continue

        interval = np.array([(word.xmin, word.xmax) for word in filtered_grid])
        audio_path = os.path.join(lang_root, '16kHz/{}.wav'.format(id))
        info = torchaudio.info(audio_path)
        duration = info.num_frames / info.sample_rate
        interval = interval / duration

        th.save([segmentss[i], interval], os.path.join(lang_root, '16kHz', '{}.pt'.format(id)))
# Out:
# 100%|██████████| 127824/127824 [01:13<00:00, 1734.18it/s]
