# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
fn = 'wo_const.txt'
with open(fn, 'r') as r:
    wo_const_sims = [float(line.strip()) for line in r.readlines() if line.strip() != '']

# %%
fn = 'w_const_13.txt'
with open(fn, 'r') as r:
    w_const_13_sims = [float(line.strip()) for line in r.readlines() if line.strip() != '']

# %%
len(wo_const_sims), len(w_const_13_sims)
# Out:
# (2160, 2160)

# %%
df = pd.DataFrame(columns=['sim', 'const'])

# %%
df['sim'] = wo_const_sims + w_const_13_sims
df['const'] = [False] *

# %%
sns.displot(df, x="wo", kind="kde")
sns.displot(df, x="w", kind="kde")
